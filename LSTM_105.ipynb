# %% [markdown]
# # LSTM
# Here, use 8 weather features.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %%
SITE = 'Eagle'
METER = 'steam'
BLDG = 'Eagle_education_Peter'   # one example
PREDICTOR_VARIABLE = 'dewTemperature'  # for starters
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)
PREDICTED_VARIABLE = 'steam'  # for starters
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
DOWNSAMPLE = False   # if true, use 1 time per day, else 24 times per day
STEPS_HISTORY = 24 
STEPS_FUTURE =  1    
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                X[x0,x1,x2] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
num_predictors = len(PREDICTORS)  # e.g. 8 weather features
def make_RNN():
    rnn = Sequential([
        LSTM(20,return_sequences=True, 
                  input_shape=(STEPS_HISTORY,num_predictors)), 
        LSTM(10,return_sequences=False),
        Dense(STEPS_FUTURE)   
    ])
    rnn.compile(optimizer='adam',loss=MeanSquaredError())
    return rnn

# %%
cors = []
EPOCHS=5
# Test on only Peter just during code development
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        print("Train on",len(X_train),"samples such as",X_train[100][0])
        print("Predict",len(y_train),"labels such as",y_train[100])
        model = make_RNN()
        print(model.summary())
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        # Compare. Solve the problem that predict.shape != truth.shape 
        ##print(" before ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        #nsamples, nsteps, ndim = y_test.shape
        #y_test = y_test.reshape(nsamples,nsteps*ndim)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        ##print(" after ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][PREDICTOR_VARIABLE] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)

        ## break   ## REMOVE THIS LINE TO LOOP OVER BUILDINGS!
        
if True:
    print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
    print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",PREDICTOR_VARIABLE)
    print("          Using one weather feature as leading correlate.")
    print("Column 2: Mean usage.")
    print("          Using mean to help understand the RMSE.")
    print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
    print("Column 4: RMSE/mean normalized to help understand RMSE.")
    print("Column 5: Building.")
    for cor in sorted(cors):
        print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [856.91]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 24, 20)            2320
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10)                1240
# _________________________________________________________________
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 10s 24ms/step - loss: 342919.0333
# Epoch 2/5
# 274/274 [==============================] - 7s 25ms/step - loss: 331123.9882
# Epoch 3/5
# 274/274 [==============================] - 7s 26ms/step - loss: 328120.1134
# Epoch 4/5
# 274/274 [==============================] - 6s 23ms/step - loss: 328738.1591
# Epoch 5/5
# 274/274 [==============================] - 6s 23ms/step - loss: 324390.1552
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545475 462.14819904520215 0.9680299296582485 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [424.34]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 24, 20)            2320
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10)                1240
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 10s 23ms/step - loss: 52864.7399
# Epoch 2/5
# 274/274 [==============================] - 7s 25ms/step - loss: 50058.2919
# Epoch 3/5
# 274/274 [==============================] - 7s 27ms/step - loss: 49112.7123
# Epoch 4/5
# 274/274 [==============================] - 8s 30ms/step - loss: 46816.3470
# Epoch 5/5
# 274/274 [==============================] - 7s 27ms/step - loss: 45651.1089
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500085 143.55349135687715 0.789017050062393 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [2374.16]
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 24, 20)            2320
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 10)                1240
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 12s 31ms/step - loss: 1666489.9632
# Epoch 2/5
# 274/274 [==============================] - 7s 24ms/step - loss: 1631204.3305
# Epoch 3/5
# 274/274 [==============================] - 7s 26ms/step - loss: 1638167.7936
# Epoch 4/5
# 274/274 [==============================] - 6s 24ms/step - loss: 1646046.2050
# Epoch 5/5
# 274/274 [==============================] - 7s 24ms/step - loss: 1581103.1936
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.016015073252 1242.1700030693573 1.037722125207608 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [207.79]
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 24, 20)            2320
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 10)                1240
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 26ms/step - loss: 8583.9572
# Epoch 2/5
# 274/274 [==============================] - 7s 27ms/step - loss: 7627.3114
# Epoch 3/5
# 274/274 [==============================] - 7s 25ms/step - loss: 7032.6665
# Epoch 4/5
# 274/274 [==============================] - 7s 25ms/step - loss: 6546.5646
# Epoch 5/5
# 274/274 [==============================] - 7s 24ms/step - loss: 6322.7365
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264256 74.02333972702235 0.9041383609128159 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [6895.45]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 24, 20)            2320
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 10)                1240
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 23ms/step - loss: 12788679.4145
# Epoch 2/5
# 274/274 [==============================] - 7s 26ms/step - loss: 12772905.3855
# Epoch 3/5
# 274/274 [==============================] - 7s 26ms/step - loss: 12765978.2036
# Epoch 4/5
# 274/274 [==============================] - 8s 28ms/step - loss: 12914346.1927
# Epoch 5/5
# 274/274 [==============================] - 7s 25ms/step - loss: 12782785.0509
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.430703431568 3197.772677587083 1.0159946251082281 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [256.52]
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 24ms/step - loss: 12760.3034
# Epoch 2/5
# 274/274 [==============================] - 6s 23ms/step - loss: 11704.7435
# Epoch 3/5
# 274/274 [==============================] - 7s 24ms/step - loss: 11002.5787
# Epoch 4/5
# 274/274 [==============================] - 6s 24ms/step - loss: 10601.0259
# Epoch 5/5
# 274/274 [==============================] - 6s 22ms/step - loss: 10090.1892
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606874 80.44421441543983 0.8674647806075416 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [0.08]
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 10s 23ms/step - loss: 0.0163
# Epoch 2/5
# 274/274 [==============================] - 7s 25ms/step - loss: 3.4719e-04
# Epoch 3/5
# 274/274 [==============================] - 7s 24ms/step - loss: 3.2687e-04
# Epoch 4/5
# 274/274 [==============================] - 7s 24ms/step - loss: 3.4598e-04
# Epoch 5/5
# 274/274 [==============================] - 7s 25ms/step - loss: 3.4168e-04
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135475 0.029204473780464615 0.27752663809000694 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [201.49]
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 26ms/step - loss: 15349.2990
# Epoch 2/5
# 274/274 [==============================] - 7s 25ms/step - loss: 14196.1273
# Epoch 3/5
# 274/274 [==============================] - 7s 27ms/step - loss: 13443.3593
# Epoch 4/5
# 274/274 [==============================] - 7s 26ms/step - loss: 12568.1578
# Epoch 5/5
# 274/274 [==============================] - 6s 21ms/step - loss: 11992.6831
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508735 109.93860009616614 0.901813158288007 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [412.35]
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 10s 22ms/step - loss: 85781.3757
# Epoch 2/5
# 274/274 [==============================] - 6s 21ms/step - loss: 83602.1678
# Epoch 3/5
# 274/274 [==============================] - 6s 21ms/step - loss: 81082.2330
# Epoch 4/5
# 274/274 [==============================] - 6s 22ms/step - loss: 79239.4877
# Epoch 5/5
# 274/274 [==============================] - 6s 23ms/step - loss: 77991.9799
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.9563635497514 378.96105366469 1.1280067734408907 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [3984.16]
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 9s 21ms/step - loss: 5290663.0382
# Epoch 2/5
# 274/274 [==============================] - 6s 21ms/step - loss: 5287431.7673
# Epoch 3/5
# 274/274 [==============================] - 6s 21ms/step - loss: 5370861.8036
# Epoch 4/5
# 274/274 [==============================] - 6s 21ms/step - loss: 5224795.3436
# Epoch 5/5
# 274/274 [==============================] - 6s 21ms/step - loss: 5287333.1491
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358292 2227.049724933325 1.096874964965687 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [3581.43]
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_20 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 9s 21ms/step - loss: 4367992.6173
# Epoch 2/5
# 274/274 [==============================] - 7s 27ms/step - loss: 4360520.4509
# Epoch 3/5
# 274/274 [==============================] - 6s 22ms/step - loss: 4379288.1855
# Epoch 4/5
# 274/274 [==============================] - 5s 19ms/step - loss: 4270750.0591
# Epoch 5/5
# 274/274 [==============================] - 5s 19ms/step - loss: 4347509.4782
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547193 1684.4429644072775 1.0306939197106488 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [1543.14]
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_22 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 9s 20ms/step - loss: 608942.1264
# Epoch 2/5
# 274/274 [==============================] - 6s 20ms/step - loss: 579880.2549
# Epoch 3/5
# 274/274 [==============================] - 6s 22ms/step - loss: 574754.0208
# Epoch 4/5
# 274/274 [==============================] - 7s 24ms/step - loss: 592003.9650
# Epoch 5/5
# 274/274 [==============================] - 8s 28ms/step - loss: 579424.4425
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245889 815.3098296520682 1.1461750822720544 Eagle_education_Norah
# Building Eagle_education_Will
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [297.45]
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 23ms/step - loss: 75959.8245
# Epoch 2/5
# 274/274 [==============================] - 6s 23ms/step - loss: 73207.2480
# Epoch 3/5
# 274/274 [==============================] - 6s 21ms/step - loss: 70526.5858
# Epoch 4/5
# 274/274 [==============================] - 6s 21ms/step - loss: 70590.0593
# Epoch 5/5
# 274/274 [==============================] - 6s 22ms/step - loss: 69574.1681
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769716 174.58649541502234 0.7722691642814915 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [135.07]
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_26 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 10s 25ms/step - loss: 4181.1328
# Epoch 2/5
# 274/274 [==============================] - 6s 22ms/step - loss: 3631.3815
# Epoch 3/5
# 274/274 [==============================] - 6s 21ms/step - loss: 3360.0612
# Epoch 4/5
# 274/274 [==============================] - 6s 22ms/step - loss: 3078.5014
# Epoch 5/5
# 274/274 [==============================] - 7s 26ms/step - loss: 2812.1597
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.96274977501869 48.563170423825774 0.8525425934603214 Eagle_education_Petra
# Building Eagle_lodging_Trina
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [304.34]
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_28 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 26ms/step - loss: 11346.8926
# Epoch 2/5
# 274/274 [==============================] - 7s 24ms/step - loss: 10490.6443
# Epoch 3/5
# 274/274 [==============================] - 6s 22ms/step - loss: 10027.9594
# Epoch 4/5
# 274/274 [==============================] - 6s 22ms/step - loss: 9291.9550
# Epoch 5/5
# 274/274 [==============================] - 6s 20ms/step - loss: 9024.4877
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551768 84.97823628994196 0.9318104420803729 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [234.44]
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_30 (LSTM)               (None, 24, 20)            2320
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,571
# Trainable params: 3,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 11s 24ms/step - loss: 28240.2698
# Epoch 2/5
# 274/274 [==============================] - 6s 24ms/step - loss: 26709.1585
# Epoch 3/5
# 274/274 [==============================] - 6s 21ms/step - loss: 25633.1821
# Epoch 4/5
# 274/274 [==============================] - 6s 21ms/step - loss: 25540.8104
# Epoch 5/5
# 274/274 [==============================] - 7s 27ms/step - loss: 24995.1416
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033823 132.47438041457886 0.8920390824855006 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36    2227.05  1.10   Eagle_education_Sherrill
# -0.8545    1634.28    1684.44  1.03   Eagle_education_Brooke
# -0.8502    3147.43    3197.77  1.02   Eagle_education_Peter
# -0.8403     477.41     462.15  0.97   Eagle_health_Athena
# -0.8186    1197.02    1242.17  1.04   Eagle_education_Roman
# -0.7988      56.96      48.56  0.85   Eagle_education_Petra
# -0.7961     121.91     109.94  0.90   Eagle_health_Vincenza
# -0.7722     711.33     815.31  1.15   Eagle_education_Norah
# -0.7596     181.94     143.55  0.79   Eagle_public_Alvin
# -0.7222      81.87      74.02  0.90   Eagle_lodging_Edgardo
# -0.7130      92.73      80.44  0.87   Eagle_lodging_Dawn
# -0.6796     148.51     132.47  0.89   Eagle_education_Teresa
# -0.6741      91.20      84.98  0.93   Eagle_lodging_Trina
# -0.5553     335.96     378.96  1.13   Eagle_office_Francis
# -0.3579     226.07     174.59  0.77   Eagle_education_Will
#  0.7231       0.11       0.03  0.28   Eagle_education_Wesley
