# %% [markdown]
# # Apply ARIMA to the Electricity Dataset
# Assume user downloaded archive.zip from Kaggle,
# renamed the file BuildingData.zip,
# and stored the file in the data subdirectory.
# Assume the zip file contains the electricity_cleaned.csv file.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='C:/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
ELEC_FILE='electricity_cleaned.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from pandas.plotting import autocorrelation_plot

from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import StandardScaler

from statsmodels.tsa.arima.model import ARIMA

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    temp_col = pd.to_datetime(panda['timestamp'])
    temp_tab = panda.drop(['timestamp'],axis=1)
    panda = temp_tab
    panda.insert(0,'date',temp_col,True)
    return panda
def get_building_timeseries(panda,building):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    building_df = list(elec_df)==building
    temp_col = building_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = building_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %%
elec_df = read_zip_to_panda(ZIP_PATH,ELEC_FILE)
elec_df = fix_date_type(elec_df)
elec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Columns: 1579 entries, date to Mouse_science_Micheal
# dtypes: datetime64[ns](1), float64(1578)
# memory usage: 211.3 MB

# %%
elec_df
# Out:
#                      date  Panther_parking_Lorriane  Panther_lodging_Cora  \
# 0     2016-01-01 00:00:00                       NaN                   NaN
# 1     2016-01-01 01:00:00                       NaN                   NaN
# 2     2016-01-01 02:00:00                       NaN                   NaN
# 3     2016-01-01 03:00:00                       NaN                   NaN
# 4     2016-01-01 04:00:00                       NaN                   NaN
# ...                   ...                       ...                   ...
# 17539 2017-12-31 19:00:00                   15.4830              135.2261
# 17540 2017-12-31 20:00:00                   12.7224              135.9262
# 17541 2017-12-31 21:00:00                   11.2822              135.1761
# 17542 2017-12-31 22:00:00                   16.9233              137.6266
# 17543 2017-12-31 23:00:00                   11.8223              136.1263
#
#        Panther_office_Hannah  Panther_lodging_Hattie  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 17539                 3.4357                 79.1353
# 17540                 3.4087                 81.6958
# 17541                 3.3546                 82.8160
# 17542                 3.2876                 82.3359
# 17543                 3.3686                 82.4959
#
#        Panther_education_Teofila  Panther_education_Jerome  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 17539                   105.6374                  465.0898
# 17540                   107.7348                  463.6895
# 17541                   106.1295                  461.2890
# 17542                   109.6282                  460.5889
# 17543                   103.7540                  462.0892
#
#        Panther_retail_Felix  Panther_parking_Asia  Panther_education_Misty  \
# 0                       NaN                   NaN                      NaN
# 1                       NaN                   NaN                      NaN
# 2                       NaN                   NaN                      NaN
# 3                       NaN                   NaN                      NaN
# 4                       NaN                   NaN                      NaN
# ...                     ...                   ...                      ...
# 17539               67.0199               35.7069                  16.3231
# 17540               56.6869               35.7069                  16.0831
# 17541               55.0576               35.5068                  16.1631
# 17542               49.6776               35.7069                  14.8829
# 17543               42.6952               35.6069                  16.0031
#
#        ...  Cockatoo_public_Caleb  Cockatoo_education_Tyler  \
# 0      ...                123.200                   727.575
# 1      ...                126.475                   731.200
# 2      ...                127.825                   724.675
# 3      ...                130.475                   737.375
# 4      ...                129.675                   721.150
# ...    ...                    ...                       ...
# 17539  ...                 96.925                   704.950
# 17540  ...                 97.550                   695.700
# 17541  ...                 93.825                   687.325
# 17542  ...                 94.150                   674.275
# 17543  ...                 96.325                   677.400
#
#        Cockatoo_public_Shad  Mouse_health_Buddy  Mouse_health_Modesto  \
# 0                    69.200              8.8224              370.0870
# 1                    66.275             17.6449              737.8260
# 2                    64.675             17.6449              729.9255
# 3                    65.875             17.6449              722.2620
# 4                    66.275             17.6449              719.1665
# ...                     ...                 ...                   ...
# 17539               111.350                 NaN                   NaN
# 17540               115.875                 NaN                   NaN
# 17541               111.650                 NaN                   NaN
# 17542               111.950                 NaN                   NaN
# 17543               113.250                 NaN                   NaN
#
#        Mouse_lodging_Vicente  Mouse_health_Justin  Mouse_health_Ileana  \
# 0                       10.0             282.9965                 26.0
# 1                       30.0             574.9265                 51.0
# 2                       30.0             570.2780                 50.0
# 3                       20.0             561.1470                 52.0
# 4                       30.0             564.3695                 50.0
# ...                      ...                  ...                  ...
# 17539                    NaN                  NaN                  NaN
# 17540                    NaN                  NaN                  NaN
# 17541                    NaN                  NaN                  NaN
# 17542                    NaN                  NaN                  NaN
# 17543                    NaN                  NaN                  NaN
#
#        Mouse_health_Estela  Mouse_science_Micheal
# 0                    135.0               168.2243
# 1                    265.0               336.4486
# 2                    272.0               336.4486
# 3                    276.0               336.4486
# 4                    280.0               336.4486
# ...                    ...                    ...
# 17539                  NaN                    NaN
# 17540                  NaN                    NaN
# 17541                  NaN                    NaN
# 17542                  NaN                    NaN
# 17543                  NaN                    NaN
#
# [17544 rows x 1579 columns]

# %%
park_cols = [c for c in elec_df.columns if 'Gator' in c]
print(park_cols)
# Out:
# ['Gator_public_Nettie', 'Gator_assembly_Selma', 'Gator_public_Marcie', 'Gator_assembly_Beryl', 'Gator_public_Lindsey', 'Gator_public_Clara', 'Gator_public_Marissa', 'Gator_public_Maude', 'Gator_assembly_Erich', 'Gator_assembly_Marjorie', 'Gator_public_Kenny', 'Gator_other_Reginald', 'Gator_assembly_Loyce', 'Gator_assembly_Blanca', 'Gator_office_Carrie', 'Gator_assembly_Maurine', 'Gator_public_Latasha', 'Gator_other_Cassandra', 'Gator_public_Dewey', 'Gator_assembly_Stacy', 'Gator_assembly_Lucia', 'Gator_assembly_Joni', 'Gator_public_Cheri', 'Gator_public_Everette', 'Gator_other_Glen', 'Gator_public_Beulah', 'Gator_assembly_Virgie', 'Gator_public_Geraldine', 'Gator_public_Jayme', 'Gator_office_August', 'Gator_assembly_Lera', 'Gator_assembly_Daisy', 'Gator_public_Erika', 'Gator_assembly_Elliot', 'Gator_assembly_Roy', 'Gator_public_Noe', 'Gator_public_Leroy', 'Gator_other_Minda', 'Gator_other_Elfriede', 'Gator_public_Natasha', 'Gator_public_Philip', 'Gator_assembly_Lelia', 'Gator_office_Lisa', 'Gator_office_Merle', 'Gator_office_Betty', 'Gator_office_Hunter', 'Gator_assembly_Kimberly', 'Gator_public_Tiffany', 'Gator_public_Alexandra', 'Gator_assembly_Regina', 'Gator_public_Dionna', 'Gator_other_Russel', 'Gator_office_Julie', 'Gator_public_Randall', 'Gator_other_Samuel', 'Gator_public_Lona', 'Gator_assembly_Milton', 'Gator_assembly_Kayleigh', 'Gator_assembly_Enid', 'Gator_assembly_Bailey', 'Gator_office_Lucy', 'Gator_assembly_Alexa', 'Gator_assembly_Hue', 'Gator_public_Jolene', 'Gator_other_Gertrude', 'Gator_public_Ross', 'Gator_warehouse_Constance', 'Gator_public_Kendall', 'Gator_assembly_Lilli', 'Gator_public_Dale', 'Gator_public_Janna', 'Gator_warehouse_Stacie', 'Gator_other_Refugio', 'Gator_assembly_Gene']

# %%
Gator = elec_df.filter(like='Gator')
Gator
# Out:
#        Gator_public_Nettie  Gator_assembly_Selma  Gator_public_Marcie  \
# 0                  20.0000                1.6667             123.3333
# 1                  20.0000                1.6667             123.3333
# 2                  20.0000                1.6667             123.3333
# 3                  20.0000                1.6667             123.3333
# 4                  20.0000                1.6667             123.3333
# ...                    ...                   ...                  ...
# 17539              21.6667                1.0417              76.6667
# 17540              21.6667                1.0417              76.6667
# 17541              21.6667                1.0417              76.6667
# 17542              21.6667                1.0417              76.6667
# 17543              21.6667                1.0417              76.6667
#
#        Gator_assembly_Beryl  Gator_public_Lindsey  Gator_public_Clara  \
# 0                    0.5417               25.0000             15.9583
# 1                    0.5417               25.0000             15.9583
# 2                    0.5417               25.0000             15.9583
# 3                    0.5417               25.0000             15.9583
# 4                    0.5417               25.0000             15.9583
# ...                     ...                   ...                 ...
# 17539                   NaN               16.6667             11.3333
# 17540                   NaN               16.6667             11.3333
# 17541                   NaN               16.6667             11.3333
# 17542                   NaN               16.6667             11.3333
# 17543                   NaN               16.6667             11.3333
#
#        Gator_public_Marissa  Gator_public_Maude  Gator_assembly_Erich  \
# 0                   13.3333            108.3333                 14.80
# 1                   13.3333            108.3333                 17.61
# 2                   13.3333            108.3333                 17.68
# 3                   13.3333            108.3333                 16.90
# 4                   13.3333            108.3333                 16.74
# ...                     ...                 ...                   ...
# 17539                8.3333            104.1667                   NaN
# 17540                8.3333            104.1667                   NaN
# 17541                8.3333            104.1667                   NaN
# 17542                8.3333            104.1667                   NaN
# 17543                8.3333            104.1667                   NaN
#
#        Gator_assembly_Marjorie  ...  Gator_other_Gertrude  Gator_public_Ross  \
# 0                      35.0417  ...                0.6667             8.3333
# 1                      35.0417  ...                0.6667             8.3333
# 2                      35.0417  ...                0.6667             8.3333
# 3                      35.0417  ...                0.6667             8.3333
# 4                      35.0417  ...                0.6667             8.3333
# ...                        ...  ...                   ...                ...
# 17539                  54.4583  ...                1.0417            10.0000
# 17540                  54.4583  ...                1.0417            10.0000
# 17541                  54.4583  ...                1.0417            10.0000
# 17542                  54.4583  ...                1.0417            10.0000
# 17543                  54.4583  ...                1.0417            10.0000
#
#        Gator_warehouse_Constance  Gator_public_Kendall  Gator_assembly_Lilli  \
# 0                        15.0000               20.1667                3.7917
# 1                        15.0000               20.1667                3.7917
# 2                        15.0000               20.1667                3.7917
# 3                        15.0000               20.1667                3.7917
# 4                        15.0000               20.1667                3.7917
# ...                          ...                   ...                   ...
# 17539                     6.6667               13.5000                1.6250
# 17540                     6.6667               13.5000                1.6250
# 17541                     6.6667               13.5000                1.6250
# 17542                     6.6667               13.5000                1.6250
# 17543                     6.6667               13.5000                1.6250
#
#        Gator_public_Dale  Gator_public_Janna  Gator_warehouse_Stacie  \
# 0                50.0000             91.6667                     NaN
# 1                50.0000             91.6667                     NaN
# 2                50.0000             91.6667                     NaN
# 3                50.0000             91.6667                     NaN
# 4                50.0000             91.6667                     NaN
# ...                  ...                 ...                     ...
# 17539            20.8333            133.3333                 11.6667
# 17540            20.8333            133.3333                 11.6667
# 17541            20.8333            133.3333                 11.6667
# 17542            20.8333            133.3333                 11.6667
# 17543            20.8333            133.3333                 11.6667
#
#        Gator_other_Refugio  Gator_assembly_Gene
# 0                   0.1250              29.1667
# 1                   0.1250              29.1667
# 2                   0.1250              29.1667
# 3                   0.1250              29.1667
# 4                   0.1250              29.1667
# ...                    ...                  ...
# 17539               0.0833              20.8333
# 17540               0.0833              20.8333
# 17541               0.0833              20.8333
# 17542               0.0833              20.8333
# 17543               0.0833              20.8333
#
# [17544 rows x 74 columns]

# %%
buildings= list(elec_df)

# %%
# Plot temperature time series per site. 
# Separate plots stacked vertically.
for building in buildings:
    building_df = get_building_timeseries(elec_df,building)
    #temp_df = building_df[Gator ]
    temp_df.plot(figsize=(20,5))
    plt.plot(elec_df[building])
    plt.title(building)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-49c875f55087> in <module>
#       2 # Separate plots stacked vertically.
#       3 for building in buildings:
# ----> 4     building_df = get_building_timeseries(elec_df,building)
#       5     #temp_df = building_df[Gator ]
#       6     temp_df.plot(figsize=(20,5))
#
# <ipython-input-3-9996d5861eb0> in get_building_timeseries(panda, building)
#      16     # Convert the datetime column to a DatetimeIndex.
#      17     building_df = list(elec_df)==building
# ---> 18     temp_col = building_df['date']
#      19     temp_val = temp_col.values
#      20     temp_ndx = pd.DatetimeIndex(temp_val)
#
# TypeError: 'bool' object is not subscriptable

# %%
# See the Electricity_100 notebook for basic stats.

# %%
# Not done: start ARIMA analysis.
