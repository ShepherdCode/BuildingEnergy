# %% [markdown]
# # CNN + LSTM
# Assume user downloaded archive.zip from Kaggle, renamed the file BuildingData.zip, and stored the file in the data subdirectory. Assume the zip file contains the weather.csv file.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import TimeDistributed

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=5  # use 1 for testing, 25 for production
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(TimeDistributed(Flatten()))
    dnn.add(Flatten())
    dnn.add(Dense(STEPS_FUTURE))   
    dnn.compile(optimizer='adam',loss=MeanSquaredError())
    dnn.build(input_shape=INPUT_SHAPE)
    return dnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_DNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)        
        print("Raw y_pred.shape:",y_pred.shape)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        #print("Reshaped y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed (TimeDistri (None, 22, 48)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 48680.7740
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 20842.2297
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 20429.2759
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 19601.9438
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 18512.4057
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545475 139.12280015054105 0.29141092559015774 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 49900.7783
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 3688.5749
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 3841.8874
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 3678.8619
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 3617.9257
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500085 48.417716270517495 0.2661196415456704 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 336870.8747
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 93122.8543
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 88203.9620
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 84745.7615
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 84442.9862
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.016015073252 255.12365851787422 0.21313303690616187 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 2857.2718
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 1156.6925
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 1020.4938
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 983.2253
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 958.4835
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264256 30.461401059801762 0.37206266735440297 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3488876.8159
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 851545.2309
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 650065.5014
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 633135.4445
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 591430.1874
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.430703431568 790.0086223168229 0.25100111702395717 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4387.3882
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1484.4056
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1533.5942
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1388.5529
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1353.8106
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606874 43.24000376402066 0.4662756750276157 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3822.5291
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 15.6121
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10.7578
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8.5351
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.2025
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135475 1.9181693580521364 18.228135087425194 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2915.4129
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 622.8070
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 530.4555
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 546.2840
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 583.2581
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508735 24.310170526619302 0.19941341477837407 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8288.4176
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4386.2812
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4163.7022
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3863.1106
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3832.9976
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.9563635497514 117.10636963558288 0.3485761317280145 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 22, 48)            0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1571205.4375
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 360569.6174
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 304472.4201
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 264404.4138
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 258518.9868
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358292 451.37191401845246 0.22231140456026763 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 22, 48)            0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 931860.6411
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 296723.6090
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 260267.8446
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 243905.5173
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 232147.4837
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547193 576.6603767004767 0.35285275700170554 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 22, 48)            0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 138064.2313
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 75376.1883
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 71923.2555
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 70223.7745
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 70551.6515
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245889 221.7011705416953 0.3116709110374379 Eagle_education_Norah
# Building Eagle_education_Will
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 22, 48)            0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10480.5572
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7645.9708
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7839.8909
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7584.0584
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 7357.0708
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769716 67.32912743192358 0.29782491967691815 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 22, 48)            0
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 5ms/step - loss: 18885.4707
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 418.1282
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 388.1314
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 363.0097
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 374.3604
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.96274977501869 18.88835066467601 0.33159127217835954 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 22, 48)            0
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6706.4908
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2085.4122
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2074.0428
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2194.1920
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1971.4436
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551768 35.84601272803631 0.3930616876180521 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 22, 48)            0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 10786.9655
# Epoch 2/5
# 274/274 [==============================] - 1s 5ms/step - loss: 3086.5808
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2900.1147
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2789.1654
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2752.2232
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033823 54.23944409504974 0.3652306490783717 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36     451.37  0.22   Eagle_education_Sherrill
# -0.8545    1634.28     576.66  0.35   Eagle_education_Brooke
# -0.8502    3147.43     790.01  0.25   Eagle_education_Peter
# -0.8403     477.41     139.12  0.29   Eagle_health_Athena
# -0.8186    1197.02     255.12  0.21   Eagle_education_Roman
# -0.7988      56.96      18.89  0.33   Eagle_education_Petra
# -0.7961     121.91      24.31  0.20   Eagle_health_Vincenza
# -0.7722     711.33     221.70  0.31   Eagle_education_Norah
# -0.7596     181.94      48.42  0.27   Eagle_public_Alvin
# -0.7222      81.87      30.46  0.37   Eagle_lodging_Edgardo
# -0.7130      92.73      43.24  0.47   Eagle_lodging_Dawn
# -0.6796     148.51      54.24  0.37   Eagle_education_Teresa
# -0.6741      91.20      35.85  0.39   Eagle_lodging_Trina
# -0.5553     335.96     117.11  0.35   Eagle_office_Francis
# -0.3579     226.07      67.33  0.30   Eagle_education_Will
#  0.7231       0.11       1.92 18.23   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Results on all buildings.
#
# * 0.00 mean RMSE
# * 0.00 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.00 mean RMSE
# * 0.00 stddev
