# %% [markdown]
# # CNN + GRU CoLab
# Assume user downloaded archive.zip from Kaggle, renamed the file BuildingData.zip, and stored the file in the data subdirectory. Assume the zip file contains the weather.csv file.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import TimeDistributed

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=25  # use 1 for testing, 25 for production
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(Conv2D(
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(MaxPooling2D())
    dnn.add(TimeDistributed(Flatten()))
    dnn.add(GRU(8,return_sequences=True))
    dnn.add(GRU(8,return_sequences=False))
    dnn.add(Dense(STEPS_FUTURE))   
    dnn.compile(optimizer='adam',loss=MeanSquaredError())
    dnn.build(input_shape=INPUT_SHAPE)
    return dnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_DNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)        
        print("Raw y_pred.shape:",y_pred.shape)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        #print("Reshaped y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 16)            0
# _________________________________________________________________
# gru (GRU)                    (None, 10, 8)             624
# _________________________________________________________________
# gru_1 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 13ms/step - loss: 345259.3133
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 333594.7665
# Epoch 3/25
# 274/274 [==============================] - 4s 13ms/step - loss: 334361.0130
# Epoch 4/25
# 274/274 [==============================] - 4s 13ms/step - loss: 327665.9170
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 326171.5438
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 323718.0925
# Epoch 7/25
# 274/274 [==============================] - 4s 13ms/step - loss: 319601.2970
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 320250.0273
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 315280.6436
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 320424.4485
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 310285.7093
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 310551.9548
# Epoch 13/25
# 274/274 [==============================] - 4s 13ms/step - loss: 303924.4414
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 305486.8220
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 300735.3663
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 303814.2488
# Epoch 17/25
# 274/274 [==============================] - 4s 13ms/step - loss: 299214.3957
# Epoch 18/25
# 274/274 [==============================] - 4s 13ms/step - loss: 290209.3895
# Epoch 19/25
# 274/274 [==============================] - 4s 13ms/step - loss: 296270.9235
# Epoch 20/25
# 274/274 [==============================] - 4s 13ms/step - loss: 292272.7218
# Epoch 21/25
# 274/274 [==============================] - 4s 13ms/step - loss: 287793.8303
# Epoch 22/25
# 274/274 [==============================] - 4s 13ms/step - loss: 291810.6730
# Epoch 23/25
# 274/274 [==============================] - 4s 13ms/step - loss: 282805.8558
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 283107.7244
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 279348.8211
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545472 423.20580445230354 0.8864599839647027 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_3 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 52891.0321
# Epoch 2/25
# 274/274 [==============================] - 4s 13ms/step - loss: 51244.2312
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 49784.7370
# Epoch 4/25
# 274/274 [==============================] - 4s 13ms/step - loss: 48874.7524
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 47881.6712
# Epoch 6/25
# 274/274 [==============================] - 4s 13ms/step - loss: 47784.4821
# Epoch 7/25
# 274/274 [==============================] - 4s 13ms/step - loss: 46657.3164
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 45296.3412
# Epoch 9/25
# 274/274 [==============================] - 4s 13ms/step - loss: 44915.8737
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 43838.2356
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 43391.4653
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 41981.0844
# Epoch 13/25
# 274/274 [==============================] - 4s 13ms/step - loss: 40647.0305
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 41471.6527
# Epoch 15/25
# 274/274 [==============================] - 4s 13ms/step - loss: 38785.6146
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 37878.1626
# Epoch 17/25
# 274/274 [==============================] - 4s 14ms/step - loss: 37315.5611
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 37010.3916
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 35814.2541
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 36002.8149
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 34598.8298
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 33698.2702
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 32812.3363
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 32284.0162
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 31619.0995
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500068 106.21244028052624 0.5837783917197236 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_4 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_5 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 1703226.1623
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1626432.4327
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1675511.8450
# Epoch 4/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1617966.9945
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1626308.0841
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1622678.2286
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1603359.3477
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1638279.0077
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1639984.4377
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1636028.0059
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1605898.3245
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1588667.5300
# Epoch 13/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1583708.4291
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1570832.9109
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1583404.2595
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1567161.3023
# Epoch 17/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1541292.5068
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1552344.4809
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1573273.5650
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1532343.5055
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1550837.0832
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1527513.3827
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1535511.0509
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1535735.1827
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1534486.7064
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.0160150732597 1201.0521497735854 1.0033718301589127 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_6 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_7 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 8451.2265
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7851.1062
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7569.9963
# Epoch 4/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7228.9298
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6867.0512
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6400.7046
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6113.2040
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6114.7638
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5541.2912
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5308.5268
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5205.0076
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4875.5027
# Epoch 13/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4743.8841
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4508.7226
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4214.4947
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4121.1888
# Epoch 17/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3934.4000
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3701.1058
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3591.8617
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3402.4233
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3308.6029
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3218.4378
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3035.3606
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 2875.8696
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 2853.5484
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264219 48.21630377408165 0.5889251960845893 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_8 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_9 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 12894986.3491
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12615840.2218
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12543522.9164
# Epoch 4/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12870588.3636
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12908020.8218
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12638581.8000
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12724811.6727
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12513627.7964
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12818699.8582
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12788709.9927
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12791499.4982
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12512716.6836
# Epoch 13/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12547675.7382
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12414522.7091
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12696257.6291
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12503532.0436
# Epoch 17/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12439082.7127
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12482360.5891
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12452025.4618
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12296531.8327
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12339651.5055
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12350116.6218
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12412133.8400
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12506423.7782
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12412993.8036
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.4307034315702 3155.3157424620003 1.0025052303842092 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_10 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_11 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 13156.8197
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 11832.3312
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 11614.2974
# Epoch 4/25
# 274/274 [==============================] - 4s 14ms/step - loss: 10883.4165
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 10549.3634
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 9827.3655
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 9656.4791
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 9183.9056
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 8832.0152
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 8446.8285
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 8276.9612
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7819.3814
# Epoch 13/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7628.4973
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7358.1959
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7149.3287
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6907.9691
# Epoch 17/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6377.5095
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6527.8013
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 6099.3142
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5697.6745
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5599.9881
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5319.1318
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5087.8554
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4643.7514
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 4715.6314
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606884 54.11957640533431 0.5835948155398452 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_12 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_13 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 0.1416
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3355e-04
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3168e-04
# Epoch 4/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4099e-04
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3712e-04
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3483e-04
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3.3580e-04
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.2208e-04
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4201e-04
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4120e-04
# Epoch 11/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3752e-04
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3248e-04
# Epoch 13/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4058e-04
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.2815e-04
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4815e-04
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4123e-04
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3.4477e-04
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4819e-04
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4175e-04
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.5678e-04
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3.4579e-04
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.5442e-04
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3.4491e-04
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4959e-04
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.3936e-04
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135511 0.030933999176060923 0.2939621120567447 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_14 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_15 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 8s 14ms/step - loss: 15199.2997
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 14162.5700
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 13488.9727
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 13037.8834
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 12578.0971
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 12052.5140
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 11576.8929
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 11059.4313
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 10552.9934
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 10231.1535
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 9806.5653
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 9531.7896
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 8928.1105
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 8647.4890
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 8160.1118
# Epoch 16/25
# 274/274 [==============================] - 4s 14ms/step - loss: 7875.1617
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7525.8317
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7132.8976
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 6889.1634
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 6464.2979
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 6216.2939
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5836.2825
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5642.6352
# Epoch 24/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5480.8437
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5118.8747
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508708 71.44376518055668 0.586044641837417 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_16 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_17 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 14ms/step - loss: 85922.0172
# Epoch 2/25
# 274/274 [==============================] - 4s 14ms/step - loss: 82186.0327
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 81428.5398
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 79168.0109
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 78042.5315
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 77472.0047
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 75981.5643
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 75062.5632
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 72752.3706
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 72120.6307
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 71007.9404
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 70651.0921
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 68760.7039
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 67519.6720
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 67090.5809
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 64507.7916
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 63658.3586
# Epoch 18/25
# 274/274 [==============================] - 4s 14ms/step - loss: 62629.7906
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 61726.2361
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 60606.6424
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 59911.3042
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 58293.5171
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 57254.6584
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 56057.0667
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 54776.6343
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.95636354975403 334.8248104580538 0.9966318450415877 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_18 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_19 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 15ms/step - loss: 5343904.1436
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5309154.2927
# Epoch 3/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5405759.6291
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5357235.1400
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5398455.3618
# Epoch 6/25
# 274/274 [==============================] - 4s 14ms/step - loss: 5341981.4527
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5295195.3218
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5270546.2655
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5283517.9582
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5246743.2755
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5186466.8255
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5270716.0564
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5152614.9709
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5238634.9636
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5276551.3655
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5227059.3127
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5166259.8909
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5261940.2491
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5196498.1000
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5110916.1618
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5146001.0164
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5091447.5527
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5077724.7927
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5146907.9927
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5053001.4018
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358317 2186.8732713318245 1.0770871058787448 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_20 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_21 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 15ms/step - loss: 4377939.4055
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4298906.6418
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4350013.2909
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4371110.1091
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4271898.0873
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4317182.7891
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4301226.1636
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4277732.4418
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4232390.1545
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4212437.5618
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4200553.5364
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4350786.2945
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4220389.8100
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4180070.3582
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4127265.0455
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4196766.7736
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4210968.3018
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4183282.7645
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4111627.4473
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4254859.3473
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4092255.9082
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4209771.2427
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4159006.8082
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4154248.2836
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 4209320.3855
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547134 1646.8796642779173 1.0077093094473888 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_22 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_23 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 8s 15ms/step - loss: 598231.2845
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 584828.0026
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 591618.2511
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 586113.1551
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 597888.9441
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 590500.6668
# Epoch 7/25
# 274/274 [==============================] - 4s 16ms/step - loss: 587636.6242
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 586361.8443
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 571630.5025
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 578112.0700
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 566602.1936
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 559132.8868
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 564023.3561
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 562568.2220
# Epoch 15/25
# 274/274 [==============================] - 4s 16ms/step - loss: 549647.6935
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 562719.7249
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 544246.8878
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 528534.4295
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 541569.3595
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 519850.2673
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 522058.7544
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 520271.3695
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 526539.6083
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 528425.2278
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 518747.1859
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245861 776.6290425365721 1.0917970375802986 Eagle_education_Norah
# Building Eagle_education_Will
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_24 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_25 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 15ms/step - loss: 75845.1904
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 72769.2451
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 71591.4887
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 70584.2831
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 69603.6346
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 68594.6408
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 66416.9689
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 66279.2425
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 64910.3723
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 63709.9741
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 63164.4055
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 62049.6137
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 60094.0771
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 59343.0853
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 58341.0237
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 57539.0132
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 55843.9030
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 54541.0817
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 54195.1785
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 53039.7573
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 53012.1329
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 50595.8683
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 50034.4798
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 49324.8095
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 47865.7105
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769736 131.49863992086526 0.5816735396081569 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_26 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_27 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 15ms/step - loss: 4086.4388
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3521.1454
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3327.4119
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 3135.1076
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2890.3619
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2694.6212
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2536.5726
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2399.0118
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2210.3289
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2156.7888
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2063.1024
# Epoch 12/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1820.4191
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1803.2485
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1674.9701
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1609.5259
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1575.1609
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1511.4397
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1418.3846
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1409.0872
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1351.3591
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1349.0227
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1260.9860
# Epoch 23/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1275.4926
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1244.2792
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1231.5107
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.9627497750187 29.403591859596116 0.5161898253811337 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_28 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_29 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 8s 15ms/step - loss: 11094.5818
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 10444.9494
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 10395.0691
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 10121.2413
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 9768.1997
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 9534.1774
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 8880.1451
# Epoch 8/25
# 274/274 [==============================] - 4s 15ms/step - loss: 8649.9041
# Epoch 9/25
# 274/274 [==============================] - 4s 16ms/step - loss: 8191.0047
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7903.6628
# Epoch 11/25
# 274/274 [==============================] - 4s 16ms/step - loss: 7572.5663
# Epoch 12/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7433.3690
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7169.0534
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 6804.3060
# Epoch 15/25
# 274/274 [==============================] - 4s 16ms/step - loss: 6552.2679
# Epoch 16/25
# 274/274 [==============================] - 4s 16ms/step - loss: 6639.8356
# Epoch 17/25
# 274/274 [==============================] - 4s 16ms/step - loss: 6296.0270
# Epoch 18/25
# 274/274 [==============================] - 4s 16ms/step - loss: 6207.1922
# Epoch 19/25
# 274/274 [==============================] - 4s 16ms/step - loss: 6128.0367
# Epoch 20/25
# 274/274 [==============================] - 4s 16ms/step - loss: 5634.0887
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5277.8075
# Epoch 22/25
# 274/274 [==============================] - 4s 16ms/step - loss: 5327.3374
# Epoch 23/25
# 274/274 [==============================] - 4s 16ms/step - loss: 5283.4930
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 5359.6414
# Epoch 25/25
# 274/274 [==============================] - 4s 16ms/step - loss: 5079.6263
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551751 53.93323536450247 0.5913932093901342 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_30 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_31 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,729
# Trainable params: 1,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 8s 16ms/step - loss: 29523.9655
# Epoch 2/25
# 274/274 [==============================] - 4s 16ms/step - loss: 27105.6350
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 27277.2789
# Epoch 4/25
# 274/274 [==============================] - 4s 16ms/step - loss: 25926.5083
# Epoch 5/25
# 274/274 [==============================] - 4s 16ms/step - loss: 25354.1380
# Epoch 6/25
# 274/274 [==============================] - 4s 16ms/step - loss: 24387.1946
# Epoch 7/25
# 274/274 [==============================] - 4s 15ms/step - loss: 24881.5607
# Epoch 8/25
# 274/274 [==============================] - 4s 16ms/step - loss: 23485.5887
# Epoch 9/25
# 274/274 [==============================] - 4s 15ms/step - loss: 23583.6859
# Epoch 10/25
# 274/274 [==============================] - 4s 16ms/step - loss: 22695.2867
# Epoch 11/25
# 274/274 [==============================] - 4s 15ms/step - loss: 21584.2435
# Epoch 12/25
# 274/274 [==============================] - 4s 16ms/step - loss: 20765.4830
# Epoch 13/25
# 274/274 [==============================] - 4s 16ms/step - loss: 20410.8942
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 20194.3225
# Epoch 15/25
# 274/274 [==============================] - 4s 15ms/step - loss: 19722.5703
# Epoch 16/25
# 274/274 [==============================] - 4s 15ms/step - loss: 19104.2937
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 18660.9107
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 17961.4565
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 17681.3003
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 17135.1481
# Epoch 21/25
# 274/274 [==============================] - 5s 16ms/step - loss: 16823.4840
# Epoch 22/25
# 274/274 [==============================] - 4s 16ms/step - loss: 16141.1109
# Epoch 23/25
# 274/274 [==============================] - 4s 16ms/step - loss: 15624.7518
# Epoch 24/25
# 274/274 [==============================] - 4s 16ms/step - loss: 15263.8381
# Epoch 25/25
# 274/274 [==============================] - 4s 16ms/step - loss: 14540.9881
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033783 94.86607498505273 0.6387970732441669 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36    2186.87  1.08   Eagle_education_Sherrill
# -0.8545    1634.28    1646.88  1.01   Eagle_education_Brooke
# -0.8502    3147.43    3155.32  1.00   Eagle_education_Peter
# -0.8403     477.41     423.21  0.89   Eagle_health_Athena
# -0.8186    1197.02    1201.05  1.00   Eagle_education_Roman
# -0.7988      56.96      29.40  0.52   Eagle_education_Petra
# -0.7961     121.91      71.44  0.59   Eagle_health_Vincenza
# -0.7722     711.33     776.63  1.09   Eagle_education_Norah
# -0.7596     181.94     106.21  0.58   Eagle_public_Alvin
# -0.7222      81.87      48.22  0.59   Eagle_lodging_Edgardo
# -0.7130      92.73      54.12  0.58   Eagle_lodging_Dawn
# -0.6796     148.51      94.87  0.64   Eagle_education_Teresa
# -0.6741      91.20      53.93  0.59   Eagle_lodging_Trina
# -0.5553     335.96     334.82  1.00   Eagle_office_Francis
# -0.3579     226.07     131.50  0.58   Eagle_education_Will
#  0.7231       0.11       0.03  0.29   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Results on all buildings.
#
# * 0.00 mean RMSE
# * 0.00 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.00 mean RMSE
# * 0.00 stddev
