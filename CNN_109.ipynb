# %% [markdown]
# # CNN
# Include current weather as a predictor.
#
# Previous notebooks used weather 0-23 to predict steam 24. Here, use weather 0-24 to predict steam 24. Thus, use 25 hours of weather thru current as predictor of current steam.
#
# Compare to CNN 108. Both use no smoothing. The only difference is the extra information in the predictor: current weather. The extra information did not help.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 25   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=5
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:25], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY-1:x0+STEPS_FUTURE-1]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1104)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 97009.1550
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 46495.5989
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 43982.4658
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 45841.9384
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 42317.6322
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.7016806144551 194.23872943654288 0.40661094008858983 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 19754.2335
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 13171.8783
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 13196.0170
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 12446.9040
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 12710.5917
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830828 63.20052581347719 0.3470974657994782 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 402983.9072
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 187131.7088
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 172740.7319
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 163636.3183
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 169158.7305
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121295 370.9583422391148 0.30969043435284455 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 6607.2906
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4831.1057
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4943.4159
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4795.3933
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 4729.0144
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.96779195736434 69.35688253195475 0.846147991494401 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 3s 5ms/step - loss: 4014537.6900
# Epoch 2/5
# 274/274 [==============================] - 1s 5ms/step - loss: 1065844.3477
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 846219.3257
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 846627.8223
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 819571.1468
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.688883128135 900.6242693886023 0.28594070805308913 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 31236.0414
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 4040.1210
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 3570.6529
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 3553.3641
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 3501.4109
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815779 62.231346388385454 0.6704009537080349 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 1917.9333
# Epoch 2/5
# 274/274 [==============================] - 1s 5ms/step - loss: 72.1335: 1s - loss
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 20.1867
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 8.7416
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 4.0432
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.1051845132238942 1.2038134338706952 11.444778294579123 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 5456.7739
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3373.1849
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 3211.4495
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 3176.0179
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3151.4328
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534426 53.32162903247483 0.43724417049844916 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 5ms/step - loss: 11490.3521
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 9010.5155
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 8493.4598
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8335.7963
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 7840.3674
# cor,mean,rmse,rmse/mean,bldg: -0.4515947035800076 336.3595254616963 154.15385565841697 0.45830084772185703 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 3ms/step - loss: 1832934.7632
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 557604.4873
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 491952.8555
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 471021.1955
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 473549.5223
# cor,mean,rmse,rmse/mean,bldg: -0.8130507458567988 2032.6741548164612 611.6339767354726 0.3009011431006755 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 1971788.2768
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1277543.2914
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1207562.3027
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1135860.8568
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1180895.2539
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1371.3827990783711 0.8385991539388853 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 214325.0362
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 103006.9559
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 98669.9241
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 99086.1229
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 98887.9626
# cor,mean,rmse,rmse/mean,bldg: -0.6928377753347054 712.0697702804378 303.4308085183771 0.4261251090590119 Eagle_education_Norah
# Building Eagle_education_Will
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 12708.5303
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 9589.0349
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 9908.7737
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 9373.0911
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 9877.3575
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.2548535624715 81.89916727110104 0.3619775044891479 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 4413.4875
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 847.0664
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 767.6760
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 762.8510
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 741.2185
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819881 36.78163342077231 0.6447241444250286 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 7964.9259
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6481.0637
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 6078.6161
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 5867.3866
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 5980.7594
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157318 76.94486838511563 0.842951035572317 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 18987.0995
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 5857.3946
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 5581.4524
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 5101.4043
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 5238.4292
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.5078192772458 79.05912007753308 0.5323566157142167 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 25 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     611.63  0.30   Eagle_education_Sherrill
# -0.8011    3149.69     900.62  0.29   Eagle_education_Peter
# -0.7147     477.70     194.24  0.41   Eagle_health_Athena
# -0.6972    1197.84     370.96  0.31   Eagle_education_Roman
# -0.6928     712.07     303.43  0.43   Eagle_education_Norah
# -0.6191      57.05      36.78  0.64   Eagle_education_Petra
# -0.5975    1635.33    1371.38  0.84   Eagle_education_Brooke
# -0.5645     182.08      63.20  0.35   Eagle_public_Alvin
# -0.5301     148.51      79.06  0.53   Eagle_education_Teresa
# -0.5294      92.83      62.23  0.67   Eagle_lodging_Dawn
# -0.4636     121.95      53.32  0.44   Eagle_health_Vincenza
# -0.4516     336.36     154.15  0.46   Eagle_office_Francis
# -0.4243      91.28      76.94  0.84   Eagle_lodging_Trina
# -0.4210      81.97      69.36  0.85   Eagle_lodging_Edgardo
# -0.3226     226.25      81.90  0.36   Eagle_education_Will
#  0.4372       0.11       1.20 11.44   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 1.20 mean RMSE
# * 2.74 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.51 mean RMSE
# * 0.20 stddev
