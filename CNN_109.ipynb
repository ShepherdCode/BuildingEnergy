# %% [markdown]
# # CNN
# Include current weather as a predictor.
#
# Previous notebooks used weather 0-23 to predict steam 24. Here, use weather 0-24 to predict steam 24. Thus, use 25 hours of weather thru current as predictor of current steam.
#
# Compare to CNN 108. Both use no smoothing. The only difference is the extra information in the predictor: current weather. The extra information did not help.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 25   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=25
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:25], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY-1:x0+STEPS_FUTURE-1]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1104)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 69282.4563
# Epoch 2/25
# 274/274 [==============================] - 1s 5ms/step - loss: 44973.2351
# Epoch 3/25
# 274/274 [==============================] - 1s 5ms/step - loss: 45619.2332
# Epoch 4/25
# 274/274 [==============================] - 1s 5ms/step - loss: 43471.6928
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 42910.2367
# Epoch 6/25
# 274/274 [==============================] - 1s 5ms/step - loss: 44487.4869A: 0s -
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 41865.2077
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 43188.3464
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 44406.7158
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 44578.1842
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42017.1172A: 0s - loss: 4
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42145.2032
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 41381.8668
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 43048.2305
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 42158.8502
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 42453.8550
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 42407.4368
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 42380.8072A: 0s -
# Epoch 19/25
# 274/274 [==============================] - 1s 5ms/step - loss: 42594.1377
# Epoch 20/25
# 274/274 [==============================] - 1s 4ms/step - loss: 40625.4628
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 40114.3213
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 42078.4829
# Epoch 23/25
# 274/274 [==============================] - 1s 5ms/step - loss: 42239.8519
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 41124.4585
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 40808.4834
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.7016806144551 190.21232673294838 0.39818224312772627 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 17038.9544
# Epoch 2/25
# 274/274 [==============================] - 1s 5ms/step - loss: 13525.7974
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 13314.3153
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12861.1121
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 13425.3015
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12556.2946
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12901.4895
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12528.3527
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12105.8698
# Epoch 10/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11965.2403
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12433.7543
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 11881.4319
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12287.6494
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12289.8889A: 1
# Epoch 15/25
# 274/274 [==============================] - 1s 5ms/step - loss: 11520.7851
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12067.0143
# Epoch 17/25
# 274/274 [==============================] - 2s 5ms/step - loss: 12175.2238
# Epoch 18/25
# 274/274 [==============================] - 1s 5ms/step - loss: 12160.6315
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12358.8209
# Epoch 20/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11981.6457
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12575.3397
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12508.8787
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11762.9396
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12248.2086
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 12200.2845
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830828 86.43623633093101 0.4747080534148532 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 545436.9167
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 184313.8854
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 166054.7834
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 164924.8963
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 167456.0258
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 172299.4816
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 162778.5271
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 158646.3691
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 156843.4441
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 163737.3018
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 165053.6013
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 161066.1489
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 159196.4295
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 158245.0739
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 161960.0798
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 163231.1645
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 159364.2262
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 163426.4985
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 148721.4070
# Epoch 20/25
# 274/274 [==============================] - 1s 4ms/step - loss: 153465.8949
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 157968.2521
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 155129.8188
# Epoch 23/25
# 274/274 [==============================] - 1s 5ms/step - loss: 156424.6110
# Epoch 24/25
# 274/274 [==============================] - 1s 5ms/step - loss: 152461.9836
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 158163.6903
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121295 367.8053430383857 0.307058188138636 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 6424.1752
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 5212.9179
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4956.9371
# Epoch 4/25
# 274/274 [==============================] - 1s 5ms/step - loss: 4942.2817
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4621.9183
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4741.5570
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4559.0003
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4854.8605
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4977.8028
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4667.6672
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4362.7342
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4562.6425
# Epoch 13/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4914.1724
# Epoch 14/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4639.1165
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4351.0314
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4243.9603
# Epoch 17/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4754.5808
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4576.5650
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4436.0797
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 4627.9493
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4779.5526
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4782.3922
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4401.6892
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4380.2291
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4548.0402
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.96779195736434 69.60853831401869 0.8492181703543468 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2958965.4168
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1021488.9245
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 853077.9841
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 844052.2375
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 869926.3382
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 811765.9786
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 815154.1464
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 797251.1386
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 779404.0907
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 736304.1675
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 793852.7373
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 799919.7805
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 777289.5584
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 745456.8686
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 768750.8241
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 754602.5152
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 779627.4300
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 744593.9970
# Epoch 19/25
# 274/274 [==============================] - 1s 5ms/step - loss: 756538.1055
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 731237.6995
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 760319.5130
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 756233.4435
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 766861.6245
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 739405.9164
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 722621.3213
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.688883128135 931.9288892635892 0.29587966426005785 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 3ms/step - loss: 34379.6704
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4052.7368
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3884.2294
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3580.8862
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3290.0427
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3276.3451
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3735.2751
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3523.0302
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3201.9238
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3499.4274
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3448.4894
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3599.2778
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3605.8930
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3492.5807
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3589.7007
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3417.7308
# Epoch 17/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3310.1299
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3646.4415
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3136.9660
# Epoch 20/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3429.7641
# Epoch 21/25
# 274/274 [==============================] - 1s 5ms/step - loss: 3422.6763
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3181.4749
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3341.1047
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3365.6909
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3532.0473: 0s
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815779 58.975904562176495 0.6353309860520108 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 4ms/step - loss: 4659.4143
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 117.2593
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12.2985
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2.1923
# Epoch 5/25
# 274/274 [==============================] - 1s 5ms/step - loss: 0.7814
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 0.3987
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 0.2406
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 0.1438
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 0.1394
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 0.1193
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 0.1576
# Epoch 12/25
# 274/274 [==============================] - 1s 5ms/step - loss: 0.2980
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1.1750
# Epoch 14/25
# 274/274 [==============================] - 1s 5ms/step - loss: 6.8843
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4.1821A:
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9.5356
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 10.2119
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 5.4361
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2.3807
# Epoch 20/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7.2894
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3.8560
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3.2570
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 5.0412
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 0.9873
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10.5769
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.1051845132238942 1.366912848379664 12.995381225656988 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 27178.3457
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3572.0250
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3209.7235
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3094.6641
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2869.4167
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2902.8605
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2892.7002
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3031.5081
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2877.8789
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2812.2920
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2744.8099
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2594.1127
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2799.1088
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2698.1372
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2682.1256
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2666.2959
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2778.5882
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2722.5690
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2591.0737
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2581.8158
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2587.8495
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2672.0635
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2494.1875
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2502.4517
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2545.8136
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534426 50.40759901089117 0.4133487520216632 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 26505.8782
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9491.8207
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7918.4270
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7863.2152
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8794.6378
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8277.8561
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7363.2362
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8417.6793
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7593.6756
# Epoch 10/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9059.8439
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7627.7141
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8192.5134
# Epoch 13/25
# 274/274 [==============================] - 1s 5ms/step - loss: 7447.5155
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7703.2778
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8435.3771
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7346.4473
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8514.2656
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10443.4136
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7869.7858
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10543.6032
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7741.7772
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7064.7988
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7441.4353
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7584.3143
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10066.0317A: 0s - loss: 117
# cor,mean,rmse,rmse/mean,bldg: -0.4515947035800076 336.3595254616963 146.34654127966112 0.4350896294040784 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1104)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1548755.6782
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 558581.3680
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 507398.1431
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 464690.7966
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 489775.4145
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 448118.1785
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 469290.3415
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 445338.5485
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 459589.0540
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 427796.1930
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 405464.7153
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 423621.3761
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 400851.9302
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 416700.9901
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 410391.9983: 0s -
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 412215.8422
# Epoch 17/25
# 274/274 [==============================] - 1s 4ms/step - loss: 404903.4359
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 417169.1556
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 406143.3909
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 404743.7436
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 387744.3074
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 412235.1786
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 393674.6230
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 398838.4358
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 402023.9416
# cor,mean,rmse,rmse/mean,bldg: -0.8130507458567988 2032.6741548164612 604.737735637431 0.2975084492536559 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 2011636.9773
# Epoch 2/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1278013.2568
# Epoch 3/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1246686.2527
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1200321.3018
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1192076.5359
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1234811.4564
# Epoch 7/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1171331.3311
# Epoch 8/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1144407.2652
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1168403.9195
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1178695.0818
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1173260.7314
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1179685.6855
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1170648.0516
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1135750.3395
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1153777.8700
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1170806.1023
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1139950.0066
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1147029.4084
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1132377.3636
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1131948.9059
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1125376.8484
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1170279.9809
# Epoch 23/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1151126.3814
# Epoch 24/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1158521.5930
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1159983.8341
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1236.7066725735365 0.756244842787673 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 197301.0960
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 107292.2785
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 106488.6759
# Epoch 4/25
# 274/274 [==============================] - 1s 5ms/step - loss: 98396.3990
# Epoch 5/25
# 274/274 [==============================] - 1s 5ms/step - loss: 94023.7599
# Epoch 6/25
# 274/274 [==============================] - 1s 5ms/step - loss: 98450.0114
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 97694.9755
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 95519.7775
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 97565.1235
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 91692.7811
# Epoch 11/25
# 274/274 [==============================] - 1s 5ms/step - loss: 93258.0104
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 95419.3611
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 92949.0947
# Epoch 14/25
# 274/274 [==============================] - 1s 5ms/step - loss: 91204.0551
# Epoch 15/25
# 274/274 [==============================] - 1s 5ms/step - loss: 94590.2842
# Epoch 16/25
# 274/274 [==============================] - 1s 5ms/step - loss: 89080.6293
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 92415.3153
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 92657.3239
# Epoch 19/25
# 274/274 [==============================] - 1s 5ms/step - loss: 92309.3507
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 89341.0823
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 89565.6460
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 92647.8236
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 89441.2017
# Epoch 24/25
# 274/274 [==============================] - 1s 5ms/step - loss: 91907.4234
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 88586.0296
# cor,mean,rmse,rmse/mean,bldg: -0.6928377753347054 712.0697702804378 291.507045967849 0.409379892440938 Eagle_education_Norah
# Building Eagle_education_Will
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 16582.1454
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10340.4099
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10530.1147
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9944.8506
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10478.7474
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9609.1340
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9399.8773
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8993.7456
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10083.6463
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9161.2267
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9524.0862
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9801.2929
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9225.2083
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9366.9344
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9488.9646: 0s - los
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9700.9371
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9502.5890
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10200.7744
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9395.6924
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9826.7630
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8851.0401
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9661.1741
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9483.6433
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9313.4643
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9379.0295
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.2548535624715 91.03603070217038 0.4023605649504191 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5073.3185
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 925.4356
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 759.6530
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 722.0624
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 762.7301
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 784.5751
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 728.7613
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 724.1896
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 815.6528
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 736.9779
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 676.8200
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 741.7584
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 752.0742
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 726.3487
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 719.0932
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 786.2882
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 709.7871
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 721.7997
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 702.2763
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 704.6058
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 674.9157
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 674.7891
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 685.8467
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 688.6017
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 708.3995
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819881 38.09140445127002 0.6676823691827533 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 23928.2231
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 6116.2309
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5966.0294
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 6008.2727
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5957.5092
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 6180.5311
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5493.6007
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5819.2143
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 6237.3683
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5978.3278
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5902.7252
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5818.7806
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5793.3822
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5801.5972
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5790.2227
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5687.9923
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5690.7628
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5888.9537
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5632.5714
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5890.4049
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5678.8292
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5372.6570
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5610.3788
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5728.8932
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5484.1333
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157318 79.3438391894007 0.8692323843642662 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_CNN
# input shape: (25, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 23, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1104)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1105
# =================================================================
# Total params: 1,185
# Trainable params: 1,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 25, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 30148.8275
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5768.8746
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5326.2908
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5374.2144
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5512.5245
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4968.3388
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5094.4746
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5162.7289
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5169.7535
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4899.5580
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4739.3881
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4997.4846
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5107.1106
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4780.7333
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4829.9256
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4876.9320
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4990.8753
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4708.5783
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5066.8428
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4908.4288
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4852.5295
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4810.3764
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4815.6204
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4925.3554
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4983.5929
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.5078192772458 71.15333302910787 0.4791217955754462 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 25 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     604.74  0.30   Eagle_education_Sherrill
# -0.8011    3149.69     931.93  0.30   Eagle_education_Peter
# -0.7147     477.70     190.21  0.40   Eagle_health_Athena
# -0.6972    1197.84     367.81  0.31   Eagle_education_Roman
# -0.6928     712.07     291.51  0.41   Eagle_education_Norah
# -0.6191      57.05      38.09  0.67   Eagle_education_Petra
# -0.5975    1635.33    1236.71  0.76   Eagle_education_Brooke
# -0.5645     182.08      86.44  0.47   Eagle_public_Alvin
# -0.5301     148.51      71.15  0.48   Eagle_education_Teresa
# -0.5294      92.83      58.98  0.64   Eagle_lodging_Dawn
# -0.4636     121.95      50.41  0.41   Eagle_health_Vincenza
# -0.4516     336.36     146.35  0.44   Eagle_office_Francis
# -0.4243      91.28      79.34  0.87   Eagle_lodging_Trina
# -0.4210      81.97      69.61  0.85   Eagle_lodging_Edgardo
# -0.3226     226.25      91.04  0.40   Eagle_education_Will
#  0.4372       0.11       1.37 13.00   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 1.20 mean RMSE
# * 2.74 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.51 mean RMSE
# * 0.20 stddev
