# %% [markdown]
# # LSTM
# Here, use 8 weather features.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %%
SITE = 'Eagle'
METER = 'steam'
BLDG = 'Eagle_education_Peter'   # one example
PREDICTOR_VARIABLE = 'dewTemperature'  # for starters
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)
PREDICTED_VARIABLE = 'steam'  # for starters
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
DOWNSAMPLE = False   # if true, use 1 time per day, else 24 times per day
STEPS_HISTORY = 24 
STEPS_FUTURE =  1    
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                X[x0,x1,x2] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
num_predictors = len(PREDICTORS)  # e.g. 8 weather features
def make_RNN():
    rnn = Sequential([
        SimpleRNN(20,return_sequences=True, 
                  input_shape=(STEPS_HISTORY,num_predictors)), 
        SimpleRNN(10,return_sequences=False),
        Dense(STEPS_FUTURE)   
    ])
    rnn.compile(optimizer='adam',loss=MeanSquaredError())
    return rnn

# %%
cors = []
EPOCHS=5
# Test on only Peter just during code development
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        print("Train on",len(X_train),"samples such as",X_train[100][0])
        print("Predict",len(y_train),"labels such as",y_train[100])

        model = make_RNN()
        print(model.summary())
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        # Compare. Solve the problem that predict.shape != truth.shape 
        ##print(" before ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        #nsamples, nsteps, ndim = y_test.shape
        #y_test = y_test.reshape(nsamples,nsteps*ndim)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        ##print(" after ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][PREDICTOR_VARIABLE] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)

        ## break   ## REMOVE THIS LINE TO LOOP OVER BUILDINGS!
        
if True:
    print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
    print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",PREDICTOR_VARIABLE)
    print("          Using one weather feature as leading correlate.")
    print("Column 2: Mean usage.")
    print("          Using mean to help understand the RMSE.")
    print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
    print("Column 4: RMSE/mean normalized to help understand RMSE.")
    print("Column 5: Building.")
    for cor in sorted(cors):
        print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [856.91]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 343212.4410
# Epoch 2/5
# 274/274 [==============================] - 2s 8ms/step - loss: 338420.2477
# Epoch 3/5
# 274/274 [==============================] - 2s 8ms/step - loss: 329893.3775
# Epoch 4/5
# 274/274 [==============================] - 2s 8ms/step - loss: 328142.5318
# Epoch 5/5
# 274/274 [==============================] - 2s 8ms/step - loss: 322646.7049
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545472 461.59704474830545 0.9668754647996647 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [424.34]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 52744.8578
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 49180.1777
# Epoch 3/5
# 274/274 [==============================] - 2s 8ms/step - loss: 48799.6512
# Epoch 4/5
# 274/274 [==============================] - 2s 8ms/step - loss: 46928.9774
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 46283.4551
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500068 144.74711281828104 0.795577584922718 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [2374.16]
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 1652062.1973
# Epoch 2/5
# 274/274 [==============================] - 2s 8ms/step - loss: 1658268.3677
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 1641393.7900
# Epoch 4/5
# 274/274 [==============================] - 2s 8ms/step - loss: 1641371.2491
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 1625742.4464
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.0160150732597 1243.6286118502132 1.038940662606006 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [207.79]
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_6 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_7 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 8550.4566
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 7786.8411
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 7405.2216
# Epoch 4/5
# 274/274 [==============================] - 2s 8ms/step - loss: 6833.9567
# Epoch 5/5
# 274/274 [==============================] - 2s 8ms/step - loss: 6392.7324
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264219 75.87412484277583 0.9267442826008998 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [6895.45]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_8 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_9 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 8ms/step - loss: 12529663.8800
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 12866917.2582
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 12783033.9345
# Epoch 4/5
# 274/274 [==============================] - 2s 8ms/step - loss: 12919779.9273
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 12898117.2000
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.4307034315702 3198.284769472668 1.0161573266682735 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [256.52]
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_10 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 13082.0160
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 11871.4755
# Epoch 3/5
# 274/274 [==============================] - 3s 9ms/step - loss: 11202.7895
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 10823.4180
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 10372.0852
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606884 81.33950013078486 0.8771190339592122 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [0.08]
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_12 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_13 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 0.1431
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 3.7727e-04
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 3.5070e-04
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 3.6927e-04
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 3.5025e-04
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135511 0.02839119149078996 0.26979811329725556 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [201.49]
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_14 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_15 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 15348.2581
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 14298.1244
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 13705.5671
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 13080.3829
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 12574.0860
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508708 112.32565887042291 0.921393915277352 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [412.35]
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_16 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_17 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 86544.4925
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 82727.6369
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 81222.5531
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 79638.6488
# Epoch 5/5
# 274/274 [==============================] - 3s 9ms/step - loss: 77763.8284
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.95636354975403 379.5813880010431 1.1298532463869473 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [3984.16]
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_18 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_19 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 5339970.4945
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 5371611.5200
# Epoch 3/5
# 274/274 [==============================] - 3s 9ms/step - loss: 5271459.6509
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 5282710.2364
# Epoch 5/5
# 274/274 [==============================] - 3s 9ms/step - loss: 5424745.9327
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358317 2229.624337260795 1.0981430227799667 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [3581.43]
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_20 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_21 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 4393516.0509
# Epoch 2/5
# 274/274 [==============================] - 3s 10ms/step - loss: 4276206.3855
# Epoch 3/5
# 274/274 [==============================] - 3s 10ms/step - loss: 4267619.0091
# Epoch 4/5
# 274/274 [==============================] - 3s 9ms/step - loss: 4347282.2409
# Epoch 5/5
# 274/274 [==============================] - 3s 10ms/step - loss: 4273306.7027
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547134 1684.2752911348641 1.030591322100626 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [1543.14]
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_22 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_23 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 602025.6791
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 596629.0252
# Epoch 3/5
# 274/274 [==============================] - 3s 9ms/step - loss: 600433.6359
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 583904.8488
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 587655.2135
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245861 816.6373134143131 1.148041279336131 Eagle_education_Norah
# Building Eagle_education_Will
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [297.45]
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_24 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_25 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 76739.6531
# Epoch 2/5
# 274/274 [==============================] - 3s 9ms/step - loss: 73031.6479
# Epoch 3/5
# 274/274 [==============================] - 3s 9ms/step - loss: 71750.6784
# Epoch 4/5
# 274/274 [==============================] - 3s 9ms/step - loss: 69570.1577
# Epoch 5/5
# 274/274 [==============================] - 2s 9ms/step - loss: 68234.2804
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769736 174.92348305521526 0.7737598017024799 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [135.07]
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_26 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_27 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 4132.9757
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 3555.6814
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 3381.8915
# Epoch 4/5
# 274/274 [==============================] - 2s 8ms/step - loss: 3177.7225
# Epoch 5/5
# 274/274 [==============================] - 2s 8ms/step - loss: 2769.0380
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.9627497750187 48.350573120500975 0.8488103771581856 Eagle_education_Petra
# Building Eagle_lodging_Trina
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [304.34]
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_28 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_29 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 11160.7941
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 10814.7350
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 10035.9129
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 9603.8444
# Epoch 5/5
# 274/274 [==============================] - 3s 9ms/step - loss: 9101.0269
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551751 85.22068662691078 0.9344689787308956 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [234.44]
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_30 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_31 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 274/274 [==============================] - 4s 9ms/step - loss: 28731.9869
# Epoch 2/5
# 274/274 [==============================] - 2s 9ms/step - loss: 27512.7166
# Epoch 3/5
# 274/274 [==============================] - 2s 9ms/step - loss: 26568.5672
# Epoch 4/5
# 274/274 [==============================] - 2s 9ms/step - loss: 25740.1003
# Epoch 5/5
# 274/274 [==============================] - 3s 9ms/step - loss: 25636.0219
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033783 135.14054446015803 0.9099921578011323 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36    2229.62  1.10   Eagle_education_Sherrill
# -0.8545    1634.28    1684.28  1.03   Eagle_education_Brooke
# -0.8502    3147.43    3198.28  1.02   Eagle_education_Peter
# -0.8403     477.41     461.60  0.97   Eagle_health_Athena
# -0.8186    1197.02    1243.63  1.04   Eagle_education_Roman
# -0.7988      56.96      48.35  0.85   Eagle_education_Petra
# -0.7961     121.91     112.33  0.92   Eagle_health_Vincenza
# -0.7722     711.33     816.64  1.15   Eagle_education_Norah
# -0.7596     181.94     144.75  0.80   Eagle_public_Alvin
# -0.7222      81.87      75.87  0.93   Eagle_lodging_Edgardo
# -0.7130      92.73      81.34  0.88   Eagle_lodging_Dawn
# -0.6796     148.51     135.14  0.91   Eagle_education_Teresa
# -0.6741      91.20      85.22  0.93   Eagle_lodging_Trina
# -0.5553     335.96     379.58  1.13   Eagle_office_Francis
# -0.3579     226.07     174.92  0.77   Eagle_education_Will
#  0.7231       0.11       0.03  0.27   Eagle_education_Wesley
