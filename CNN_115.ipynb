# %% [markdown]
# # CNN
# No smoothing. Use 24 hr to predict 24 hr.
#
# Compare to CNN 108 which predicted 1 hr.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24   # length of the predicted sequence

## CNN parameters
EPOCHS=25
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:24], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 81531.5836
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 43128.7648
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41854.4332
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42340.1744
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40965.6575
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41821.8050
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41480.2306
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40621.8989
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41381.7524
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40898.6342
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40261.2469
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40432.0635
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39676.8947
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40094.5955
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40722.2786
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39887.6041
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40237.9366
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39568.2824
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39999.1079
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39534.5509
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40040.5268
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39324.8009
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39472.4001
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39993.0671
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39526.9246
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.70168061445776 199.77267519383597 0.4181954623581657 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 22099.4525
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12901.6357
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12275.3185
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12361.8898
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12214.6641
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12114.9940
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12511.8066
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12123.2892
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12063.4318
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12129.8525
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12336.1282
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12015.7848
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11941.7445
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11885.0440
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11844.7268
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11959.9246
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12032.3676
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12016.3402
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11950.1778
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12107.0654
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11873.5194
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11842.9249
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11930.3828
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11763.9243
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11705.4825
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830808 78.96844096799698 0.43369490024531543 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 415698.4333
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 159862.9610
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 157067.1752
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 157573.5349
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 156193.1542
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 158638.2021
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 153748.3143
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 156830.5878
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 149607.1501
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 154726.1978
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 151190.2472
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 154260.7180
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 147531.1301
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 151394.8304
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 148634.3755
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 151317.3820
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 156574.9718
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 148584.2786
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 147859.9084
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 145715.8414
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 148230.0939
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 149102.3684
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 144916.8034
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 147716.4899
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 147543.2083
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121304 365.754023294004 0.3053456667304378 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8277.8123
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4820.7588
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4677.4298
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4603.0892
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4621.9422
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4541.7695
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4546.0687
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4462.9864
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4444.6081
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4462.0522
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4556.8099
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4605.1851
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4511.6137
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4515.9555
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4504.2193
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4489.9030
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4452.9285
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4458.2883
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4527.0740
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4443.0229
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4433.4678
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4524.9877
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4425.1202
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4415.2166
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4484.5258
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.9677919573641 68.66542679163645 0.8377122910344232 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3556461.9768
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 928311.5177
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 725896.0077
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 700337.9818
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 692764.3314
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 693219.4159
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 706122.6918
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 686001.3251
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 704363.0114
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 692847.7373
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 696963.7627
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 681022.8405
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 679983.3598
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 689649.5730
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 688841.5093
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 668046.7184
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 679925.0657
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 663637.9050
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 666681.1723
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 659335.3264
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 679706.7016
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 675243.1189
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 649037.4066
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 657228.1782
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 672552.1080
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.6888831281212 834.2018821555033 0.264852153056785 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8273.1209
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3547.3051
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3422.2870
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3326.5691
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3278.0290
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3314.8791
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3236.5198
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3186.8099
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3268.6159
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3268.6473
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3243.9224
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3156.4997
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3199.4592
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3175.1707
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3219.5303
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3192.4285
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3239.3935
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3216.2040
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3132.0211
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3197.2536
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3213.2298
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3169.2994
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3199.5097
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3201.0112
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3240.1726
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815749 62.24962770761517 0.6705978932659594 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5876.4138
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 191.2858
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 47.6361
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 14.7981
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5.8045
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.4141
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.2294
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 0.7386
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 0.5457
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.2427
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.9892
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.9740
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.8093
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.6459
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.1388
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.6681
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.5444
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.9620
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.3378
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4.4126
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.3344
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.7433
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.1460
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.7515
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.9092
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.10518451322389408 2.9231620368849374 27.7908025363272 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 6556.9409
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3173.3311
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3002.1254
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2868.4288
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2842.7179
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2746.7568
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2696.7668
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2633.3875
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2629.6925
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2563.6486
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2574.3481
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2534.4550
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2486.3635
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2467.4660
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2444.6278
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2404.2903
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2369.1717
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2374.3921
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2357.7984
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2365.8853
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2326.8415
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2363.6859
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2346.3940
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2344.0330
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2348.1202
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534436 50.45474921204432 0.41373538969508217 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 21502.8182
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9095.4476
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8368.6920
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8433.7642
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8040.0075
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8146.4533
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7943.2244
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7615.5328
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7668.9678
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7569.4653
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7523.6296
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7427.0615
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7750.4429
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7631.8545
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7892.7130
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7881.9040
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7422.5474
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7725.8050
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7830.1322
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7420.9937
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7529.5943
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7645.1078
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7545.9150
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7539.6092
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7473.8144
# cor,mean,rmse,rmse/mean,bldg: -0.4515947035800076 336.35952546169125 136.16481531168364 0.4048192633307534 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1739011.3323
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 486236.2117
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 419496.4461
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 410639.8115
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 392021.8985
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 378633.8377
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 382865.7272
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 368934.4786
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 374214.2272
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 359486.2665
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 348788.8223
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 345810.3258
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 350807.0904
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 355665.4163
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 370752.5682
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 353252.7699
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 342817.8382
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 347371.3833
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 345814.7464
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 347384.3965
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 355602.6866
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 345248.2227
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 340712.9718
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 345340.9672
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 351091.2830
# cor,mean,rmse,rmse/mean,bldg: -0.8130507458567988 2032.6741548164603 553.7314695501536 0.2724152654954934 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2071228.1159
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1179259.3055
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1157311.9468
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1143592.8500
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1127249.7732
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1141663.0450
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1130882.9091
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1116543.2300
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1109561.4186
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1115166.8159
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1099324.0643
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1117808.4132
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1103768.2059
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1091529.5173
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1114631.6305
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1108312.8470
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1105434.7814
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1107767.7918
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1103679.2818
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1098980.3711
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1089661.6173
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1090934.6477
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1090179.2636
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1106374.1195
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1099097.8768
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1152.7585407031327 0.704910647544316 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 190666.4387
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 98267.6056
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 98575.2468
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 94202.7547
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 93649.8987
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 88573.0049
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 88086.9194
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 83821.1111
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87083.8198
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 91050.7709
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 89095.1190
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87235.0140
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87544.8597
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87292.8613
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87150.7408
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 86380.5429
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87394.7374
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87930.2578
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84740.9297
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87665.6687
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84601.7000
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84093.0790
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 86982.6088
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 83390.1297
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 86726.9215
# cor,mean,rmse,rmse/mean,bldg: -0.6928377753347054 712.0697702804412 287.1243315790273 0.4032249978340555 Eagle_education_Norah
# Building Eagle_education_Will
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 18327.6016
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9850.8370
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9597.7282
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 10074.5155
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9621.3074
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9416.1076
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9343.1032
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9105.2214
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9495.6381
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9303.6920
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9052.5489
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9202.0740
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9077.3500
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9064.9779
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9441.1088
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9271.3841
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8929.0875
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9245.3885
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9462.1995
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9652.3650
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9054.4102
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8879.8339
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9007.8655
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9085.5278
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9536.7970
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.25485356247063 93.78085917498788 0.414492143255147 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7856.0973
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 831.8435
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 732.8789
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 694.1524
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 677.7893
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 683.1813
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 658.3692
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 678.7788
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 670.1431
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 667.0326
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 669.5524
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 684.1338
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 683.2407
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 639.0141
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 648.6800
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 668.8802
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 643.9647
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 637.5664
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 650.2261
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 655.0742
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 635.4027
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 644.1326
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 653.8776
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 641.6444
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 644.1492
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819895 35.63898981672332 0.624695400416416 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12215.6265
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 6331.1374
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 6134.2297
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5898.4457
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5888.4984
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5739.3835
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5796.8879
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5745.5900
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5626.4110
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5685.9087
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5769.7222
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5736.8765
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5755.8980
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5585.6908
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5547.0067
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5614.0677
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5597.0846
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5736.2882
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5589.4521
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5638.8956
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5637.9202
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5686.0638
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5717.6421
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5650.0864
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5594.4879
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157311 75.86942744907549 0.8311693005488127 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 13946.8552
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5691.0831
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5117.7171
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5137.1098
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4932.0072
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5018.7316
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4888.9205
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4881.9937
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4763.9344
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4859.5017
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4793.0035
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4918.7721
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4768.0124
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4712.4956
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4635.0709
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4805.2318
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4762.6654
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4674.7523
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4729.2798
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4526.6310
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4558.4589
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4666.3690
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4640.6782
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4590.7081
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4705.8378
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.50781927724552 64.93413495345378 0.43724387893831956 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 24
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     553.73  0.27   Eagle_education_Sherrill
# -0.8011    3149.69     834.20  0.26   Eagle_education_Peter
# -0.7147     477.70     199.77  0.42   Eagle_health_Athena
# -0.6972    1197.84     365.75  0.31   Eagle_education_Roman
# -0.6928     712.07     287.12  0.40   Eagle_education_Norah
# -0.6191      57.05      35.64  0.62   Eagle_education_Petra
# -0.5975    1635.33    1152.76  0.70   Eagle_education_Brooke
# -0.5645     182.08      78.97  0.43   Eagle_public_Alvin
# -0.5301     148.51      64.93  0.44   Eagle_education_Teresa
# -0.5294      92.83      62.25  0.67   Eagle_lodging_Dawn
# -0.4636     121.95      50.45  0.41   Eagle_health_Vincenza
# -0.4516     336.36     136.16  0.40   Eagle_office_Francis
# -0.4243      91.28      75.87  0.83   Eagle_lodging_Trina
# -0.4210      81.97      68.67  0.84   Eagle_lodging_Edgardo
# -0.3226     226.25      93.78  0.41   Eagle_education_Will
#  0.4372       0.11       2.92 27.79   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 2.20 mean RMSE
# * 6.83 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.49 mean RMSE
# * 0.19 stddev
