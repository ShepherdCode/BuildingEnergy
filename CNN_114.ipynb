# %% [markdown]
# # CNN  CoLab
# Based previous 24 hr, predict next 30 days.
#
# Same as CNN 112 but predict many future steps.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24*30   # length of the predicted sequence

## CNN parameters
EPOCHS=25
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:24], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        print("y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 4s 12ms/step - loss: 86811.3755
# Epoch 2/25
# 263/263 [==============================] - 3s 11ms/step - loss: 52834.7930
# Epoch 3/25
# 263/263 [==============================] - 3s 11ms/step - loss: 50241.7394
# Epoch 4/25
# 263/263 [==============================] - 3s 11ms/step - loss: 49429.4855
# Epoch 5/25
# 263/263 [==============================] - 3s 11ms/step - loss: 48844.5602
# Epoch 6/25
# 263/263 [==============================] - 3s 11ms/step - loss: 49428.4587
# Epoch 7/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47709.0974
# Epoch 8/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47654.5158
# Epoch 9/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47998.9017
# Epoch 10/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47474.3025
# Epoch 11/25
# 263/263 [==============================] - 3s 11ms/step - loss: 48976.4521
# Epoch 12/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47944.4480
# Epoch 13/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47181.4148
# Epoch 14/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47758.3448
# Epoch 15/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47935.2126
# Epoch 16/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47372.5958
# Epoch 17/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47833.1410
# Epoch 18/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47564.3819
# Epoch 19/25
# 263/263 [==============================] - 3s 11ms/step - loss: 46926.5004
# Epoch 20/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47131.7455
# Epoch 21/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47622.2763
# Epoch 22/25
# 263/263 [==============================] - 3s 11ms/step - loss: 46805.9016
# Epoch 23/25
# 263/263 [==============================] - 3s 11ms/step - loss: 46972.0731
# Epoch 24/25
# 263/263 [==============================] - 3s 11ms/step - loss: 47331.7774
# Epoch 25/25
# 263/263 [==============================] - 3s 11ms/step - loss: 46849.1695
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.70168061445776 217.03803797541175 0.45433802471919343 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 11ms/step - loss: 20862.6606
# Epoch 2/25
# 263/263 [==============================] - 3s 11ms/step - loss: 12582.2256
# Epoch 3/25
# 263/263 [==============================] - 3s 11ms/step - loss: 12360.4428
# Epoch 4/25
# 263/263 [==============================] - 3s 11ms/step - loss: 12073.4419
# Epoch 5/25
# 263/263 [==============================] - 3s 11ms/step - loss: 12262.3829
# Epoch 6/25
# 263/263 [==============================] - 3s 11ms/step - loss: 12026.8321
# Epoch 7/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11835.0321
# Epoch 8/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11954.6748
# Epoch 9/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11838.9098
# Epoch 10/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11980.9867
# Epoch 11/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11778.8895
# Epoch 12/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11763.8719
# Epoch 13/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11701.0717
# Epoch 14/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11601.9082
# Epoch 15/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11699.0469
# Epoch 16/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11719.3346
# Epoch 17/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11736.9574
# Epoch 18/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11689.0232
# Epoch 19/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11843.1108
# Epoch 20/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11713.7462
# Epoch 21/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11784.0642
# Epoch 22/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11644.1035
# Epoch 23/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11559.1024
# Epoch 24/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11623.5271
# Epoch 25/25
# 263/263 [==============================] - 3s 11ms/step - loss: 11574.0689
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830808 84.93412552077987 0.4664584566141531 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 11ms/step - loss: 376594.0865
# Epoch 2/25
# 263/263 [==============================] - 3s 11ms/step - loss: 216869.7999
# Epoch 3/25
# 263/263 [==============================] - 3s 11ms/step - loss: 209165.9622
# Epoch 4/25
# 263/263 [==============================] - 3s 11ms/step - loss: 212168.1214
# Epoch 5/25
# 263/263 [==============================] - 3s 11ms/step - loss: 207596.7763
# Epoch 6/25
# 263/263 [==============================] - 3s 11ms/step - loss: 205196.8774
# Epoch 7/25
# 263/263 [==============================] - 3s 11ms/step - loss: 206290.5745
# Epoch 8/25
# 263/263 [==============================] - 3s 11ms/step - loss: 201217.5994
# Epoch 9/25
# 263/263 [==============================] - 3s 11ms/step - loss: 203942.7473
# Epoch 10/25
# 263/263 [==============================] - 3s 11ms/step - loss: 205837.3575
# Epoch 11/25
# 263/263 [==============================] - 3s 11ms/step - loss: 198597.5565
# Epoch 12/25
# 263/263 [==============================] - 3s 12ms/step - loss: 203106.7621
# Epoch 13/25
# 263/263 [==============================] - 3s 11ms/step - loss: 199976.3405
# Epoch 14/25
# 263/263 [==============================] - 3s 11ms/step - loss: 200057.8798
# Epoch 15/25
# 263/263 [==============================] - 3s 11ms/step - loss: 199730.1499
# Epoch 16/25
# 263/263 [==============================] - 3s 11ms/step - loss: 201564.1820
# Epoch 17/25
# 263/263 [==============================] - 3s 11ms/step - loss: 203603.3652
# Epoch 18/25
# 263/263 [==============================] - 3s 11ms/step - loss: 200189.1670
# Epoch 19/25
# 263/263 [==============================] - 3s 11ms/step - loss: 198241.1925
# Epoch 20/25
# 263/263 [==============================] - 3s 12ms/step - loss: 194833.3859
# Epoch 21/25
# 263/263 [==============================] - 3s 11ms/step - loss: 198897.1491
# Epoch 22/25
# 263/263 [==============================] - 3s 11ms/step - loss: 196710.7201
# Epoch 23/25
# 263/263 [==============================] - 3s 11ms/step - loss: 197133.9654
# Epoch 24/25
# 263/263 [==============================] - 3s 11ms/step - loss: 192971.6614
# Epoch 25/25
# 263/263 [==============================] - 3s 11ms/step - loss: 198346.7146
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121304 425.9354205460098 0.3555874349635975 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 12ms/step - loss: 8147.6163
# Epoch 2/25
# 263/263 [==============================] - 3s 11ms/step - loss: 5173.8382
# Epoch 3/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4971.2620
# Epoch 4/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4943.8269
# Epoch 5/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4892.2766
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 4866.7340
# Epoch 7/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4911.5355
# Epoch 8/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4930.6631
# Epoch 9/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4908.0757
# Epoch 10/25
# 263/263 [==============================] - 3s 12ms/step - loss: 4876.7221
# Epoch 11/25
# 263/263 [==============================] - 3s 12ms/step - loss: 4812.8873
# Epoch 12/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4861.7869
# Epoch 13/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4815.4586
# Epoch 14/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4791.4445
# Epoch 15/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4867.4505
# Epoch 16/25
# 263/263 [==============================] - 3s 12ms/step - loss: 4838.9628
# Epoch 17/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4882.2847
# Epoch 18/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4872.7526
# Epoch 19/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4882.4826
# Epoch 20/25
# 263/263 [==============================] - 3s 12ms/step - loss: 4829.5238
# Epoch 21/25
# 263/263 [==============================] - 3s 12ms/step - loss: 4811.4790
# Epoch 22/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4809.0254
# Epoch 23/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4796.8305
# Epoch 24/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4810.4661
# Epoch 25/25
# 263/263 [==============================] - 3s 11ms/step - loss: 4808.5163
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.9677919573641 70.47040326355965 0.8597328484853555 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3406540.4991
# Epoch 2/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1424862.7306
# Epoch 3/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1278893.6113
# Epoch 4/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1273168.5502
# Epoch 5/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1243957.5663
# Epoch 6/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1227729.3442
# Epoch 7/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1212798.9072
# Epoch 8/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1191741.7803
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1181298.1238
# Epoch 10/25
# 263/263 [==============================] - 3s 13ms/step - loss: 1208821.5526
# Epoch 11/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1181410.3172
# Epoch 12/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1205833.1657
# Epoch 13/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1169428.3179
# Epoch 14/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1187874.8906
# Epoch 15/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1186879.7036
# Epoch 16/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1177390.2881
# Epoch 17/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1167162.2820
# Epoch 18/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1181412.0492
# Epoch 19/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1174339.0502
# Epoch 20/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1171833.1877
# Epoch 21/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1174216.6006
# Epoch 22/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1150337.1761
# Epoch 23/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1187790.9427
# Epoch 24/25
# 263/263 [==============================] - 3s 11ms/step - loss: 1184946.9020
# Epoch 25/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1170255.9763
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.6888831281212 1086.5753490308816 0.3449786278420447 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 4s 11ms/step - loss: 7691.9977
# Epoch 2/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3958.3693
# Epoch 3/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3888.2757
# Epoch 4/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3833.3713
# Epoch 5/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3793.2495
# Epoch 6/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3743.9780
# Epoch 7/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3779.4048
# Epoch 8/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3789.2763
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3744.6680
# Epoch 10/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3725.9868
# Epoch 11/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3712.8405
# Epoch 12/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3711.4728
# Epoch 13/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3693.9590
# Epoch 14/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3737.3453
# Epoch 15/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3730.5301
# Epoch 16/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3743.5147
# Epoch 17/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3695.7398
# Epoch 18/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3688.0684
# Epoch 19/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3693.4232
# Epoch 20/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3679.8939
# Epoch 21/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3648.3032
# Epoch 22/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3714.8245
# Epoch 23/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3683.5865
# Epoch 24/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3657.7951
# Epoch 25/25
# 263/263 [==============================] - 3s 11ms/step - loss: 3654.3990
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815749 61.76218710955533 0.66534683152971 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3143.5929
# Epoch 2/25
# 263/263 [==============================] - 3s 12ms/step - loss: 51.1238
# Epoch 3/25
# 263/263 [==============================] - 3s 12ms/step - loss: 10.0368
# Epoch 4/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2.6629
# Epoch 5/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.9572
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.4718
# Epoch 7/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2814
# Epoch 8/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2192
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.2665
# Epoch 10/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.5578
# Epoch 11/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1.0965
# Epoch 12/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1.1490
# Epoch 13/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1.0555
# Epoch 14/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2.2694
# Epoch 15/25
# 263/263 [==============================] - 3s 13ms/step - loss: 1.8351
# Epoch 16/25
# 263/263 [==============================] - 3s 13ms/step - loss: 1.0437
# Epoch 17/25
# 263/263 [==============================] - 4s 13ms/step - loss: 1.7807
# Epoch 18/25
# 263/263 [==============================] - 3s 13ms/step - loss: 1.0659
# Epoch 19/25
# 263/263 [==============================] - 3s 13ms/step - loss: 1.1601
# Epoch 20/25
# 263/263 [==============================] - 3s 13ms/step - loss: 2.0113
# Epoch 21/25
# 263/263 [==============================] - 3s 13ms/step - loss: 1.5336
# Epoch 22/25
# 263/263 [==============================] - 3s 12ms/step - loss: 0.9549
# Epoch 23/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1.5646
# Epoch 24/25
# 263/263 [==============================] - 3s 12ms/step - loss: 1.6700
# Epoch 25/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2.3338
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.10518451322389408 0.887191734717133 8.434623192376913 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 11ms/step - loss: 8189.1817
# Epoch 2/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3467.6583
# Epoch 3/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3257.1984
# Epoch 4/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3193.9997
# Epoch 5/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3040.2678
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 3044.5884
# Epoch 7/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2969.8489
# Epoch 8/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2941.3642
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2833.0801
# Epoch 10/25
# 263/263 [==============================] - 3s 12ms/step - loss: 2830.8001

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 4s 12ms/step - loss: 16493.3711
# Epoch 2/25
# 263/263 [==============================] - 3s 12ms/step - loss: 10308.3085
# Epoch 3/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9934.5410
# Epoch 4/25
# 263/263 [==============================] - 3s 13ms/step - loss: 10071.6970
# Epoch 5/25
# 263/263 [==============================] - 3s 12ms/step - loss: 10017.1534
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 10048.9401
# Epoch 7/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9915.9417
# Epoch 8/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9719.3235
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9654.3610
# Epoch 10/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9697.1144
# Epoch 11/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9799.7860
# Epoch 12/25
# 263/263 [==============================] - 3s 12ms/step - loss: 10110.0004
# Epoch 13/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9924.5328
# Epoch 14/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9712.4415
# Epoch 15/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9892.0862
# Epoch 16/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9802.7245
# Epoch 17/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9884.5570
# Epoch 18/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9636.2645
# Epoch 19/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9698.1975
# Epoch 20/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9714.3459
# Epoch 21/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9944.6603
# Epoch 22/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9672.4838
# Epoch 23/25
# 263/263 [==============================] - 3s 13ms/step - loss: 9733.4256
# Epoch 24/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9730.9585
# Epoch 25/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9971.4473
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.25485356247063 84.2311507309599 0.37228439259846885 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 4s 13ms/step - loss: 4180.5630
# Epoch 2/25
# 263/263 [==============================] - 3s 12ms/step - loss: 961.2229
# Epoch 3/25
# 263/263 [==============================] - 3s 12ms/step - loss: 878.4927
# Epoch 4/25
# 263/263 [==============================] - 3s 12ms/step - loss: 881.2163
# Epoch 5/25
# 263/263 [==============================] - 3s 12ms/step - loss: 846.4603
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 852.3486
# Epoch 7/25
# 263/263 [==============================] - 3s 12ms/step - loss: 832.6178
# Epoch 8/25
# 263/263 [==============================] - 3s 13ms/step - loss: 836.2276
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 826.0205
# Epoch 10/25
# 263/263 [==============================] - 3s 12ms/step - loss: 817.7974
# Epoch 11/25
# 263/263 [==============================] - 3s 12ms/step - loss: 819.2193
# Epoch 12/25
# 263/263 [==============================] - 3s 12ms/step - loss: 833.9390
# Epoch 13/25
# 263/263 [==============================] - 3s 12ms/step - loss: 828.3893
# Epoch 14/25
# 263/263 [==============================] - 3s 12ms/step - loss: 823.7280
# Epoch 15/25
# 263/263 [==============================] - 3s 12ms/step - loss: 813.2636
# Epoch 16/25
# 263/263 [==============================] - 3s 12ms/step - loss: 795.3301
# Epoch 17/25
# 263/263 [==============================] - 3s 12ms/step - loss: 814.0919
# Epoch 18/25
# 263/263 [==============================] - 3s 12ms/step - loss: 819.9120
# Epoch 19/25
# 263/263 [==============================] - 3s 12ms/step - loss: 827.4744
# Epoch 20/25
# 263/263 [==============================] - 3s 12ms/step - loss: 819.2492
# Epoch 21/25
# 263/263 [==============================] - 3s 12ms/step - loss: 813.7397
# Epoch 22/25
# 263/263 [==============================] - 3s 12ms/step - loss: 843.5547
# Epoch 23/25
# 263/263 [==============================] - 3s 12ms/step - loss: 809.2340
# Epoch 24/25
# 263/263 [==============================] - 3s 12ms/step - loss: 802.4347
# Epoch 25/25
# 263/263 [==============================] - 3s 12ms/step - loss: 796.5758
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819895 39.10446193168422 0.6854396723955163 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 3s 12ms/step - loss: 9847.2791
# Epoch 2/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6270.2604
# Epoch 3/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6143.8376
# Epoch 4/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6122.0130
# Epoch 5/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5996.2140
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6006.7283
# Epoch 7/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6093.0693
# Epoch 8/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6079.2447
# Epoch 9/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6034.2647
# Epoch 10/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5945.9807
# Epoch 11/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5968.6739
# Epoch 12/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5905.3851
# Epoch 13/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5960.5494
# Epoch 14/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5884.9577
# Epoch 15/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6022.0785
# Epoch 16/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5947.1376
# Epoch 17/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5947.0729
# Epoch 18/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5921.2433
# Epoch 19/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5968.5845
# Epoch 20/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5889.1181
# Epoch 21/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5889.4360
# Epoch 22/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5871.1123
# Epoch 23/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5953.7233
# Epoch 24/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5923.9101
# Epoch 25/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5942.9347
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157311 78.44786274158905 0.8594167294624862 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 720)               761040
# =================================================================
# Total params: 761,120
# Trainable params: 761,120
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8400, 24, 8, 1)
# Epoch 1/25
# 263/263 [==============================] - 4s 13ms/step - loss: 11892.8193
# Epoch 2/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6352.8459
# Epoch 3/25
# 263/263 [==============================] - 3s 12ms/step - loss: 6060.9341
# Epoch 4/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5866.1771
# Epoch 5/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5926.2393
# Epoch 6/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5710.3505
# Epoch 7/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5647.7813
# Epoch 8/25
# 263/263 [==============================] - 3s 12ms/step - loss: 5678.5790
# Epoch 9/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5733.6327
# Epoch 10/25
# 263/263 [==============================] - 4s 14ms/step - loss: 5543.7873
# Epoch 11/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5639.4894
# Epoch 12/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5458.2645
# Epoch 13/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5629.2802
# Epoch 14/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5466.5138
# Epoch 15/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5611.3977
# Epoch 16/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5485.4876
# Epoch 17/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5485.9290
# Epoch 18/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5410.6774
# Epoch 19/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5513.7653
# Epoch 20/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5317.2695
# Epoch 21/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5554.5876
# Epoch 22/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5376.8544
# Epoch 23/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5322.8950
# Epoch 24/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5366.4793
# Epoch 25/25
# 263/263 [==============================] - 3s 13ms/step - loss: 5331.8858
# y_pred.shape: (8400, 720)
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.50781927724552 65.46756544228026 0.44083581430860896 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 720
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     830.05  0.41   Eagle_education_Sherrill
# -0.8011    3149.69    1086.58  0.34   Eagle_education_Peter
# -0.7147     477.70     217.04  0.45   Eagle_health_Athena
# -0.6972    1197.84     425.94  0.36   Eagle_education_Roman
# -0.6928     712.07     355.35  0.50   Eagle_education_Norah
# -0.6191      57.05      39.10  0.69   Eagle_education_Petra
# -0.5975    1635.33    1282.96  0.78   Eagle_education_Brooke
# -0.5645     182.08      84.93  0.47   Eagle_public_Alvin
# -0.5301     148.51      65.47  0.44   Eagle_education_Teresa
# -0.5294      92.83      61.76  0.67   Eagle_lodging_Dawn
# -0.4636     121.95      52.36  0.43   Eagle_health_Vincenza
# -0.4516     336.36     133.70  0.40   Eagle_office_Francis
# -0.4243      91.28      78.45  0.86   Eagle_lodging_Trina
# -0.4210      81.97      70.47  0.86   Eagle_lodging_Edgardo
# -0.3226     226.25      84.23  0.37   Eagle_education_Will
#  0.4372       0.11       0.89  8.43   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 1.03 mean RMSE
# * 1.98 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.54 mean RMSE
# * 0.18 stddev
