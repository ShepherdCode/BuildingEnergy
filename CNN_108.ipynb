# %% [markdown]
# # CNN
# Here use no smoothing.
#
# Here is how the previous work may have been optimistic.
# We smoothed all the data before starting.
# But we should not smooth the steam values used to test accuracy!
#
# Compare to Report1 CNN 107. The only difference is no smoothing. The job got harder and the RMSE increased.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=25
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:24], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 79574.8913
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 44293.7338
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 43759.9817
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 43263.5109
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 43747.9206
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 43296.7119
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42743.8258
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42992.5620
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42161.5390
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42756.3181
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41838.9867
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 43830.5519
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42166.3347
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41629.6692
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42286.9794
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 43227.7295
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42412.9586
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41906.5637
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42368.0558
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42135.1581
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41357.0636
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41771.8612
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 42184.4667
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42050.3354
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 41247.1421
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.7016806144551 172.12797554661663 0.3603252459258945 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 15933.1160
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 13841.1281
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12762.1201
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12524.1926
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12791.5373
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12552.6235
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12720.7558
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12190.4026
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12747.9063
# Epoch 10/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12345.8731
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12432.5877
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11867.7140
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12532.4021
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12655.6276
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12796.4369
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12417.0011
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12770.3056
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12608.7205
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12617.0251
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12074.6376
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 11911.7687
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12554.1581
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 11929.3275
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12283.0845
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 12396.8273
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830828 80.97591180221663 0.44471993572176693 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 307621.7730
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 177492.5222
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 173475.5636
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 163011.4696
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 168741.3473
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 168537.2170
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 164259.6105
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 161585.0754
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 168839.6957
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 164740.4878
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 155817.3999
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 163488.5501
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 158006.4211: 0s - los
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 155701.0907
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 162510.2115
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 153706.7426
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 159585.2735
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 160166.9591
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 160096.4831
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 153288.0202
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 158866.4101
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 160620.2568
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 158739.5657
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 155380.9950
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 157875.6673
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121295 363.0383565194415 0.3030785226142134 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 6821.4936
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5424.4653
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4848.1942
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4806.7516
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4978.5712
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4861.7572
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4825.9962
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4712.3909
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4695.7498
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4419.3294
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4456.9872: 0s - los
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4533.5982
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4585.8088
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4626.2248
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4633.8846
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4601.6044
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4632.2166
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4562.0676
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4619.3980
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4562.8067
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4744.6590
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4839.6158
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4780.4113
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4401.9729
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 4869.8480
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.96779195736434 70.74000155144557 0.8630219243705025 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3250448.4918
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1027580.0286
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 851584.8180
# Epoch 4/25
# 274/274 [==============================] - 1s 3ms/step - loss: 859086.7877
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 804072.4320
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 816944.6464
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 812446.4311
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 814193.8607
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 809157.8039
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 767217.1361
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 793897.7350
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 771885.1777
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 790627.3268
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 769969.2534
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 773400.8757
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 777508.9164
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 775302.3016
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 756611.9209
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 772823.0031
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 772009.1736
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 749870.1298
# Epoch 22/25
# 274/274 [==============================] - 1s 5ms/step - loss: 754020.6523
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 772724.8289
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 772916.2502
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 745852.9770
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.688883128135 866.8193727328559 0.2752079347824247 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 3ms/step - loss: 19853.9627
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3539.7553
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3761.6880
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3594.1490
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3451.4492
# Epoch 6/25
# 274/274 [==============================] - ETA: 0s - loss: 3564.11 - 1s 3ms/step - loss: 3560.8928
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3528.2696
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3480.1884
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3527.4538
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3681.4539
# Epoch 11/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3334.8229
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3339.7110
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3459.8681
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3544.8455
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 3360.9312
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3604.3212
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3447.0284
# Epoch 18/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3271.0452
# Epoch 19/25
# 274/274 [==============================] - 1s 5ms/step - loss: 3357.6679
# Epoch 20/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3329.0934
# Epoch 21/25
# 274/274 [==============================] - 2s 6ms/step - loss: 3374.2332
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3571.7524
# Epoch 23/25
# 274/274 [==============================] - 1s 5ms/step - loss: 3263.6719
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3300.6857
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 3308.7125
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815779 69.10554959841292 0.7444548293742274 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 4ms/step - loss: 2652.5777
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 128.4988
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 21.2239
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 5.4414
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2.4509A: 0s - loss: 2.48
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1.4473
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 0.9355
# Epoch 8/25
# 274/274 [==============================] - 1s 5ms/step - loss: 0.9346
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2.2740
# Epoch 10/25
# 274/274 [==============================] - 1s 5ms/step - loss: 17.1511
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11.9657
# Epoch 12/25
# 274/274 [==============================] - 1s 5ms/step - loss: 17.4437
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1.3957
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5.7567
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2.4629
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 13.8744
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11.5680
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 17.9032
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9.0274
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 5.8866
# Epoch 21/25
# 274/274 [==============================] - 1s 5ms/step - loss: 15.7347
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 12.8077
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11.1568
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7.0964
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 11.8709
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.1051845132238942 1.131307480021228 10.755456724063015 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 4ms/step - loss: 8259.8823
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3561.0601
# Epoch 3/25
# 274/274 [==============================] - 1s 5ms/step - loss: 3158.7561
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2995.1165
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 2914.1726
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 3080.1290
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2878.8261
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2911.7484
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2717.7885
# Epoch 10/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2805.2289
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2660.8628: 0s -
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2661.9090
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2572.2409
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2698.2758
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2643.1942
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2567.2704
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2524.2170
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 2476.0856
# Epoch 19/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2537.5936
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 2490.7907
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2500.6906
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2418.7566
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2354.7024
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2372.7618
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 2435.0527
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534426 50.55910219927339 0.4145910975226176 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 14248.1051
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8549.8136
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8287.2592
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8279.6058
# Epoch 5/25
# 274/274 [==============================] - 1s 5ms/step - loss: 7457.6808
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8295.8850
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8075.0305
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8003.9257
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8456.9007
# Epoch 10/25
# 274/274 [==============================] - 1s 5ms/step - loss: 8530.8770
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7196.9316
# Epoch 12/25
# 274/274 [==============================] - 1s 5ms/step - loss: 8351.6219
# Epoch 13/25
# 274/274 [==============================] - 1s 5ms/step - loss: 7180.6368
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7236.0590
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7533.0980
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7349.7506
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7174.3618
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7953.2685
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 8556.7708
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 7302.9762
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8102.3991
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7521.0431
# Epoch 23/25
# 274/274 [==============================] - 1s 5ms/step - loss: 7717.1999
# Epoch 24/25
# 274/274 [==============================] - 1s 4ms/step - loss: 7272.9153
# Epoch 25/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8203.9423
# cor,mean,rmse,rmse/mean,bldg: -0.4515947035800076 336.3595254616963 137.4380963655193 0.4086047397553793 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 4ms/step - loss: 1646347.6227
# Epoch 2/25
# 274/274 [==============================] - 2s 6ms/step - loss: 570427.0364: 0s - loss: 570978.
# Epoch 3/25
# 274/274 [==============================] - 1s 5ms/step - loss: 495036.8919
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 477868.8177
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 483300.3237
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 457695.7119
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 446278.9782
# Epoch 8/25
# 274/274 [==============================] - 1s 4ms/step - loss: 431210.6515
# Epoch 9/25
# 274/274 [==============================] - 1s 5ms/step - loss: 441486.5807
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 454381.0539
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 442581.8099
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 423452.8614
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 426903.1698
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 414975.1138
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 411903.1918
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 411883.4522
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 421553.6976
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 416459.3985
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 400309.8091
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 396126.4602
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 402393.1761
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 398869.2380
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 394451.5887
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 402450.3068
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 401045.4967
# cor,mean,rmse,rmse/mean,bldg: -0.8130507458567988 2032.6741548164612 583.7799553706191 0.2871980017000467 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 2077760.9245
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1285369.2264
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1237368.4023
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1238321.9141
# Epoch 5/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1180215.5798
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1167099.5686
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1150452.1945
# Epoch 8/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1183483.8018
# Epoch 9/25
# 274/274 [==============================] - 1s 5ms/step - loss: 1158787.9523
# Epoch 10/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1175842.9741
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1166726.5500
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1155185.1918
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1158568.1820
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1183752.9955
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1132268.1786
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1168270.3977
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1139579.3318
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1142046.9020
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1163315.0191
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1146823.2832
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1127052.4561
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1136344.1491
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 1164772.7982
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1137778.1736
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 1184404.5018
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1169.8654168506882 0.7153714844991899 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 4ms/step - loss: 143902.9257
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 101828.8719
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 98530.2590A: 0s
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 102253.7390
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 100431.7890
# Epoch 6/25
# 274/274 [==============================] - 1s 4ms/step - loss: 98179.0128
# Epoch 7/25
# 274/274 [==============================] - 1s 4ms/step - loss: 96395.3961
# Epoch 8/25
# 274/274 [==============================] - 1s 3ms/step - loss: 95354.6773
# Epoch 9/25
# 274/274 [==============================] - 1s 4ms/step - loss: 97580.5799
# Epoch 10/25
# 274/274 [==============================] - 1s 4ms/step - loss: 90563.9702
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 95821.7073
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 92522.7088
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 93461.3289
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 89845.0501
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 89008.4553
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 89261.2205
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 91863.0023
# Epoch 18/25
# 274/274 [==============================] - 1s 3ms/step - loss: 88548.6056
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 92129.8229
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 89930.3678
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 88415.1207
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 91902.4388
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 89782.3844
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 92067.5214
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 86155.1392A: 1s - los
# cor,mean,rmse,rmse/mean,bldg: -0.6928377753347054 712.0697702804378 294.95750440917755 0.4142255670999951 Eagle_education_Norah
# Building Eagle_education_Will
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 6ms/step - loss: 19588.3615
# Epoch 2/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9553.5448
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9544.3606
# Epoch 4/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9656.8069
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9802.4141
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9489.9654
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9362.4093
# Epoch 8/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9877.3070
# Epoch 9/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9623.0870
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 8954.2760
# Epoch 11/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9849.6551
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 8998.1897
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9593.2437
# Epoch 14/25
# 274/274 [==============================] - 1s 5ms/step - loss: 8906.8771
# Epoch 15/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9445.0395
# Epoch 16/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9040.1104
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9907.5624
# Epoch 18/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9448.4792
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9139.8142
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9309.9577
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9273.3805
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 9337.4047
# Epoch 23/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9431.1526
# Epoch 24/25
# 274/274 [==============================] - 1s 5ms/step - loss: 8995.5454
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 9102.9802
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.2548535624715 93.49294003624269 0.4132195997750308 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 2324.5050
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 860.0555
# Epoch 3/25
# 274/274 [==============================] - 1s 4ms/step - loss: 749.5068
# Epoch 4/25
# 274/274 [==============================] - 1s 4ms/step - loss: 788.2103
# Epoch 5/25
# 274/274 [==============================] - 1s 5ms/step - loss: 714.3210
# Epoch 6/25
# 274/274 [==============================] - 1s 5ms/step - loss: 759.2363
# Epoch 7/25
# 274/274 [==============================] - 1s 5ms/step - loss: 690.5093
# Epoch 8/25
# 274/274 [==============================] - 1s 5ms/step - loss: 728.2738
# Epoch 9/25
# 274/274 [==============================] - 1s 5ms/step - loss: 714.4155
# Epoch 10/25
# 274/274 [==============================] - 1s 5ms/step - loss: 742.5944
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 697.6519
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 718.3279
# Epoch 13/25
# 274/274 [==============================] - 1s 5ms/step - loss: 753.0238
# Epoch 14/25
# 274/274 [==============================] - 1s 5ms/step - loss: 697.8992
# Epoch 15/25
# 274/274 [==============================] - 1s 5ms/step - loss: 679.5834
# Epoch 16/25
# 274/274 [==============================] - 1s 5ms/step - loss: 721.4145
# Epoch 17/25
# 274/274 [==============================] - 1s 5ms/step - loss: 667.8619
# Epoch 18/25
# 274/274 [==============================] - 1s 5ms/step - loss: 670.3457
# Epoch 19/25
# 274/274 [==============================] - 1s 5ms/step - loss: 659.5860
# Epoch 20/25
# 274/274 [==============================] - 1s 5ms/step - loss: 686.7937
# Epoch 21/25
# 274/274 [==============================] - 1s 4ms/step - loss: 656.7515
# Epoch 22/25
# 274/274 [==============================] - 1s 4ms/step - loss: 631.5434
# Epoch 23/25
# 274/274 [==============================] - 1s 4ms/step - loss: 671.5551
# Epoch 24/25
# 274/274 [==============================] - 1s 5ms/step - loss: 672.3434
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 688.7522
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819881 36.60196049121505 0.64157476075139 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 2s 5ms/step - loss: 7766.1105
# Epoch 2/25
# 274/274 [==============================] - 1s 4ms/step - loss: 6242.9051
# Epoch 3/25
# 274/274 [==============================] - 1s 5ms/step - loss: 6530.5114
# Epoch 4/25
# 274/274 [==============================] - 2s 5ms/step - loss: 5901.1964
# Epoch 5/25
# 274/274 [==============================] - 1s 5ms/step - loss: 6175.6561
# Epoch 6/25
# 274/274 [==============================] - 2s 5ms/step - loss: 6407.9925
# Epoch 7/25
# 274/274 [==============================] - 1s 5ms/step - loss: 5913.5300
# Epoch 8/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5939.2698
# Epoch 9/25
# 274/274 [==============================] - 1s 5ms/step - loss: 5808.2408
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5931.5798
# Epoch 11/25
# 274/274 [==============================] - 1s 5ms/step - loss: 5791.4966
# Epoch 12/25
# 274/274 [==============================] - 1s 4ms/step - loss: 6030.6187
# Epoch 13/25
# 274/274 [==============================] - 1s 4ms/step - loss: 5613.4494
# Epoch 14/25
# 274/274 [==============================] - 1s 4ms/step - loss: 5608.0358
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5842.7120
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5558.5668
# Epoch 17/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5424.6237
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5819.3169
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5608.0809
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5923.4271
# Epoch 21/25
# 274/274 [==============================] - 1s 5ms/step - loss: 6020.8246
# Epoch 22/25
# 274/274 [==============================] - 2s 5ms/step - loss: 5878.1639
# Epoch 23/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5624.0763
# Epoch 24/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5451.4417
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5478.4363
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157318 76.56716494026394 0.8388131961470363 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8759, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 8794.3826
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5704.3116
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5772.5685
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5285.3439
# Epoch 5/25
# 274/274 [==============================] - 1s 5ms/step - loss: 5109.7754
# Epoch 6/25
# 274/274 [==============================] - 1s 5ms/step - loss: 5259.1033
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5053.1252
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4990.4207
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5022.6915
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5077.6978
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4924.4277
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4994.1385
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5127.1953
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4864.5928
# Epoch 15/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5164.4143
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4906.6204
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5267.8126
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 5008.3217
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4798.5907
# Epoch 20/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4803.0896
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4843.2372
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 4922.0862
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4840.1367
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4855.3450
# Epoch 25/25
# 274/274 [==============================] - 1s 5ms/step - loss: 4880.4935
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.5078192772458 65.43103324970218 0.44058981923066626 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     583.78  0.29   Eagle_education_Sherrill
# -0.8011    3149.69     866.82  0.28   Eagle_education_Peter
# -0.7147     477.70     172.13  0.36   Eagle_health_Athena
# -0.6972    1197.84     363.04  0.30   Eagle_education_Roman
# -0.6928     712.07     294.96  0.41   Eagle_education_Norah
# -0.6191      57.05      36.60  0.64   Eagle_education_Petra
# -0.5975    1635.33    1169.87  0.72   Eagle_education_Brooke
# -0.5645     182.08      80.98  0.44   Eagle_public_Alvin
# -0.5301     148.51      65.43  0.44   Eagle_education_Teresa
# -0.5294      92.83      69.11  0.74   Eagle_lodging_Dawn
# -0.4636     121.95      50.56  0.41   Eagle_health_Vincenza
# -0.4516     336.36     137.44  0.41   Eagle_office_Francis
# -0.4243      91.28      76.57  0.84   Eagle_lodging_Trina
# -0.4210      81.97      70.74  0.86   Eagle_lodging_Edgardo
# -0.3226     226.25      93.49  0.41   Eagle_education_Will
#  0.4372       0.11       1.13 10.76   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 1.14 mean RMSE
# * 2.57 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.50 mean RMSE
# * 0.20 stddev
