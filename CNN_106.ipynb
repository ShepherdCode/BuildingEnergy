# %% [markdown]
# ## CNN

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH="data/"  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
HOTWATER_FILE='hotwater.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'hotwater'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'hotwater' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=5
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
htwter_df = read_zip_to_panda(ZIP_PATH,HOTWATER_FILE)
htwter_df = fix_date_type(htwter_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in htwter_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    # This is very slow. Is there a faster way? See...
    # https://stackoverflow.com/questions/27852343/split-python-sequence-time-series-array-into-subsequences-with-overlap
    # This didn't work: np.atleast_1d(p) 
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,1)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_hotwater = htwter_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_hotwater,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        print("Train on",len(X_train),"samples...")
        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        # Compare. Solve the problem that predict.shape != truth.shape 
        #print(" before ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        #nsamples, nsteps, ndim = y_test.shape
        #y_test = y_test.reshape(nsamples,nsteps*ndim)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        ##print(" after ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)

        ## break   ## REMOVE THIS LINE TO LOOP OVER BUILDINGS!
        
if True:
    print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
    print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
    print("          Using one weather feature as leading correlate.")
    print("Column 2: Mean usage.")
    print("          Using mean to help understand the RMSE.")
    print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
    print("Column 4: RMSE/mean normalized to help understand RMSE.")
    print("Column 5: Building.")
    for cor in sorted(cors):
        print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# Building Eagle_office_Ryan
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Margo
# Building Eagle_health_Reba
# Building Eagle_office_Sonya
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 6ms/step - loss: 2445.0985
# Epoch 2/5
# 274/274 [==============================] - 2s 7ms/step - loss: 20.6573
# Epoch 3/5
# 274/274 [==============================] - 2s 6ms/step - loss: 15.6030
# Epoch 4/5
# 274/274 [==============================] - 2s 6ms/step - loss: 11.2448
# Epoch 5/5
# 274/274 [==============================] - 2s 5ms/step - loss: 9.1820
# cor,mean,rmse,rmse/mean,bldg: -0.800427880052977 370553.0361592029 5.206660631538445 1.4051053758743123e-05 Eagle_office_Sonya
# Building Eagle_education_Cassie
# Building Eagle_food_Jennifer
# Building Eagle_office_Yadira
# Building Eagle_education_Shanna
# Building Eagle_office_Nereida
# Building Eagle_office_Efrain
# Building Eagle_education_Lino
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 6ms/step - loss: 3517.9492
# Epoch 2/5
# 274/274 [==============================] - 2s 6ms/step - loss: 12.2127
# Epoch 3/5
# 274/274 [==============================] - 2s 6ms/step - loss: 10.1786
# Epoch 4/5
# 274/274 [==============================] - 2s 6ms/step - loss: 8.0517
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 7.7270A: 0s - los
# cor,mean,rmse,rmse/mean,bldg: -0.7923174545842205 210486.82883646275 3.281704871973375 1.5591022441233544e-05 Eagle_education_Lino
# Building Eagle_office_Jeff
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2280.3819
# Epoch 2/5
# 274/274 [==============================] - 2s 6ms/step - loss: 15.7841
# Epoch 3/5
# 274/274 [==============================] - 2s 6ms/step - loss: 10.8509
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 9.7086
# Epoch 5/5
# 274/274 [==============================] - 2s 6ms/step - loss: 8.8201
# cor,mean,rmse,rmse/mean,bldg: -0.7114992352240831 53933.06755377882 2.103282314337381 3.899801012134372e-05 Eagle_office_Jeff
# Building Eagle_education_Wesley
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7656.7781
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10.4418
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8.8705
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7.5658
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 6.8488
# cor,mean,rmse,rmse/mean,bldg: -0.551196623813277 136997.35027563386 2.40826522271283 1.7578918262780155e-05 Eagle_education_Wesley
# Building Eagle_assembly_Lacy
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 5ms/step - loss: 7921.5205
# Epoch 2/5
# 274/274 [==============================] - 1s 5ms/step - loss: 28.1875
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 18.7691
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 13.8943
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 10.7177
# cor,mean,rmse,rmse/mean,bldg: -0.878213126813526 309984.3601304947 2.932179130151985 9.459119579186575e-06 Eagle_assembly_Lacy
# Building Eagle_office_Chantelle
# Building Eagle_lodging_Andy
# Building Eagle_education_Sheena
# Building Eagle_office_Lane
# Building Eagle_assembly_Ian
# Building Eagle_office_Jackie
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 3292.0850
# Epoch 2/5
# 274/274 [==============================] - 1s 5ms/step - loss: 5.6472
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 5.3650
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 4.7690
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 4.9354
# cor,mean,rmse,rmse/mean,bldg: -0.8223439184721957 31236.04393931528 2.125769078614432 6.805500346792733e-05 Eagle_office_Jackie
# Building Eagle_office_Isidro
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4766.1288
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 19.2065
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 16.0199
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 13.0962
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 12.6906
# cor,mean,rmse,rmse/mean,bldg: -0.5416814562473937 52918.29336000502 2.736078112951317 5.17038237483904e-05 Eagle_office_Isidro
# Building Eagle_office_Donovan
# Building Eagle_assembly_Estelle
# Building Eagle_office_Phyllis
# Building Eagle_education_Samantha
# Building Eagle_office_Randolph
# Building Eagle_education_April
# Building Eagle_office_Francis
# Building Eagle_office_Mable
# Building Eagle_education_Brooke
# Building Eagle_office_Demetra
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 16441.6146
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.7321
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 3.3926
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 2.9239
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 2.7374
# cor,mean,rmse,rmse/mean,bldg: -0.745597449400916 205194.93019945626 1.413081840368976 6.886533887535203e-06 Eagle_office_Demetra
# Building Eagle_education_Alberto
# Building Eagle_public_Pearle
# Building Eagle_office_Elias
# Building Eagle_public_Preston
# Building Eagle_assembly_Latrina
# Building Eagle_public_Ola
# Building Eagle_public_Henry
# Building Eagle_education_Will
# Building Eagle_lodging_Stephanie
# Building Eagle_assembly_Candice
# Building Eagle_public_Missy
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 1009.3569
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 15.8868
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 9.9792
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 7.6094
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 6.3787
# cor,mean,rmse,rmse/mean,bldg: -0.7252008435225401 64437.79121721158 1.9976256085485247 3.1000839271706e-05 Eagle_public_Missy
# Building Eagle_lodging_Blake
# Building Eagle_education_Maragret
# Building Eagle_office_Lillian
# Building Eagle_office_Damian
# Building Eagle_health_Amy
# Building Eagle_assembly_Josie
# Building Eagle_office_Elvis
# Building Eagle_office_Remedios
# Building Eagle_public_Minnie
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 548.6541
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.0027
# Epoch 3/5
# 274/274 [==============================] - 1s 5ms/step - loss: 3.6999
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 3.4809
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 4.1193
# cor,mean,rmse,rmse/mean,bldg: -0.47196346362641883 124816.09824790656 2.9771383057432153 2.3852198134170954e-05 Eagle_public_Minnie
# Building Eagle_education_Luther
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 13323.9714
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 37.9925
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 12.6807
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 7.4198
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 6.2097
# cor,mean,rmse,rmse/mean,bldg: -0.7528727055937101 377400.32777387515 2.051643688570283 5.436253064940513e-06 Eagle_education_Luther
# Building Eagle_education_Paul
# Building Eagle_assembly_Margret
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 5ms/step - loss: 3986.2280
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10.8103
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8.0099
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.9792
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 5.3868
# cor,mean,rmse,rmse/mean,bldg: -0.4623670938300602 293442.86686486553 1.9105798707970847 6.5109092315300105e-06 Eagle_assembly_Margret
# Building Eagle_office_Marisela
# History 24 Future 1
# Column 1: Correlation of hotwater and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8782  309984.36       2.93  0.00   Eagle_assembly_Lacy
# -0.8223   31236.04       2.13  0.00   Eagle_office_Jackie
# -0.8004  370553.04       5.21  0.00   Eagle_office_Sonya
# -0.7923  210486.83       3.28  0.00   Eagle_education_Lino
# -0.7529  377400.33       2.05  0.00   Eagle_education_Luther
# -0.7456  205194.93       1.41  0.00   Eagle_office_Demetra
# -0.7252   64437.79       2.00  0.00   Eagle_public_Missy
# -0.7115   53933.07       2.10  0.00   Eagle_office_Jeff
# -0.5512  136997.35       2.41  0.00   Eagle_education_Wesley
# -0.5417   52918.29       2.74  0.00   Eagle_office_Isidro
# -0.4720  124816.10       2.98  0.00   Eagle_public_Minnie
# -0.4624  293442.87       1.91  0.00   Eagle_assembly_Margret
