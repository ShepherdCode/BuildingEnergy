# %% [markdown]
# # CNN  CoLab
# Here predict more than one hour at a time.
#
# Same as CNN 110 but use 25 epochs not 5. The extra training did not help.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24   # length of the predicted sequence

## CNN parameters
EPOCHS=25
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:24], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        print("y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 86914.5879
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 43372.8611
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42468.7281
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42088.3029
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 42044.1095
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40563.2495
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41799.5965
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40740.7965
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 41278.7569
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40270.1628
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40514.4189
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39643.4634
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40236.7471
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40316.4115
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40081.4221
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40344.9205
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 38977.4111
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39575.4591
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39896.0194
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 40036.5543
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39485.8276
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 38934.6623
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39583.0123
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39991.6277
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 39667.4067
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.70168061445776 199.02419108167658 0.4166286181486234 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 24584.1879
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12565.8524
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12672.4700
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12288.2738
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12295.0502
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12323.4421
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12111.6405
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12236.6599
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12105.7048
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12202.9132
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12146.4668
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12089.1858
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11842.2352
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11989.4733
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12058.0027
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11919.0913
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11746.3710
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11774.2416
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11803.4151
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11813.5229
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11873.2530
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11995.9608
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 12025.8072
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11898.4531
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11748.8364
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830808 83.33255430473454 0.45766262298410787 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 334878.8241
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 157194.1478
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 157579.8541
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 159174.8999
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 155752.8228
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 154897.2123
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 156790.5731
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 153585.3997
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 148036.5482
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 154043.9970
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 153177.6000
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 152243.7652
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 148816.1461
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 153137.1797
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 147578.1754
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 148011.0605
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 145495.5708
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 151406.9865
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 149185.3541
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 147036.1528
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 150138.0472
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 149817.6228
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 150128.8041
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 151456.3877
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 150346.3805
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121304 359.80816304303687 0.3003818316199811 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 10870.1621
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4962.5871
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4727.6932
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4692.9251
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4555.0399
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4556.9073
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4604.5566
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4544.1041
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4525.2430
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4516.8442
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4515.7212
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4499.0565
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4546.9572
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4489.7400
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4524.8912
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4476.1529
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4494.2426
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4494.7344
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4537.5933
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4517.1928
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4488.4907
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4465.3992
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4544.9364
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4444.8256
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4504.3742
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.9677919573641 68.33355884816696 0.8336635307159543 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3190817.1950
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 883280.4064
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 688362.1289
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 725271.4395
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 729429.2100
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 700553.7270
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 681712.9073
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 700867.8809
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 688850.4489
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 677271.1616
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 676957.8758
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 684828.2306
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 695480.5223
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 682589.7164
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 690522.9734
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 674634.3630
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 679192.8761
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 661802.1500
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 676631.5186
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 665844.8248
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 661950.3825
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 669392.0307
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 669258.6859
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 660975.6686
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 654220.3652
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.6888831281212 886.3816732975289 0.28141880236031974 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9949.8013
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3695.7818
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3425.8839
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3336.0266
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3278.6311
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3416.9815
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3314.8898
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3266.2276
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3168.0193
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3244.8186
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3303.6087
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3238.1666
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3232.4570
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3187.9667
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3172.4194
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3202.9440
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3232.2394
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3184.5906
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3221.6857
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3272.7895
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3211.3668
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3196.5416
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3176.1753
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3235.9740
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3177.6203
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815749 62.223654496526265 0.6703180911004046 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5497.8045
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 282.5485
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 75.5293
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 25.3988
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 10.0113
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4.2702
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.1202
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.2589
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.4189
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.4653
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.7666
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.3415
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.6784
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4.2883
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4.9059
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5.3311
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4.3947
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.2129
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5.0348
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7.4801
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1.9458
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4.1776
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.3590
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2.3595
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3.8185
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.10518451322389408 2.446829394536944 23.26225904880752 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 10936.0302
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3259.6886
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 3038.6052
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2974.7602
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2892.1153
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2864.1837
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2756.6396
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2750.8561
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2668.3943
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2635.1356
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2647.5081
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2592.4548
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2536.7527
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2532.4286
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2481.2020
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2469.2280
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2456.5169
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2409.1242
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2381.7473
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2405.7549
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2358.4677
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2373.9148
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2349.9910
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2319.6860
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2372.3574
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534436 49.39758162328352 0.4050664804023065 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 17335.5126
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8880.3651
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8411.6393
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8215.4617
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7992.3093
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8037.3122
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7804.6139
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8002.0208
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7913.3872
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7911.2428
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7643.1737
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7405.9877
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7783.5809
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7609.5933
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7410.1533
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7784.4451
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7768.8467
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7573.5787
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7464.4042
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7696.6586
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7533.8130
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7720.3667
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7518.3180
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7728.6840
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 7506.5358
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.4515947035800076 336.35952546169125 127.66350517722609 0.37954478917162693 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1655413.1050
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 479335.0883
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 428434.1427
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 396302.0957
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 395801.7482
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 367943.0737
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 369547.4950
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 361978.7991
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 367976.9059
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 345705.2003
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 352367.7567
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 348967.4900
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 352415.3486
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 340777.8718
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 354021.8415
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 358591.0509
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 348159.1158
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 344148.5338
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 359139.4647
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 344967.4634
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 350804.1441
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 351849.5474
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 338967.4637
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 343085.3283
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 337642.7584
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8130507458567988 2032.6741548164603 547.4576171283153 0.26932876370327435 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 2106711.2232
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1203233.8841
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1140229.5552
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1142640.6255
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1138277.4841
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1130688.8118
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1126071.0564
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1141686.1077
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1120084.0191
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1110261.8436
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1120252.8820
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1127053.8986
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1127643.0086
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1109298.2832
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1102050.7095
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1096696.1518
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1112426.1816
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1081533.7534
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1096804.5782
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1093550.2882
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1107447.2855
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1095509.9818
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1086074.6514
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1092065.3707
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 1095672.4364
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1171.8314727724544 0.7165737256485594 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 174488.4968
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 95707.5476
# Epoch 3/25
# 274/274 [==============================] - 1s 3ms/step - loss: 97133.9845
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 91306.4789
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 91754.5820
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 92805.9457
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 88744.4672
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 88967.0823
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84404.8266
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87447.4988
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84234.3978
# Epoch 12/25
# 274/274 [==============================] - 1s 2ms/step - loss: 89886.2046
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 88150.1043
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 85214.7193
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 86874.2960
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 86215.2491
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 85810.1294
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 85577.4591
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84987.0296
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84720.9344
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 87453.7387
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 84100.7218
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 83378.6984
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 83588.5852
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 89086.9462
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6928377753347054 712.0697702804412 283.2479852752585 0.39778122467367805 Eagle_education_Norah
# Building Eagle_education_Will
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 3ms/step - loss: 19019.5662
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10266.4601
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9437.5762
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9310.1574
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9802.4704
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9330.9916
# Epoch 7/25
# 274/274 [==============================] - 1s 3ms/step - loss: 10112.1692
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9629.0187
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9327.9428
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9649.9711
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9357.8388
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9232.9882
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9355.5442
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9385.9299
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9831.5895
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 8939.6523
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9422.4953
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9636.9431
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9162.5304
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9109.7324
# Epoch 21/25
# 274/274 [==============================] - 1s 3ms/step - loss: 9503.3317
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9526.7287
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9180.4750
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9835.0407
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 9173.2694
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.25485356247063 81.69187968376653 0.36106133591167716 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 6319.0092
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 832.3688
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 739.2581
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 701.1645
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 712.0663
# Epoch 6/25
# 274/274 [==============================] - 1s 2ms/step - loss: 681.6965
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 734.3888
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 689.7751
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 664.5622
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 675.7270
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 646.9482
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 647.8372
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 640.7386
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 638.9044
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 646.7984
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 658.6578
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 645.0019
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 655.0749
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 635.8993
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 644.6286
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 668.1472
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 635.4522
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 646.0568
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 650.5201
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 636.4550
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819895 35.327513136784354 0.6192357044403101 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 11819.8203
# Epoch 2/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5981.7240
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5806.2079
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5832.7238
# Epoch 5/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5804.1353
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5671.5705
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5663.7001
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5856.9948
# Epoch 9/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5575.8219
# Epoch 10/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5677.5775
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5581.5140
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5748.7484
# Epoch 13/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5645.9091
# Epoch 14/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5678.3037
# Epoch 15/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5682.7617
# Epoch 16/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5684.5436
# Epoch 17/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5763.5314
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5683.4494
# Epoch 19/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5632.5419
# Epoch 20/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5565.6099
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5544.1384
# Epoch 22/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5586.6023
# Epoch 23/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5668.0246
# Epoch 24/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5626.1715
# Epoch 25/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5541.5766
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157311 75.86415100321376 0.8311114957127446 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 24)                25368
# =================================================================
# Total params: 25,448
# Trainable params: 25,448
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 1s 2ms/step - loss: 14650.9196
# Epoch 2/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5554.1881
# Epoch 3/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5284.0115
# Epoch 4/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5003.9069
# Epoch 5/25
# 274/274 [==============================] - 1s 2ms/step - loss: 5144.9172
# Epoch 6/25
# 274/274 [==============================] - 1s 3ms/step - loss: 5007.3656
# Epoch 7/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4913.7597
# Epoch 8/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4925.1144
# Epoch 9/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4963.9573
# Epoch 10/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4785.3148
# Epoch 11/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4730.0732
# Epoch 12/25
# 274/274 [==============================] - 1s 3ms/step - loss: 4668.5290
# Epoch 13/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4753.4428
# Epoch 14/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4642.2935
# Epoch 15/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4673.2882
# Epoch 16/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4519.8393
# Epoch 17/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4675.8268
# Epoch 18/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4448.2166
# Epoch 19/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4531.8288
# Epoch 20/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4713.6006
# Epoch 21/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4544.6484
# Epoch 22/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4555.0395
# Epoch 23/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4588.6290
# Epoch 24/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4570.3859
# Epoch 25/25
# 274/274 [==============================] - 1s 2ms/step - loss: 4608.9283
# y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.50781927724552 64.3761920935774 0.433486885787442 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 24
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     547.46  0.27   Eagle_education_Sherrill
# -0.8011    3149.69     886.38  0.28   Eagle_education_Peter
# -0.7147     477.70     199.02  0.42   Eagle_health_Athena
# -0.6972    1197.84     359.81  0.30   Eagle_education_Roman
# -0.6928     712.07     283.25  0.40   Eagle_education_Norah
# -0.6191      57.05      35.33  0.62   Eagle_education_Petra
# -0.5975    1635.33    1171.83  0.72   Eagle_education_Brooke
# -0.5645     182.08      83.33  0.46   Eagle_public_Alvin
# -0.5301     148.51      64.38  0.43   Eagle_education_Teresa
# -0.5294      92.83      62.22  0.67   Eagle_lodging_Dawn
# -0.4636     121.95      49.40  0.41   Eagle_health_Vincenza
# -0.4516     336.36     127.66  0.38   Eagle_office_Francis
# -0.4243      91.28      75.86  0.83   Eagle_lodging_Trina
# -0.4210      81.97      68.33  0.83   Eagle_lodging_Edgardo
# -0.3226     226.25      81.69  0.36   Eagle_education_Will
#  0.4372       0.11       2.45 23.26   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 1.92 mean RMSE
# * 5.70 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.49 mean RMSE
# * 0.19 stddev
