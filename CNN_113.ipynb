# %% [markdown]
# # CNN  CoLab
# Based previous 24 hr, predict next 96 hr.
#
# Same as CNN 112 but predict 96 hr.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  96   # length of the predicted sequence

## CNN parameters
EPOCHS=25
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # Weather [0:24], steam [24:25]
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        print("y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 96)                101472
# =================================================================
# Total params: 101,552
# Trainable params: 101,552
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8712, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 1s 3ms/step - loss: 96860.5636
# Epoch 2/25
# 273/273 [==============================] - 1s 3ms/step - loss: 48451.8410
# Epoch 3/25
# 273/273 [==============================] - 1s 3ms/step - loss: 47283.8552
# Epoch 4/25
# 273/273 [==============================] - 1s 3ms/step - loss: 45390.2947
# Epoch 5/25
# 273/273 [==============================] - 1s 3ms/step - loss: 45535.9626
# Epoch 6/25
# 273/273 [==============================] - 1s 3ms/step - loss: 45354.1338
# Epoch 7/25
# 273/273 [==============================] - 1s 3ms/step - loss: 44982.9249
# Epoch 8/25
# 273/273 [==============================] - 1s 3ms/step - loss: 44672.6770
# Epoch 9/25
# 273/273 [==============================] - 1s 3ms/step - loss: 45282.3932
# Epoch 10/25
# 273/273 [==============================] - 1s 3ms/step - loss: 44771.9657
# Epoch 11/25
# 273/273 [==============================] - 1s 3ms/step - loss: 43997.5281
# Epoch 12/25
# 273/273 [==============================] - 1s 3ms/step - loss: 44794.0544
# Epoch 13/25
# 273/273 [==============================] - 1s 3ms/step - loss: 44651.2309
# Epoch 14/25
# 273/273 [==============================] - 1s 3ms/step - loss: 43722.3117
# Epoch 15/25
# y_pred.shape: (8712, 96)
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121304 393.45259654234343 0.32846951165721683 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 96)                101472
# =================================================================
# Total params: 101,552
# Trainable params: 101,552
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8712, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 1s 3ms/step - loss: 8485.6308
# Epoch 2/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4912.1816
# Epoch 3/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4823.7646
# Epoch 4/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4798.2323
# Epoch 5/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4685.6487
# Epoch 6/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4754.1124
# Epoch 7/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4737.8688
# Epoch 8/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4693.0242
# Epoch 9/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4696.9902
# Epoch 10/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4724.1650
# Epoch 11/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4600.2985
# Epoch 12/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4681.0410
# Epoch 13/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4749.0639
# Epoch 14/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4664.0825
# Epoch 15/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4652.5220
# Epoch 16/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4642.8398
# Epoch 17/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4652.7832
# Epoch 18/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4625.8847
# Epoch 19/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4620.1373
# Epoch 20/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4690.4052
# Epoch 21/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4624.6162
# Epoch 22/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4627.5186
# Epoch 23/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4558.5190
# Epoch 24/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4608.7617
# Epoch 25/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4588.8962
# y_pred.shape: (8712, 96)
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.9677919573641 69.21895059974234 0.8444652338048447 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 96)                101472
# =================================================================
# Total params: 101,552
# Trainable params: 101,552
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8712, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 1s 3ms/step - loss: 3469979.8417
# Epoch 2/25
# 273/273 [==============================] - 1s 3ms/step - loss: 1152507.7076
# Epoch 3/25
# 273/273 [==============================] - 1s 3ms/step - loss: 1030824.1848
# Epoch 4/25
# 273/273 [==============================] - 1s 3ms/step - loss: 1007910.8089
# Epoch 5/25
# 273/273 [==============================] - 1s 3ms/step - loss: 987446.2021
# Epoch 6/25
# 273/273 [==============================] - 1s 3ms/step - loss: 995260.8387
# Epoch 7/25
# 273/273 [==============================] - 1s 3ms/step - loss: 993831.4683
# Epoch 8/25
# 273/273 [==============================] - 1s 3ms/step - loss: 971765.7096
# Epoch 9/25
# 273/273 [==============================] - 1s 3ms/step - loss: 949636.4078
# Epoch 10/25
# 273/273 [==============================] - 1s 3ms/step - loss: 944867.2927
# Epoch 11/25
# 273/273 [==============================] - 1s 3ms/step - loss: 970232.0185
# Epoch 12/25
# 273/273 [==============================] - 1s 3ms/step - loss: 952353.2844
# Epoch 13/25
# 273/273 [==============================] - 1s 3ms/step - loss: 946532.2361
# Epoch 14/25
# 273/273 [==============================] - 1s 3ms/step - loss: 946427.6341
# Epoch 15/25
# 273/273 [==============================] - 1s 3ms/step - loss: 933997.1065
# Epoch 16/25
# 273/273 [==============================] - 1s 3ms/step - loss: 926791.3141
# Epoch 17/25
# 273/273 [==============================] - 1s 3ms/step - loss: 933064.7826
# Epoch 18/25
# 273/273 [==============================] - 1s 3ms/step - loss: 936772.6036
# Epoch 19/25
# 273/273 [==============================] - 1s 3ms/step - loss: 926595.3558
# Epoch 20/25
# 273/273 [==============================] - 1s 3ms/step - loss: 914101.1047
# Epoch 21/25
# 273/273 [==============================] - 1s 3ms/step - loss: 928136.0440
# Epoch 22/25
# 273/273 [==============================] - 1s 3ms/step - loss: 931280.1594
# Epoch 23/25
# 273/273 [==============================] - 1s 3ms/step - loss: 924011.8691
# Epoch 24/25
# 273/273 [==============================] - 1s 3ms/step - loss: 930096.2112
# Epoch 25/25
# 273/273 [==============================] - 1s 3ms/step - loss: 930906.9503
# y_pred.shape: (8712, 96)
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.6888831281212 978.3035179099589 0.3106032227977877 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 96)                101472
# =================================================================
# Total params: 101,552
# Trainable params: 101,552
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8712, 24, 8, 1)
# Epoch 1/25

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 96)                101472
# =================================================================
# Total params: 101,552
# Trainable params: 101,552
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8712, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 1s 3ms/step - loss: 7314.6299
# Epoch 2/25
# 273/273 [==============================] - 1s 3ms/step - loss: 1074.1574
# Epoch 3/25
# 273/273 [==============================] - 1s 3ms/step - loss: 887.7514
# Epoch 4/25
# 273/273 [==============================] - 1s 3ms/step - loss: 796.6003
# Epoch 5/25
# 273/273 [==============================] - 1s 3ms/step - loss: 786.1712
# Epoch 6/25
# 273/273 [==============================] - 1s 3ms/step - loss: 743.6477
# Epoch 7/25
# 273/273 [==============================] - 1s 3ms/step - loss: 739.5677
# Epoch 8/25
# 273/273 [==============================] - 1s 3ms/step - loss: 742.9224
# Epoch 9/25
# 273/273 [==============================] - 1s 3ms/step - loss: 743.4809
# Epoch 10/25
# 273/273 [==============================] - 1s 3ms/step - loss: 713.7695
# Epoch 11/25
# 273/273 [==============================] - 1s 3ms/step - loss: 741.0332
# Epoch 12/25
# 273/273 [==============================] - 1s 3ms/step - loss: 722.4227
# Epoch 13/25
# 273/273 [==============================] - 1s 3ms/step - loss: 733.4663
# Epoch 14/25
# 273/273 [==============================] - 1s 3ms/step - loss: 714.3627
# Epoch 15/25
# 273/273 [==============================] - 1s 3ms/step - loss: 706.4043
# Epoch 16/25
# 273/273 [==============================] - 1s 3ms/step - loss: 722.3250
# Epoch 17/25
# 273/273 [==============================] - 1s 3ms/step - loss: 699.0878
# Epoch 18/25
# 273/273 [==============================] - 1s 3ms/step - loss: 713.0935
# Epoch 19/25
# 273/273 [==============================] - 1s 3ms/step - loss: 712.8054
# Epoch 20/25
# 273/273 [==============================] - 1s 3ms/step - loss: 696.9927
# Epoch 21/25
# 273/273 [==============================] - 1s 3ms/step - loss: 697.1674
# Epoch 22/25
# 273/273 [==============================] - 1s 3ms/step - loss: 712.2022
# Epoch 23/25
# 273/273 [==============================] - 1s 3ms/step - loss: 713.7481
# Epoch 24/25
# 273/273 [==============================] - 1s 3ms/step - loss: 694.7908
# Epoch 25/25
# 273/273 [==============================] - 1s 4ms/step - loss: 699.3319
# y_pred.shape: (8712, 96)
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819895 36.42039598180034 0.6383922206599458 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 96)                101472
# =================================================================
# Total params: 101,552
# Trainable params: 101,552
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8712, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 1s 3ms/step - loss: 14254.4647
# Epoch 2/25
# 273/273 [==============================] - 1s 3ms/step - loss: 6543.2604
# Epoch 3/25
# 273/273 [==============================] - 1s 3ms/step - loss: 6246.9104
# Epoch 4/25
# 273/273 [==============================] - 1s 3ms/step - loss: 6027.3944
# Epoch 5/25
# 273/273 [==============================] - 1s 3ms/step - loss: 6031.9689
# 273/273 [==============================] - 1s 3ms/step - loss: 4984.6844
# Epoch 11/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4947.7574
# Epoch 12/25
# 273/273 [==============================] - 1s 3ms/step - loss: 5110.6332
# Epoch 13/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4796.2686
# Epoch 14/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4832.1503
# Epoch 15/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4911.4581
# Epoch 16/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4835.3064
# Epoch 17/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4867.5904
# Epoch 18/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4890.2056
# Epoch 19/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4767.0211
# Epoch 20/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4709.6766
# Epoch 21/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4875.9691
# Epoch 22/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4812.6839
# Epoch 23/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4742.4412
# Epoch 24/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4984.1364
# Epoch 25/25
# 273/273 [==============================] - 1s 3ms/step - loss: 4722.3723
# y_pred.shape: (8712, 96)
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.50781927724552 64.03960195943567 0.43122040489923125 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 96
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67     660.38  0.32   Eagle_education_Sherrill
# -0.8011    3149.69     978.30  0.31   Eagle_education_Peter
# -0.7147     477.70     207.96  0.44   Eagle_health_Athena
# -0.6972    1197.84     393.45  0.33   Eagle_education_Roman
# -0.6928     712.07     317.71  0.45   Eagle_education_Norah
# -0.6191      57.05      36.42  0.64   Eagle_education_Petra
# -0.5975    1635.33    1192.01  0.73   Eagle_education_Brooke
# -0.5645     182.08      78.60  0.43   Eagle_public_Alvin
# -0.5301     148.51      64.04  0.43   Eagle_education_Teresa
# -0.5294      92.83      61.61  0.66   Eagle_lodging_Dawn
# -0.4636     121.95      50.22  0.41   Eagle_health_Vincenza
# -0.4516     336.36     149.74  0.45   Eagle_office_Francis
# -0.4243      91.28      77.14  0.85   Eagle_lodging_Trina
# -0.4210      81.97      69.22  0.84   Eagle_lodging_Edgardo
# -0.3226     226.25      91.64  0.41   Eagle_education_Will
#  0.4372       0.11       1.39 13.20   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Summary results.
#
# * 1.31 mean RMSE
# * 3.18 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.51 mean RMSE
# * 0.18 stddev
