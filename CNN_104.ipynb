# %% [markdown]
# # CNN
# Start with the LSTM 104 notebook.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  1    # length of the predicted sequence

## CNN parameters
EPOCHS=5
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    # This is very slow. Is there a faster way? See...
    # https://stackoverflow.com/questions/27852343/split-python-sequence-time-series-array-into-subsequences-with-overlap
    # This didn't work: np.atleast_1d(p) 
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,1)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
    return X,y

# %%
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        print("Train on",len(X_train),"samples...")
        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        # Compare. Solve the problem that predict.shape != truth.shape 
        #print(" before ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        #nsamples, nsteps, ndim = y_test.shape
        #y_test = y_test.reshape(nsamples,nsteps*ndim)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        ##print(" after ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)

        ## break   ## REMOVE THIS LINE TO LOOP OVER BUILDINGS!
        
if True:
    print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
    print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
    print("          Using one weather feature as leading correlate.")
    print("Column 2: Mean usage.")
    print("          Using mean to help understand the RMSE.")
    print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
    print("Column 4: RMSE/mean normalized to help understand RMSE.")
    print("Column 5: Building.")
    for cor in sorted(cors):
        print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 1566.5135
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 25.9529
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 15.2722
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 12.4948
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 11.3136
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545475 2.463066129932456 0.005159214592695886 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 6653.1322
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 9.0451
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 7.4166
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 7.1613
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 6.3171
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500085 3.112154046293806 0.017105418905082187 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 5ms/step - loss: 4614.0545
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 12.1922
# Epoch 3/5
# 274/274 [==============================] - 2s 6ms/step - loss: 10.7748
# Epoch 4/5
# 274/274 [==============================] - 3s 12ms/step - loss: 10.6828
# Epoch 5/5
# 274/274 [==============================] - 2s 7ms/step - loss: 10.1585
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.016015073252 3.5377215907565533 0.002955450508772066 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 586.2626
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 11.3357
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 9.6690
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 7.9015
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 8.2799
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264256 1.6993527386573122 0.020756291264462406 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 4334.6195
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 7.5720
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 6.1459
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 5.5486
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.2109
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.430703431568 1.9246143183875168 0.0006114874320470841 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 891.5614
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 9.9719
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.6898
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 4.3455
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 4.8022
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606874 1.5641747028540585 0.016867172801711596 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 1360.1000
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 16.4680
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 10.4352
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 7.3131
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 7.0850
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135475 2.8006864849449085 26.61459029714843 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 2074.4294
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 19.4518
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 12.8963
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 9.4296
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 7.0532
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508735 1.9186109036821555 0.015738135259698922 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 27285.5040
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 32.3452
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 21.5847
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 14.6812
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 15.5655
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.9563635497514 3.750699846844084 0.011164247068320964 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1056)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 3731.4242
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 13.3734
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 9.6598
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 6.9331
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 5.9628
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358292 1.8499862966773535 0.0009111622572395527 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 580.5018
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 19.3620
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 11.9976
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 9.8593
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 8.7304
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547193 2.14865992690253 0.0013147436683697052 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 1281.6846
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 35.7376
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 15.1443
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 8.8333
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 9.0609
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245889 1.8758591738408044 0.0026371116411356248 Eagle_education_Norah
# Building Eagle_education_Will
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 3ms/step - loss: 3218.7777
# Epoch 2/5
# 274/274 [==============================] - 1s 3ms/step - loss: 24.4592
# Epoch 3/5
# 274/274 [==============================] - 1s 3ms/step - loss: 17.8378
# Epoch 4/5
# 274/274 [==============================] - 1s 3ms/step - loss: 13.0490
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 10.3459
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769716 2.52594205919975 0.01117329927749848 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5120.2010
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 24.1288
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 15.4567
# Epoch 4/5
# 274/274 [==============================] - 1s 5ms/step - loss: 10.8570
# Epoch 5/5
# 274/274 [==============================] - 1s 5ms/step - loss: 7.6493
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.96274977501869 2.309193918986573 0.040538666551509804 Eagle_education_Petra
# Building Eagle_lodging_Trina
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 6ms/step - loss: 419.6891
# Epoch 2/5
# 274/274 [==============================] - 2s 6ms/step - loss: 10.6800
# Epoch 3/5
# 274/274 [==============================] - 2s 7ms/step - loss: 8.4256
# Epoch 4/5
# 274/274 [==============================] - 2s 6ms/step - loss: 6.8987
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.4919
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551768 2.4787737861229577 0.027180457000586807 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6350.8650
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.8089
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.0645
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.1712
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.0814
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033823 1.6444011227375945 0.011072858496672321 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36       1.85  0.00   Eagle_education_Sherrill
# -0.8545    1634.28       2.15  0.00   Eagle_education_Brooke
# -0.8502    3147.43       1.92  0.00   Eagle_education_Peter
# -0.8403     477.41       2.46  0.01   Eagle_health_Athena
# -0.8186    1197.02       3.54  0.00   Eagle_education_Roman
# -0.7988      56.96       2.31  0.04   Eagle_education_Petra
# -0.7961     121.91       1.92  0.02   Eagle_health_Vincenza
# -0.7722     711.33       1.88  0.00   Eagle_education_Norah
# -0.7596     181.94       3.11  0.02   Eagle_public_Alvin
# -0.7222      81.87       1.70  0.02   Eagle_lodging_Edgardo
# -0.7130      92.73       1.56  0.02   Eagle_lodging_Dawn
# -0.6796     148.51       1.64  0.01   Eagle_education_Teresa
# -0.6741      91.20       2.48  0.03   Eagle_lodging_Trina
# -0.5553     335.96       3.75  0.01   Eagle_office_Francis
# -0.3579     226.07       2.53  0.01   Eagle_education_Will
#  0.7231       0.11       2.80 26.61   Eagle_education_Wesley

# %% [markdown]
# ## Useful Links
#
# Jason Brownlee
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
# https://machinelearningmastery.com/suitability-long-short-term-memory-networks-time-series-forecasting/
# https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/
