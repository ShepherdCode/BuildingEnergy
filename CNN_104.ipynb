# %% [markdown]
# # CNN
# Start with the LSTM 104 notebook.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %%
SITE = 'Eagle'
METER = 'steam'
BLDG = 'Eagle_education_Peter'   # one example
PREDICTOR_VARIABLE = 'airTemperature'  # for starters
PREDICTED_VARIABLE = 'steam'  # for starters

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
DOWNSAMPLE = False   # if true, use 1 time per day, else 24 times per day
STEPS_HISTORY = 24 
STEPS_FUTURE =  1    
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

PREDICTORS = [x for x in wet_df.columns if not x=='site_id']
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)
def prepare_for_learning(df):
    # This is very slow. Is there a faster way? See...
    # https://stackoverflow.com/questions/27852343/split-python-sequence-time-series-array-into-subsequences-with-overlap
    # This didn't work: np.atleast_1d(p) 
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,1)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
    return X,y
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
# input_shape = (features,steps,channels)
# Use all 8 features from weather table. (Later, add steam.)
# First, use just one weather feature: air temp.
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1) 
def make_CNN():
    print("make_CNN")
    print("input shape:",INPUT_SHAPE)
    cnn = Sequential()
    cnn.add(
        Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    cnn.add(Flatten())
    cnn.add(Dense(STEPS_FUTURE))   
    cnn.compile(optimizer='adam',loss=MeanSquaredError())
    return cnn

# %%
cors = []
EPOCHS=5
# Test on only Peter just during code development
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        print("Train on",len(X_train),"samples...")
        model = make_CNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        # Compare. Solve the problem that predict.shape != truth.shape 
        #print(" before ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        #nsamples, nsteps, ndim = y_test.shape
        #y_test = y_test.reshape(nsamples,nsteps*ndim)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        ##print(" after ytestshape",y_test.shape,"ypredshape",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][PREDICTOR_VARIABLE] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)

        ## break   ## REMOVE THIS LINE TO LOOP OVER BUILDINGS!
        
if True:
    print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
    print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",PREDICTOR_VARIABLE)
    print("          Using one weather feature as leading correlate.")
    print("Column 2: Mean usage.")
    print("          Using mean to help understand the RMSE.")
    print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
    print("Column 4: RMSE/mean normalized to help understand RMSE.")
    print("Column 5: Building.")
    for cor in sorted(cors):
        print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 2s 4ms/step - loss: 2189.4088
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 24.8521
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 13.6980
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.4947
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.5705
# cor,mean,rmse,rmse/mean,bldg: -0.849214848008229 477.4110643545475 1.7411568757222529 0.00364708111253406 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2814.0987
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.6530
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.0767
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.2988
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.4101
# cor,mean,rmse,rmse/mean,bldg: -0.755524810622147 181.93965687500085 2.2423133107723325 0.012324489060199137 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 346.0844
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.3126
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.3755
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.2446
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.6149
# cor,mean,rmse,rmse/mean,bldg: -0.8040385849969112 1197.016015073252 2.7651275309705694 0.0023100171561208026 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4399.7307
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.7146
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3.5554
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2.5857
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 2.3156
# cor,mean,rmse,rmse/mean,bldg: -0.7661481928706323 81.87169456264256 1.1610366580338023 0.014181172922290711 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 499.6930
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3.9703
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 3.9085
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.3735
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.5961
# cor,mean,rmse,rmse/mean,bldg: -0.8267485430759834 3147.430703431568 3.713464953587673 0.0011798400992717557 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_23 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4081.5436
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 30.3982
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 26.4586
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 19.1544
# Epoch 5/5
# 274/274 [==============================] - 1s 3ms/step - loss: 17.2370
# cor,mean,rmse,rmse/mean,bldg: -0.7248890899079364 92.73484781606874 4.044948446537253 0.04361842976827919 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 360.2851
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 12.6418
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.5707
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7.6171
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.4766
# cor,mean,rmse,rmse/mean,bldg: 0.7078518941773995 0.10523124548135475 1.6420562469387159 15.604265058610006 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 707.1639
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 18.8036
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 12.7585
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 13.0076
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10.9331
# cor,mean,rmse,rmse/mean,bldg: -0.8217409529348659 121.90840096508735 2.0757450032947933 0.017027087443212827 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4402.9233
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 74.5483
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 24.3242
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10.8485
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7.9229
# cor,mean,rmse,rmse/mean,bldg: -0.612183884934729 335.9563635497514 2.2189677930811182 0.00660492859737873 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 386.8909
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 15.9713
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 9.2453
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.0968
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.7925
# cor,mean,rmse,rmse/mean,bldg: -0.9191698832911114 2030.3587884358292 1.3429693087275516 0.0006614443301236249 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4343.1024
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 6.4002
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 5.9094
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.0209
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 4.1235
# cor,mean,rmse,rmse/mean,bldg: -0.8668943529930063 1634.2804902547193 2.0225429915766258 0.0012375739682613427 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 884.1829
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 15.3886
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 14.2660
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 13.0559
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 9.9771
# cor,mean,rmse,rmse/mean,bldg: -0.8006961414633348 711.3309670245889 4.4804276461396615 0.006298654007544121 Eagle_education_Norah
# Building Eagle_education_Will
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 2ms/step - loss: 556.3489
# Epoch 2/5
# 274/274 [==============================] - 1s 2ms/step - loss: 17.9717
# Epoch 3/5
# 274/274 [==============================] - 1s 2ms/step - loss: 14.7181
# Epoch 4/5
# 274/274 [==============================] - 1s 2ms/step - loss: 10.2868
# Epoch 5/5
# 274/274 [==============================] - 1s 2ms/step - loss: 15.2805
# cor,mean,rmse,rmse/mean,bldg: -0.3432541996930441 226.06948909769716 5.307922131944759 0.023479161885710774 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 23545.7072
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 15.7937
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8.8228
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 8.5295
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 7.4370
# cor,mean,rmse,rmse/mean,bldg: -0.8318744067272149 56.96274977501869 2.240191604207685 0.03932730798733548 Eagle_education_Petra
# Building Eagle_lodging_Trina
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 1564.5299
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 27.3379
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 19.1345
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 14.6144
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 13.8183
# cor,mean,rmse,rmse/mean,bldg: -0.7102555423632535 91.19691350551768 2.8194478657659525 0.030916044824207428 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# Train on 8747 samples...
# make_CNN
# input shape: (24, 8, 1)
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 1056)              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 1057
# =================================================================
# Total params: 1,137
# Trainable params: 1,137
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/5
# 274/274 [==============================] - 1s 4ms/step - loss: 677.8024
# Epoch 2/5
# 274/274 [==============================] - 1s 4ms/step - loss: 18.3153
# Epoch 3/5
# 274/274 [==============================] - 1s 4ms/step - loss: 14.0100
# Epoch 4/5
# 274/274 [==============================] - 1s 4ms/step - loss: 10.4007
# Epoch 5/5
# 274/274 [==============================] - 1s 4ms/step - loss: 12.2003
# cor,mean,rmse,rmse/mean,bldg: -0.730241336157007 148.50737262033823 8.119119250497059 0.05467148941658091 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
# History 24 Future 1
# Column 1: Correlation of steam and airTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.9192    2030.36       1.34  0.00   Eagle_education_Sherrill
# -0.8669    1634.28       2.02  0.00   Eagle_education_Brooke
# -0.8492     477.41       1.74  0.00   Eagle_health_Athena
# -0.8319      56.96       2.24  0.04   Eagle_education_Petra
# -0.8267    3147.43       3.71  0.00   Eagle_education_Peter
# -0.8217     121.91       2.08  0.02   Eagle_health_Vincenza
# -0.8040    1197.02       2.77  0.00   Eagle_education_Roman
# -0.8007     711.33       4.48  0.01   Eagle_education_Norah
# -0.7661      81.87       1.16  0.01   Eagle_lodging_Edgardo
# -0.7555     181.94       2.24  0.01   Eagle_public_Alvin
# -0.7302     148.51       8.12  0.05   Eagle_education_Teresa
# -0.7249      92.73       4.04  0.04   Eagle_lodging_Dawn
# -0.7103      91.20       2.82  0.03   Eagle_lodging_Trina
# -0.6122     335.96       2.22  0.01   Eagle_office_Francis
# -0.3433     226.07       5.31  0.02   Eagle_education_Will
#  0.7079       0.11       1.64 15.60   Eagle_education_Wesley

# %% [markdown]
# ## Useful Links
#
# Jason Brownlee
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
# https://machinelearningmastery.com/suitability-long-short-term-memory-networks-time-series-forecasting/
# https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/
