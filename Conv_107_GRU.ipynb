# %% [markdown]
# # CNN + GRU CoLab
# Based on Conv_106, but predict next 42 hours instead of next 1 hour.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import TimeDistributed

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24   # length of the predicted sequence

## CNN parameters
EPOCHS=25  # use 1 for testing, 25 for production
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(Conv2D(
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(MaxPooling2D())
    dnn.add(TimeDistributed(Flatten()))
    dnn.add(GRU(8,return_sequences=True))
    dnn.add(GRU(8,return_sequences=False))
    dnn.add(Dense(STEPS_FUTURE))   
    dnn.compile(optimizer='adam',loss=MeanSquaredError())
    dnn.build(input_shape=INPUT_SHAPE)
    return dnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_DNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)        
        print("Raw y_pred.shape:",y_pred.shape)
        #nsamples, nsteps, ndim = y_pred.shape
        #y_pred = y_pred.reshape(nsamples,nsteps*ndim)
        #print("Reshaped y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 16)            0
# _________________________________________________________________
# gru (GRU)                    (None, 10, 8)             624
# _________________________________________________________________
# gru_1 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense (Dense)                (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 6s 9ms/step - loss: 342725.1054
# Epoch 2/25
# 273/273 [==============================] - 3s 9ms/step - loss: 339652.6897
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 336718.6754
# Epoch 4/25
# 273/273 [==============================] - 3s 9ms/step - loss: 331085.9513
# Epoch 5/25
# 273/273 [==============================] - 3s 9ms/step - loss: 328104.2844
# Epoch 6/25
# 273/273 [==============================] - 3s 9ms/step - loss: 325409.0757
# Epoch 7/25
# 273/273 [==============================] - 3s 9ms/step - loss: 319399.5713
# Epoch 8/25
# 273/273 [==============================] - 3s 9ms/step - loss: 323140.4853
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 321665.4137
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 321221.6389
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 311909.7371
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 310273.4688
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 311761.3807
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 310708.4629
# Epoch 15/25
# 273/273 [==============================] - 3s 10ms/step - loss: 306415.7264
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 304151.9487
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 303162.4980
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 300425.5770
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 299980.0083
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 296304.8696
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 296998.3460
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 288308.6376
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 287253.4628
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 286444.0797
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 283414.6580
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545472 424.9383306208076 0.8900889869306193 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_3 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 9ms/step - loss: 52830.9283
# Epoch 2/25
# 273/273 [==============================] - 2s 9ms/step - loss: 51633.8734
# Epoch 3/25
# 273/273 [==============================] - 3s 9ms/step - loss: 50829.5370
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 50722.6080
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 48900.1719
# Epoch 6/25
# 273/273 [==============================] - 3s 9ms/step - loss: 48471.6400
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 47568.3238
# Epoch 8/25
# 273/273 [==============================] - 3s 9ms/step - loss: 46656.5104
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 45768.3827
# Epoch 10/25
# 273/273 [==============================] - 3s 9ms/step - loss: 43743.7770
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 43149.8534
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 43044.8287
# Epoch 13/25
# 273/273 [==============================] - 3s 9ms/step - loss: 41397.5099
# Epoch 14/25
# 273/273 [==============================] - 3s 9ms/step - loss: 40679.0431
# Epoch 15/25
# 273/273 [==============================] - 3s 9ms/step - loss: 39409.8509
# Epoch 16/25
# 273/273 [==============================] - 3s 9ms/step - loss: 39037.1376
# Epoch 17/25
# 273/273 [==============================] - 3s 9ms/step - loss: 38333.2124
# Epoch 18/25
# 273/273 [==============================] - 3s 9ms/step - loss: 38071.1036
# Epoch 19/25
# 273/273 [==============================] - 3s 9ms/step - loss: 36778.6723
# Epoch 20/25
# 273/273 [==============================] - 3s 9ms/step - loss: 36219.8022
# Epoch 21/25
# 273/273 [==============================] - 3s 9ms/step - loss: 34619.8847
# Epoch 22/25
# 273/273 [==============================] - 3s 9ms/step - loss: 35011.8114
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 32800.8766
# Epoch 24/25
# 273/273 [==============================] - 3s 9ms/step - loss: 32991.0254
# Epoch 25/25
# 273/273 [==============================] - 3s 9ms/step - loss: 32511.7346
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500068 107.85784692099575 0.592822086034262 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_4 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_5 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 9ms/step - loss: 1668927.0374
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1671399.3572
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1662783.9475
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1634147.4252
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1644842.8426
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1619349.0639
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1629337.7505
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1619349.7308
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1622649.5091
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1621397.6870
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1594251.5552
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1581266.3266
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1584407.5958
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1596460.9754
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1595279.1086
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1588584.1305
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1571033.2030
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1558143.6496
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1573337.2719
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1551384.6921
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1560285.2140
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1524496.6300
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1535863.9562
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1552450.4220
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 1507311.9745
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.0160150732597 1200.6925555400758 1.0030714212846943 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_6 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_7 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 8932.6404
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 8303.4186
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7948.4211
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7567.1354
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7020.2010
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6760.7543
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6610.2680
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6239.9490
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5850.6857
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5733.4505
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5410.5899
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5068.0720
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4927.7358
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4860.3738
# Epoch 15/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4465.7361
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4222.8679
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4030.5295
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3933.9139
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3745.8499
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3558.7499
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3444.5850
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3340.3172
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3223.2539
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3064.8995
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 2888.2584
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264219 49.19375752379073 0.6008640444855003 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_8 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_9 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 13006107.0730
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12541718.1131
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12802300.4745
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12871777.8577
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12895048.1131
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12506762.0438
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12838036.9015
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12714145.9197
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12738738.2299
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12813698.6752
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12541172.8358
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12430733.6095
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12389267.5073
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12554272.6277
# Epoch 15/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12401601.5438
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12538921.0073
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12457752.0182
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12579550.7628
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12569723.3066
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12762128.6022
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12476133.5365
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12591039.7226
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12254814.5876
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12417637.1752
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12508601.1569
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.4307034315702 3151.901046380511 1.0014203149712135 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_10 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_11 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 13081.9296
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12590.5920
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 11871.3241
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 11808.9143
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 11052.1971
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 10592.1119
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 10360.8177
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 10042.7039
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 9635.9761
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 9346.9004
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 8657.5788
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 8389.0531
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 8227.4424
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7780.3340
# Epoch 15/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7454.8651
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7160.4311
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6929.0229
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6522.3933
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6337.4250
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6303.1578
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6043.4350
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5652.5820
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5426.8232
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5294.8802
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5090.0184
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606884 55.635735206066414 0.5999442120875084 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_12 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_13 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 0.0235
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3417e-04
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3412e-04
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.2840e-04
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.4133e-04
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.2600e-04
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3054e-04
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3418e-04
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.4303e-04
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3812e-04
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.4229e-04
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3297e-04
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3947e-04
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.4234e-04
# Epoch 15/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.2916e-04
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3293e-04
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3912e-04
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3396e-04
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3419e-04
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3572e-04
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.3562e-04
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 3.4993e-04
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.4051e-04
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 3.4431e-04
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 3.3865e-04
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135511 0.02986352189762316 0.28378949390002595 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_14 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_15 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 15605.7947
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 14961.9465
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 14501.0347
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 13950.7102
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 13507.4382
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12809.1812
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 12325.9348
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 11831.3053
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 11355.6725
# Epoch 10/25
# 273/273 [==============================] - 3s 11ms/step - loss: 10732.9074
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 10612.4814
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 10081.5032
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 9879.2212
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 9330.0514
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 8854.9208
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 8424.8185
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 8099.2908
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 7867.6520
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7353.4139
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 7158.4257
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 6766.7395
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6361.0479
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 6140.7243
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5862.6311
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5697.4121
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508708 74.74709551371429 0.6131414645912782 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_16 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_17 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 6s 10ms/step - loss: 87500.5411
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 84689.2076
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 83858.5762
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 81064.8351
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 80336.0910
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 79666.4326
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 78286.0766
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 77170.0175
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 75729.9030
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 73820.1166
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 73060.7566
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 72235.8784
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 70640.6842
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 69878.7008
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 68101.9267
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 66753.2772
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 64834.1094
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 64646.7024
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 63684.8909
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 61772.4405
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 61650.4396
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 60215.4663
# Epoch 23/25
# 273/273 [==============================] - 3s 10ms/step - loss: 58753.7064
# Epoch 24/25
# 273/273 [==============================] - 3s 10ms/step - loss: 58439.4426
# Epoch 25/25
# 273/273 [==============================] - 3s 10ms/step - loss: 56534.7247
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.95636354975403 338.1946284399543 1.0066623678937063 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_18 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_19 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_9 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 5315642.2354
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5487766.5292
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5269765.0109
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5400658.2135
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5299537.5265
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5250226.6442
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5310635.1588
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5314348.1022
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5221351.2518
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5283960.2318
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5248173.8266
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5286013.0036
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5234647.7427
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5229264.4662
# Epoch 15/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5169243.7299
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5194273.3522
# Epoch 17/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5184226.5082
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5131138.3139
# Epoch 19/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5131496.6460
# Epoch 20/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5213900.9142
# Epoch 21/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5134696.6971
# Epoch 22/25
# 273/273 [==============================] - 3s 10ms/step - loss: 5160876.2518
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5043434.1761
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5000869.8960
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5104932.0894
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358317 2185.9019929571314 1.0766087281751462 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_20 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_21 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_10 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 6s 10ms/step - loss: 4460887.0511
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4355345.4808
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4398144.4927
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4445915.8139
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4347050.3905
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4352230.6551
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4313019.5611
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4344667.7327
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4285340.8120
# Epoch 10/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4315005.4024
# Epoch 11/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4277307.7956
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 4229735.2865
# Epoch 13/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4317721.7016
# Epoch 14/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4326733.5748
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4232708.4206
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4292385.3759
# Epoch 17/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4281421.2226
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4139626.8841
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4186482.8385
# Epoch 20/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4214653.8193
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4176275.0100
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4194122.7345
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4207336.4170
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4160816.3869
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4079842.8604
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547134 1646.7505850131697 1.0076303271273297 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_22 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_23 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_11 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 10ms/step - loss: 601167.7183
# Epoch 2/25
# 273/273 [==============================] - 3s 10ms/step - loss: 587206.9062
# Epoch 3/25
# 273/273 [==============================] - 3s 10ms/step - loss: 596379.3853
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 601713.2594
# Epoch 5/25
# 273/273 [==============================] - 3s 10ms/step - loss: 592927.3329
# Epoch 6/25
# 273/273 [==============================] - 3s 11ms/step - loss: 578070.2110
# Epoch 7/25
# 273/273 [==============================] - 3s 10ms/step - loss: 585249.1750
# Epoch 8/25
# 273/273 [==============================] - 3s 10ms/step - loss: 576577.7963
# Epoch 9/25
# 273/273 [==============================] - 3s 10ms/step - loss: 588788.8736
# Epoch 10/25
# 273/273 [==============================] - 3s 10ms/step - loss: 577998.7087
# Epoch 11/25
# 273/273 [==============================] - 3s 10ms/step - loss: 569773.3810
# Epoch 12/25
# 273/273 [==============================] - 3s 10ms/step - loss: 567836.0598
# Epoch 13/25
# 273/273 [==============================] - 3s 10ms/step - loss: 572453.5214
# Epoch 14/25
# 273/273 [==============================] - 3s 10ms/step - loss: 557586.5260
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 550808.5893
# Epoch 16/25
# 273/273 [==============================] - 3s 10ms/step - loss: 558797.9877
# Epoch 17/25
# 273/273 [==============================] - 3s 11ms/step - loss: 553596.9759
# Epoch 18/25
# 273/273 [==============================] - 3s 10ms/step - loss: 547723.0539
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 552898.5681
# Epoch 20/25
# 273/273 [==============================] - 3s 11ms/step - loss: 545227.9998
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 549156.9857
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 527910.4637
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 533074.7799
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 535418.2527
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 525663.5817
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245861 777.2423025495362 1.0926591679266398 Eagle_education_Norah
# Building Eagle_education_Will
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_24 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_25 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_12 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 11ms/step - loss: 76548.5123
# Epoch 2/25
# 273/273 [==============================] - 3s 11ms/step - loss: 75616.0974
# Epoch 3/25
# 273/273 [==============================] - 3s 11ms/step - loss: 73374.9294
# Epoch 4/25
# 273/273 [==============================] - 3s 11ms/step - loss: 71790.4082
# Epoch 5/25
# 273/273 [==============================] - 3s 11ms/step - loss: 71344.6299
# Epoch 6/25
# 273/273 [==============================] - 3s 11ms/step - loss: 70457.7588
# Epoch 7/25
# 273/273 [==============================] - 3s 11ms/step - loss: 69851.9557
# Epoch 8/25
# 273/273 [==============================] - 3s 11ms/step - loss: 67511.2215
# Epoch 9/25
# 273/273 [==============================] - 3s 11ms/step - loss: 66541.6565
# Epoch 10/25
# 273/273 [==============================] - 3s 11ms/step - loss: 66102.2844
# Epoch 11/25
# 273/273 [==============================] - 3s 11ms/step - loss: 64476.5900
# Epoch 12/25
# 273/273 [==============================] - 3s 11ms/step - loss: 63934.8527
# Epoch 13/25
# 273/273 [==============================] - 3s 11ms/step - loss: 62482.4241
# Epoch 14/25
# 273/273 [==============================] - 3s 11ms/step - loss: 60871.4465
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 59961.0110
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 59145.1941
# Epoch 17/25
# 273/273 [==============================] - 3s 11ms/step - loss: 57650.3650
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 55767.5644
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 55312.6887
# Epoch 20/25
# 273/273 [==============================] - 3s 11ms/step - loss: 54274.2807
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 53210.9398
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 52916.1451
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 50831.4291
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 50618.1424
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 49665.9072
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769736 134.37389376698678 0.5943919911674426 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_26 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_27 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_13 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 6s 10ms/step - loss: 4319.6504
# Epoch 2/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4027.3348
# Epoch 3/25
# 273/273 [==============================] - 3s 11ms/step - loss: 3716.1034
# Epoch 4/25
# 273/273 [==============================] - 3s 11ms/step - loss: 3434.6931
# Epoch 5/25
# 273/273 [==============================] - 3s 11ms/step - loss: 3295.7592
# Epoch 6/25
# 273/273 [==============================] - 3s 11ms/step - loss: 3041.9859
# Epoch 7/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2825.9669
# Epoch 8/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2696.8538
# Epoch 9/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2556.3284
# Epoch 10/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2435.2593
# Epoch 11/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2324.8188
# Epoch 12/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2132.0989
# Epoch 13/25
# 273/273 [==============================] - 3s 11ms/step - loss: 2036.0880
# Epoch 14/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1965.3914
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1887.0739
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1765.8702
# Epoch 17/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1632.3188
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1605.1184
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1468.4898
# Epoch 20/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1457.3290
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1384.8385
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1367.5859
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1240.0819
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1293.8463
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 1256.0660
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.9627497750187 29.830765579347325 0.5236890019735275 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_28 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_29 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 5s 11ms/step - loss: 11788.8161
# Epoch 2/25
# 273/273 [==============================] - 3s 11ms/step - loss: 11086.1819
# Epoch 3/25
# 273/273 [==============================] - 3s 11ms/step - loss: 10971.7786
# Epoch 4/25
# 273/273 [==============================] - 3s 11ms/step - loss: 10112.6646
# Epoch 5/25
# 273/273 [==============================] - 3s 11ms/step - loss: 9855.6296
# Epoch 6/25
# 273/273 [==============================] - 3s 11ms/step - loss: 9249.6475
# Epoch 7/25
# 273/273 [==============================] - 3s 11ms/step - loss: 9167.8107
# Epoch 8/25
# 273/273 [==============================] - 3s 11ms/step - loss: 8792.6135
# Epoch 9/25
# 273/273 [==============================] - 3s 11ms/step - loss: 8700.6533
# Epoch 10/25
# 273/273 [==============================] - 3s 11ms/step - loss: 8403.4267
# Epoch 11/25
# 273/273 [==============================] - 3s 11ms/step - loss: 8332.9175
# Epoch 12/25
# 273/273 [==============================] - 3s 11ms/step - loss: 7733.2522
# Epoch 13/25
# 273/273 [==============================] - 3s 11ms/step - loss: 7310.8635
# Epoch 14/25
# 273/273 [==============================] - 3s 11ms/step - loss: 7338.9925
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 7077.8662
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 6705.5451
# Epoch 17/25
# 273/273 [==============================] - 3s 11ms/step - loss: 6640.4773
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 6120.3687
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 6017.2606
# Epoch 20/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5955.1491
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5973.9346
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5852.3997
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5675.3483
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 5179.3227
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 4900.4857
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551751 55.80271784635821 0.6118926145782564 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_30 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_31 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_15 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8736, 24, 8, 1)
# Epoch 1/25
# 273/273 [==============================] - 6s 11ms/step - loss: 29294.8842
# Epoch 2/25
# 273/273 [==============================] - 3s 11ms/step - loss: 28452.5051
# Epoch 3/25
# 273/273 [==============================] - 3s 11ms/step - loss: 27716.0234
# Epoch 4/25
# 273/273 [==============================] - 3s 10ms/step - loss: 27365.8689
# Epoch 5/25
# 273/273 [==============================] - 3s 11ms/step - loss: 26290.8760
# Epoch 6/25
# 273/273 [==============================] - 3s 10ms/step - loss: 25598.5735
# Epoch 7/25
# 273/273 [==============================] - 3s 11ms/step - loss: 25090.1503
# Epoch 8/25
# 273/273 [==============================] - 3s 11ms/step - loss: 23964.8524
# Epoch 9/25
# 273/273 [==============================] - 3s 11ms/step - loss: 23387.1845
# Epoch 10/25
# 273/273 [==============================] - 3s 11ms/step - loss: 23047.1607
# Epoch 11/25
# 273/273 [==============================] - 3s 11ms/step - loss: 22704.5258
# Epoch 12/25
# 273/273 [==============================] - 3s 11ms/step - loss: 21979.6900
# Epoch 13/25
# 273/273 [==============================] - 3s 11ms/step - loss: 20857.9946
# Epoch 14/25
# 273/273 [==============================] - 3s 11ms/step - loss: 21063.1422
# Epoch 15/25
# 273/273 [==============================] - 3s 11ms/step - loss: 19853.5252
# Epoch 16/25
# 273/273 [==============================] - 3s 11ms/step - loss: 19217.4801
# Epoch 17/25
# 273/273 [==============================] - 3s 11ms/step - loss: 19207.2131
# Epoch 18/25
# 273/273 [==============================] - 3s 11ms/step - loss: 18421.5600
# Epoch 19/25
# 273/273 [==============================] - 3s 11ms/step - loss: 17631.3334
# Epoch 20/25
# 273/273 [==============================] - 3s 11ms/step - loss: 17658.9893
# Epoch 21/25
# 273/273 [==============================] - 3s 11ms/step - loss: 16742.1967
# Epoch 22/25
# 273/273 [==============================] - 3s 11ms/step - loss: 16509.0659
# Epoch 23/25
# 273/273 [==============================] - 3s 11ms/step - loss: 16457.2948
# Epoch 24/25
# 273/273 [==============================] - 3s 11ms/step - loss: 16164.5782
# Epoch 25/25
# 273/273 [==============================] - 3s 11ms/step - loss: 15275.7520
# Raw y_pred.shape: (8736, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033783 96.68451618314832 0.6510418605972128 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 24
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36    2185.90  1.08   Eagle_education_Sherrill
# -0.8545    1634.28    1646.75  1.01   Eagle_education_Brooke
# -0.8502    3147.43    3151.90  1.00   Eagle_education_Peter
# -0.8403     477.41     424.94  0.89   Eagle_health_Athena
# -0.8186    1197.02    1200.69  1.00   Eagle_education_Roman
# -0.7988      56.96      29.83  0.52   Eagle_education_Petra
# -0.7961     121.91      74.75  0.61   Eagle_health_Vincenza
# -0.7722     711.33     777.24  1.09   Eagle_education_Norah
# -0.7596     181.94     107.86  0.59   Eagle_public_Alvin
# -0.7222      81.87      49.19  0.60   Eagle_lodging_Edgardo
# -0.7130      92.73      55.64  0.60   Eagle_lodging_Dawn
# -0.6796     148.51      96.68  0.65   Eagle_education_Teresa
# -0.6741      91.20      55.80  0.61   Eagle_lodging_Trina
# -0.5553     335.96     338.19  1.01   Eagle_office_Francis
# -0.3579     226.07     134.37  0.59   Eagle_education_Will
#  0.7231       0.11       0.03  0.28   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Results on all buildings.
#
# * 0.00 mean RMSE
# * 0.00 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.00 mean RMSE
# * 0.00 stddev
