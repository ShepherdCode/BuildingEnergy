# %% [markdown]
# # CNN + GRU CoLab
# Based on Conv_106, but predict next 24 hours instead of next 1 hour.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import TimeDistributed

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24   # length of the predicted sequence

## CNN parameters
EPOCHS=25  # use 1 for testing, 25 for production
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(Conv2D(
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(MaxPooling2D())
    dnn.add(TimeDistributed(Flatten()))
    dnn.add(GRU(8,return_sequences=True))
    dnn.add(GRU(8,return_sequences=False))
    dnn.add(Dense(STEPS_FUTURE))   
    dnn.compile(optimizer='adam',loss=MeanSquaredError())
    dnn.build(input_shape=INPUT_SHAPE)
    return dnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_DNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)        
        print("Raw y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 16)            0
# _________________________________________________________________
# gru (GRU)                    (None, 10, 8)             624
# _________________________________________________________________
# gru_1 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense (Dense)                (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 10s 19ms/step - loss: 363893.5062
# Epoch 2/25
# 274/274 [==============================] - 5s 19ms/step - loss: 360454.0016
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 355105.6701
# Epoch 4/25
# 274/274 [==============================] - 5s 18ms/step - loss: 360239.3973
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 349767.6018
# Epoch 6/25
# 274/274 [==============================] - 5s 18ms/step - loss: 350434.5611
# Epoch 7/25
# Epoch 10/25
# 274/274 [==============================] - 6s 21ms/step - loss: 9534.4608
# Epoch 11/25
# 274/274 [==============================] - 5s 19ms/step - loss: 9323.7067
# Epoch 12/25
# 274/274 [==============================] - 5s 17ms/step - loss: 8880.0065
# Epoch 13/25
# 274/274 [==============================] - 5s 16ms/step - loss: 8612.5202
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 8536.3575
# Epoch 15/25
# 274/274 [==============================] - 5s 18ms/step - loss: 8143.1220
# Epoch 16/25
# 274/274 [==============================] - 5s 17ms/step - loss: 8051.9109
# Epoch 17/25
# 274/274 [==============================] - 5s 18ms/step - loss: 7800.4184
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7676.8823
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7556.6431
# Epoch 20/25
# 274/274 [==============================] - 4s 16ms/step - loss: 7384.9212
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7034.5699
# Epoch 22/25
# 274/274 [==============================] - 4s 15ms/step - loss: 7185.7351
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 6867.8917
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 6707.1377
# Epoch 25/25
# 274/274 [==============================] - 5s 17ms/step - loss: 6603.9287
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.96779195736434 79.26462404749988 0.9670215843892621 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_8 (GRU)                  (None, 10, 8)             624
# _________________________________________________________________
# gru_9 (GRU)                  (None, 8)                 432
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 9s 17ms/step - loss: 13177581.4873
# Epoch 2/25
# 274/274 [==============================] - 5s 19ms/step - loss: 13171198.8109
# Epoch 3/25
# 274/274 [==============================] - 5s 17ms/step - loss: 12900132.0691
# Epoch 4/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12813770.7418
# Epoch 5/25
# 274/274 [==============================] - 4s 14ms/step - loss: 13015969.6109
# Epoch 6/25
# 274/274 [==============================] - 4s 13ms/step - loss: 13001868.2945
# Epoch 7/25
# 274/274 [==============================] - 4s 13ms/step - loss: 12784993.1273
# Epoch 8/25
# 274/274 [==============================] - 4s 14ms/step - loss: 12832192.8618
# Epoch 9/25
# 274/274 [==============================] - 4s 13ms/step - loss: 12853216.4582
# Epoch 10/25
# Epoch 10/25
# 274/274 [==============================] - 5s 17ms/step - loss: 0.0013
# Epoch 11/25
# 274/274 [==============================] - 5s 17ms/step - loss: 0.0013
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 0.0013
# Epoch 13/25
# 274/274 [==============================] - 4s 14ms/step - loss: 0.0013
# Epoch 14/25
# 274/274 [==============================] - 4s 14ms/step - loss: 0.0013
# Epoch 15/25
# 274/274 [==============================] - 4s 14ms/step - loss: 0.0013
# Epoch 16/25
# 274/274 [==============================] - 5s 16ms/step - loss: 0.0013
# Epoch 17/25
# 274/274 [==============================] - 4s 16ms/step - loss: 0.0013
# Epoch 18/25
# 274/274 [==============================] - 4s 16ms/step - loss: 0.0013
# Epoch 19/25
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0013
# Epoch 20/25
# 274/274 [==============================] - 5s 17ms/step - loss: 0.0013
# Epoch 21/25
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0013
# Epoch 22/25
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0013
# Epoch 23/25
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0013
# Epoch 24/25
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0013
# Epoch 25/25
# 274/274 [==============================] - 4s 16ms/step - loss: 0.0013
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.1051845132238942 0.04315079395580278 0.41023904216728785 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_14 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_15 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 11s 18ms/step - loss: 18211.0128
# Epoch 2/25
# 274/274 [==============================] - 6s 21ms/step - loss: 17799.6414
# Epoch 3/25
# 274/274 [==============================] - 5s 18ms/step - loss: 16777.4113
# Epoch 4/25
# 274/274 [==============================] - 5s 19ms/step - loss: 16265.5284
# Epoch 5/25
# 274/274 [==============================] - 5s 18ms/step - loss: 16002.4776
# Epoch 6/25
# 274/274 [==============================] - 5s 17ms/step - loss: 15491.6004
# Epoch 7/25
# 274/274 [==============================] - 5s 18ms/step - loss: 14880.4451
# Epoch 8/25
# 274/274 [==============================] - 4s 16ms/step - loss: 14539.4212
# Epoch 9/25
# 274/274 [==============================] - 4s 16ms/step - loss: 13910.4397
# Epoch 10/25
# 274/274 [==============================] - 5s 19ms/step - loss: 13554.9685
# Epoch 11/25
# 274/274 [==============================] - 5s 17ms/step - loss: 13208.2494
# Epoch 12/25
# 274/274 [==============================] - 4s 16ms/step - loss: 12697.8156
# Epoch 13/25
# 274/274 [==============================] - 4s 15ms/step - loss: 12153.9499
# Epoch 14/25
# 274/274 [==============================] - 4s 15ms/step - loss: 11951.9529
# Epoch 15/25
# 274/274 [==============================] - 5s 19ms/step - loss: 11411.8516
# Epoch 16/25
# 274/274 [==============================] - 6s 20ms/step - loss: 11021.7325
# Epoch 17/25
# 274/274 [==============================] - 4s 16ms/step - loss: 10617.9024
# Epoch 18/25
# 274/274 [==============================] - 5s 17ms/step - loss: 10290.9908
# Epoch 19/25
# 274/274 [==============================] - 4s 15ms/step - loss: 10009.8081
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 9747.8263
# Epoch 21/25
# 274/274 [==============================] - 4s 15ms/step - loss: 9334.0573
# Epoch 22/25
# 274/274 [==============================] - 6s 22ms/step - loss: 9053.4697
# Epoch 23/25
# 274/274 [==============================] - 6s 24ms/step - loss: 8787.2588
# Epoch 24/25
# 274/274 [==============================] - 5s 17ms/step - loss: 8370.3954
# Epoch 25/25
# 274/274 [==============================] - 6s 21ms/step - loss: 8222.9006
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534426 91.41444228757621 0.749610105971559 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# gru_16 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_17 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 11s 21ms/step - loss: 91703.9041
# Epoch 2/25
# 274/274 [==============================] - 5s 17ms/step - loss: 88701.5666: 1s
# Epoch 3/25
# 274/274 [==============================] - 5s 19ms/step - loss: 88191.6924
# Epoch 4/25
# 274/274 [==============================] - 4s 16ms/step - loss: 86127.1250
# Epoch 5/25
# 274/274 [==============================] - 6s 21ms/step - loss: 84195.3299: 0s - loss: 8
# Epoch 6/25
# 274/274 [==============================] - 6s 23ms/step - loss: 83359.2012
# Epoch 7/25
# 274/274 [==============================] - 8s 29ms/step - loss: 82096.8142
# Epoch 8/25
# 274/274 [==============================] - 6s 20ms/step - loss: 81429.9195
# Epoch 9/25
# Epoch 10/25
# 274/274 [==============================] - 7s 27ms/step - loss: 5142005.7655
# Epoch 11/25
# 274/274 [==============================] - 6s 22ms/step - loss: 5366572.7182
# Epoch 12/25
# 274/274 [==============================] - 6s 21ms/step - loss: 5126370.1818
# Epoch 13/25
# 274/274 [==============================] - 6s 20ms/step - loss: 5131488.8055
# Epoch 14/25
# 274/274 [==============================] - 5s 18ms/step - loss: 5155630.3445
# Epoch 15/25
# 274/274 [==============================] - 5s 18ms/step - loss: 5188248.6309
# Epoch 16/25
# 274/274 [==============================] - 5s 17ms/step - loss: 5193654.0473
# Epoch 17/25
# 274/274 [==============================] - 5s 17ms/step - loss: 5112279.2364
# Epoch 18/25
# 274/274 [==============================] - 5s 18ms/step - loss: 5048067.2745
# Epoch 19/25
# 274/274 [==============================] - 5s 19ms/step - loss: 5155538.2291
# Epoch 20/25
# 274/274 [==============================] - 5s 19ms/step - loss: 5099336.3364
# Epoch 21/25
# 274/274 [==============================] - 5s 18ms/step - loss: 5094020.1109
# Epoch 22/25
# 274/274 [==============================] - 5s 17ms/step - loss: 5149260.6036
# Epoch 23/25
# 274/274 [==============================] - 4s 16ms/step - loss: 5041438.8145
# Epoch 24/25
# 274/274 [==============================] - 4s 16ms/step - loss: 5128950.0382
# Epoch 25/25
# 274/274 [==============================] - 5s 16ms/step - loss: 5007936.4509
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1926.4752906644608 1.1780376346568577 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_22 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_23 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_11 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 11s 19ms/step - loss: 630285.4086
# Epoch 2/25
# 274/274 [==============================] - 5s 20ms/step - loss: 622704.0386
# Epoch 3/25
# 274/274 [==============================] - 6s 20ms/step - loss: 619634.4718
# Epoch 4/25
# 274/274 [==============================] - 5s 20ms/step - loss: 631466.6355
# Epoch 5/25
# 274/274 [==============================] - 5s 20ms/step - loss: 610192.6566
# Epoch 6/25
# 274/274 [==============================] - 5s 18ms/step - loss: 619964.9677
# Epoch 7/25
# 274/274 [==============================] - 5s 19ms/step - loss: 617668.3678
# Epoch 8/25
# 274/274 [==============================] - 5s 20ms/step - loss: 604872.2114
# Epoch 9/25
# Epoch 10/25
# 274/274 [==============================] - 4s 15ms/step - loss: 2606.4305
# Epoch 11/25
# 274/274 [==============================] - 5s 18ms/step - loss: 2564.2597
# Epoch 12/25
# 274/274 [==============================] - 6s 21ms/step - loss: 2455.8512
# Epoch 13/25
# 274/274 [==============================] - 6s 21ms/step - loss: 2404.1603
# Epoch 14/25
# 274/274 [==============================] - 5s 17ms/step - loss: 2261.6639
# Epoch 15/25
# 274/274 [==============================] - 4s 16ms/step - loss: 2076.1975
# Epoch 16/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1988.3598
# Epoch 17/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1988.1971
# Epoch 18/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1932.6070
# Epoch 19/25
# 274/274 [==============================] - 5s 17ms/step - loss: 1858.5799
# Epoch 20/25
# 274/274 [==============================] - 5s 16ms/step - loss: 1773.6824
# Epoch 21/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1760.6891
# Epoch 22/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1714.2592
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1664.6158
# Epoch 24/25
# 274/274 [==============================] - 4s 16ms/step - loss: 1666.5535
# Epoch 25/25
# 274/274 [==============================] - 6s 22ms/step - loss: 1622.4323
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819881 42.970785013861956 0.7532102309433619 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_28 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_29 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 9s 18ms/step - loss: 16073.0292
# Epoch 2/25
# 274/274 [==============================] - 5s 19ms/step - loss: 15250.9665
# Epoch 3/25
# 274/274 [==============================] - 5s 18ms/step - loss: 14166.7902
# Epoch 4/25
# 274/274 [==============================] - 5s 19ms/step - loss: 14228.4650
# Epoch 5/25
# 274/274 [==============================] - 5s 20ms/step - loss: 13758.9536
# Epoch 6/25
# 274/274 [==============================] - 5s 17ms/step - loss: 13548.4167
# Epoch 7/25
# 274/274 [==============================] - 5s 17ms/step - loss: 12817.1100
# Epoch 8/25
# 274/274 [==============================] - 5s 17ms/step - loss: 12955.7242
# Epoch 9/25
# 274/274 [==============================] - 5s 20ms/step - loss: 12096.3775
# Epoch 10/25
# 274/274 [==============================] - 6s 22ms/step - loss: 11812.4190
# Epoch 11/25
# 274/274 [==============================] - 6s 23ms/step - loss: 11896.4677
# Epoch 12/25
# 274/274 [==============================] - 6s 22ms/step - loss: 11485.3440
# Epoch 13/25
# 274/274 [==============================] - 6s 21ms/step - loss: 11247.0010
# Epoch 14/25
# 274/274 [==============================] - 4s 16ms/step - loss: 10868.9491
# Epoch 15/25
# 274/274 [==============================] - 5s 17ms/step - loss: 10583.4735
# Epoch 16/25
# 274/274 [==============================] - 5s 17ms/step - loss: 10516.6943
# Epoch 17/25
# 274/274 [==============================] - 6s 24ms/step - loss: 10317.7670
# Epoch 18/25
# 274/274 [==============================] - 5s 19ms/step - loss: 9998.8417
# Epoch 19/25
# 274/274 [==============================] - 4s 16ms/step - loss: 10093.0567
# Epoch 20/25
# 274/274 [==============================] - 4s 16ms/step - loss: 9671.8612
# Epoch 21/25
# 274/274 [==============================] - 4s 16ms/step - loss: 9884.2710
# Epoch 22/25
# 274/274 [==============================] - 5s 19ms/step - loss: 9598.4733
# Epoch 23/25
# 274/274 [==============================] - 6s 22ms/step - loss: 9345.9848
# Epoch 24/25
# 274/274 [==============================] - 9s 34ms/step - loss: 9305.5503
# Epoch 25/25
# 274/274 [==============================] - 9s 32ms/step - loss: 8542.4498
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157318 88.03693009915114 0.964467455116768 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# gru_30 (GRU)                 (None, 10, 8)             624
# _________________________________________________________________
# gru_31 (GRU)                 (None, 8)                 432
# _________________________________________________________________
# dense_15 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 15s 20ms/step - loss: 31414.2013
# Epoch 2/25
# 274/274 [==============================] - 6s 20ms/step - loss: 30579.0202
# Epoch 3/25
# 274/274 [==============================] - 5s 18ms/step - loss: 29626.2185
# Epoch 4/25
# 274/274 [==============================] - 6s 22ms/step - loss: 30221.4121
# Epoch 5/25
# 274/274 [==============================] - 6s 21ms/step - loss: 28058.3305
# Epoch 6/25
# 274/274 [==============================] - 5s 19ms/step - loss: 27810.0975
# Epoch 7/25
# 274/274 [==============================] - 5s 19ms/step - loss: 27532.5702
# Epoch 8/25
# 274/274 [==============================] - 6s 20ms/step - loss: 26694.1768
# Epoch 9/25
# 274/274 [==============================] - 5s 17ms/step - loss: 26437.1987
# Epoch 10/25
# 274/274 [==============================] - 5s 18ms/step - loss: 25434.2028
# Epoch 11/25
# 274/274 [==============================] - 5s 17ms/step - loss: 25373.5478
# Epoch 12/25
# 274/274 [==============================] - 5s 16ms/step - loss: 24032.7894
# Epoch 13/25
# 274/274 [==============================] - 6s 22ms/step - loss: 23132.0027
# Epoch 14/25
# 274/274 [==============================] - 6s 23ms/step - loss: 22934.8846
# Epoch 15/25
# 274/274 [==============================] - 7s 27ms/step - loss: 22483.8013
# Epoch 16/25
# 274/274 [==============================] - 7s 25ms/step - loss: 22501.0906
# Epoch 17/25
# 274/274 [==============================] - 6s 22ms/step - loss: 21246.6411
# Epoch 18/25
# 274/274 [==============================] - 5s 18ms/step - loss: 21057.6365
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 20130.2859
# Epoch 20/25
# 274/274 [==============================] - 4s 15ms/step - loss: 20173.1986
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 19316.8083
# Epoch 22/25
# 274/274 [==============================] - 4s 13ms/step - loss: 18456.2484
# Epoch 23/25
# 274/274 [==============================] - 4s 14ms/step - loss: 18676.1317
# Epoch 24/25
# 274/274 [==============================] - 4s 16ms/step - loss: 18500.7117
# Epoch 25/25
# 274/274 [==============================] - 4s 15ms/step - loss: 18208.6346
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.5078192772458 108.9162698982835 0.7334042774875729 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 24
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67    2229.70  1.10   Eagle_education_Sherrill
# -0.8011    3149.69    3190.60  1.01   Eagle_education_Peter
# -0.7147     477.70     444.16  0.93   Eagle_health_Athena
# -0.6972    1197.84    1233.69  1.03   Eagle_education_Roman
# -0.6928     712.07     804.25  1.13   Eagle_education_Norah
# -0.6191      57.05      42.97  0.75   Eagle_education_Petra
# -0.5975    1635.33    1926.48  1.18   Eagle_education_Brooke
# -0.5645     182.08     117.30  0.64   Eagle_public_Alvin
# -0.5301     148.51     108.92  0.73   Eagle_education_Teresa
# -0.5294      92.83      72.15  0.78   Eagle_lodging_Dawn
# -0.4636     121.95      91.41  0.75   Eagle_health_Vincenza
# -0.4516     336.36     347.27  1.03   Eagle_office_Francis
# -0.4243      91.28      88.04  0.96   Eagle_lodging_Trina
# -0.4210      81.97      79.26  0.97   Eagle_lodging_Edgardo
# -0.3226     226.25     136.93  0.61   Eagle_education_Will
#  0.4372       0.11       0.04  0.41   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Results on all buildings.
#
# * 0.88 mean RMSE
# * 0.22 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.91 mean RMSE
# * 0.18 stddev
