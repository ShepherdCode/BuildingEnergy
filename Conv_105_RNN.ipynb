# %% [markdown]
# # CNN + RNN
# Assume user downloaded archive.zip from Kaggle, renamed the file BuildingData.zip, and stored the file in the data subdirectory. Assume the zip file contains the weather.csv file.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import TimeDistributed

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24    # length of the predicted sequence

## CNN parameters
EPOCHS=25  # use 1 for testing, 25 for production
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(Conv2D(
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(MaxPooling2D())
    dnn.add(TimeDistributed(Flatten()))
    dnn.add(SimpleRNN(8,return_sequences=True))
    dnn.add(SimpleRNN(8,return_sequences=False))
    dnn.add(Dense(STEPS_FUTURE))   
    dnn.compile(optimizer='adam',loss=MeanSquaredError())
    dnn.build(input_shape=INPUT_SHAPE)
    return dnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_DNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)        
        print("Raw y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 17ms/step - loss: 348662.0140
# Epoch 2/25
# 274/274 [==============================] - 5s 16ms/step - loss: 340848.3434
# Epoch 3/25
# 274/274 [==============================] - 5s 18ms/step - loss: 329954.7838
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 327055.7147
# Epoch 5/25
# 274/274 [==============================] - 5s 17ms/step - loss: 324013.4825
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 321956.2250
# Epoch 7/25
# 274/274 [==============================] - 4s 16ms/step - loss: 324684.0078
# Epoch 8/25
# 274/274 [==============================] - 4s 16ms/step - loss: 326245.7715
# Epoch 9/25
# 274/274 [==============================] - 5s 16ms/step - loss: 323851.1280
# Epoch 10/25
# 274/274 [==============================] - 5s 18ms/step - loss: 311524.9297
# Epoch 11/25
# 274/274 [==============================] - 4s 16ms/step - loss: 317050.8227
# Epoch 12/25
# 274/274 [==============================] - 4s 16ms/step - loss: 313019.5322
# Epoch 13/25
# 274/274 [==============================] - 3s 12ms/step - loss: 304517.8966
# Epoch 14/25
# 274/274 [==============================] - 3s 10ms/step - loss: 308719.1924
# Epoch 15/25
# 274/274 [==============================] - 3s 11ms/step - loss: 300132.5046
# Epoch 16/25
# 274/274 [==============================] - 5s 18ms/step - loss: 299505.7508
# Epoch 17/25
# 274/274 [==============================] - 5s 19ms/step - loss: 299242.3683
# Epoch 18/25
# 274/274 [==============================] - 4s 15ms/step - loss: 298219.3868
# Epoch 19/25
# 274/274 [==============================] - 4s 13ms/step - loss: 295377.8205
# Epoch 20/25
# 274/274 [==============================] - 4s 14ms/step - loss: 285554.1247
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 292569.0361
# Epoch 22/25
# 274/274 [==============================] - 4s 14ms/step - loss: 292652.6082
# Epoch 23/25
# 274/274 [==============================] - 4s 15ms/step - loss: 280542.1382
# Epoch 24/25
# 274/274 [==============================] - 4s 15ms/step - loss: 282885.1167
# Epoch 25/25
# 274/274 [==============================] - 4s 14ms/step - loss: 276984.6813
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545475 423.2894366530296 0.886635162562289 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 7s 18ms/step - loss: 53804.5405
# Epoch 2/25
# 274/274 [==============================] - 5s 18ms/step - loss: 50777.8438
# Epoch 3/25
# 274/274 [==============================] - 5s 17ms/step - loss: 49442.3707
# Epoch 4/25
# 274/274 [==============================] - 5s 17ms/step - loss: 49500.8533
# Epoch 5/25
# 274/274 [==============================] - 5s 17ms/step - loss: 47641.2765
# Epoch 6/25
# 274/274 [==============================] - 5s 17ms/step - loss: 46774.6387
# Epoch 7/25
# 274/274 [==============================] - 5s 17ms/step - loss: 46024.9607
# Epoch 8/25
# 274/274 [==============================] - 4s 16ms/step - loss: 45687.8920
# Epoch 9/25
# 274/274 [==============================] - 5s 17ms/step - loss: 44718.2597
# Epoch 10/25
# 274/274 [==============================] - 5s 16ms/step - loss: 42315.0959
# Epoch 11/25
# 274/274 [==============================] - 3s 12ms/step - loss: 43516.0032
# Epoch 12/25
# 274/274 [==============================] - 3s 12ms/step - loss: 42202.3689
# Epoch 13/25
# 274/274 [==============================] - 4s 16ms/step - loss: 41407.8740
# Epoch 14/25
# 274/274 [==============================] - 5s 18ms/step - loss: 40650.7073
# Epoch 15/25
# 274/274 [==============================] - 5s 18ms/step - loss: 39228.7598
# Epoch 16/25
# 274/274 [==============================] - 5s 18ms/step - loss: 38264.1887
# Epoch 17/25
# 274/274 [==============================] - 6s 21ms/step - loss: 37477.3508
# Epoch 18/25
# 274/274 [==============================] - 4s 16ms/step - loss: 36075.3353
# Epoch 19/25
# 274/274 [==============================] - 4s 14ms/step - loss: 35841.6042
# Epoch 20/25
# 274/274 [==============================] - 4s 13ms/step - loss: 35391.4977
# Epoch 21/25
# 274/274 [==============================] - 4s 14ms/step - loss: 34459.3837
# Epoch 22/25
# 274/274 [==============================] - 4s 13ms/step - loss: 33913.1616
# Epoch 23/25
# 274/274 [==============================] - 4s 13ms/step - loss: 33342.5166
# Epoch 24/25
# 274/274 [==============================] - 4s 13ms/step - loss: 32236.7977
# Epoch 25/25
# 274/274 [==============================] - 4s 13ms/step - loss: 31306.6041
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500085 106.20895232143344 0.5837592207530811 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_4 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 6s 15ms/step - loss: 1666344.6691
# Epoch 2/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1643831.9086
# Epoch 3/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1644077.3359
# Epoch 4/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1620735.1073
# Epoch 5/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1635468.1718
# Epoch 6/25
# 274/274 [==============================] - 4s 15ms/step - loss: 1623434.8445
# Epoch 7/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1617899.3886
# Epoch 8/25
# 274/274 [==============================] - 4s 13ms/step - loss: 1626558.0314
# Epoch 9/25
# 274/274 [==============================] - 4s 14ms/step - loss: 1623196.7568
# Epoch 10/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1625501.0000
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1623581.8645
# Epoch 12/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1608960.7482
# Epoch 13/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1587333.4455
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1592873.5377
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1575762.5955
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1565744.0964
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1577931.2186
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1549213.9577
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1550761.1568
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1545208.0859
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1561820.2909
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1521941.2336
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1548988.1091
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1555272.8918
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1527545.1100
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.81855226807807 1197.016015073252 1202.2017124898985 1.0043321871648718 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_6 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_7 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 9ms/step - loss: 8492.8170
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 7896.0764
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 7639.5464
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 7282.7658
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 7083.0467
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6589.5699
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6350.7258
# Epoch 8/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5978.0959
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5781.8200
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5620.0100
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5123.3449
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 4957.4497
# Epoch 13/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4795.7882
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4445.7212
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4408.9382
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4306.3273
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3812.0015
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3597.5369
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3523.9442
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3603.2568
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3182.6309
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3314.1037
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3145.6891
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2980.1684
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2838.4105
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264256 48.45691026315317 0.5918640199400941 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_8 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_9 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 8ms/step - loss: 12803821.5818
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12933721.9964
# Epoch 3/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12603932.9855
# Epoch 4/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12775773.1382
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 12647134.2727
# Epoch 6/25
# 274/274 [==============================] - 3s 10ms/step - loss: 12443846.7782
# Epoch 7/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12693420.4291
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 12761815.6545
# Epoch 9/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12690871.9636
# Epoch 10/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12495108.4073
# Epoch 11/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12670140.1855
# Epoch 12/25
# 274/274 [==============================] - 3s 10ms/step - loss: 12473572.8364
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12393890.3745
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12498804.5236
# Epoch 15/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12511080.1964
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12566689.5273
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12640831.0582
# Epoch 18/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12624906.5382
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12574011.9200
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12250456.9091
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12362562.7309
# Epoch 22/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12419723.0073
# Epoch 23/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12460157.9745
# Epoch 24/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12416087.3891
# Epoch 25/25
# 274/274 [==============================] - 2s 9ms/step - loss: 12478723.8618
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.430703431568 3156.095733518334 1.0027530487255267 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_10 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 6s 12ms/step - loss: 12859.0528
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 12223.7642
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11719.9869
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11103.6243
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10788.1537
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10236.4454
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9944.6399
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9595.3206
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9425.6303
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8709.1352
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8712.1679
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8158.3342
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 7661.9330
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 7485.6126
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 6954.6741
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 6921.5097
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 6912.8403
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 6201.6223
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 6268.5620
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5839.2751
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5679.0565
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5379.6728
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5292.1482
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5098.0074
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4962.1117
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606874 54.71423037692882 0.5900072266840788 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_12 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_13 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 9ms/step - loss: 0.0035
# Epoch 2/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.4278e-04
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.7095e-04
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.5027e-04
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.5204e-04
# Epoch 6/25
# 274/274 [==============================] - 3s 12ms/step - loss: 3.6217e-04
# Epoch 7/25
# 274/274 [==============================] - 3s 11ms/step - loss: 3.5042e-04
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.6096e-04
# Epoch 9/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.4461e-04
# Epoch 10/25
# 274/274 [==============================] - 4s 14ms/step - loss: 3.4254e-04
# Epoch 11/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.5842e-04
# Epoch 12/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.5852e-04
# Epoch 13/25
# 274/274 [==============================] - 3s 9ms/step - loss: 3.5464e-04
# Epoch 14/25
# 274/274 [==============================] - 3s 9ms/step - loss: 3.6856e-04
# Epoch 15/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.5741e-04
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.5547e-04
# Epoch 17/25
# 274/274 [==============================] - 3s 12ms/step - loss: 3.4978e-04
# Epoch 18/25
# 274/274 [==============================] - 4s 13ms/step - loss: 3.3838e-04
# Epoch 19/25
# 274/274 [==============================] - 3s 12ms/step - loss: 3.5527e-04
# Epoch 20/25
# 274/274 [==============================] - 3s 9ms/step - loss: 3.4986e-04
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.4814e-04
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.5254e-04
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.7169e-04
# Epoch 24/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.3846e-04
# Epoch 25/25
# 274/274 [==============================] - 3s 9ms/step - loss: 3.5298e-04
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135475 0.029054026617257856 0.2760969566059707 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_14 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_15 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 5s 10ms/step - loss: 15184.1447
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 14137.3884
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 13817.9230
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 13276.6916
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 12576.4281
# Epoch 6/25
# 274/274 [==============================] - 3s 9ms/step - loss: 12242.8951
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 11578.3447
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 11298.0712
# Epoch 9/25
# 274/274 [==============================] - 3s 9ms/step - loss: 10850.7445
# Epoch 10/25
# 274/274 [==============================] - 2s 9ms/step - loss: 10339.9414
# Epoch 11/25
# 274/274 [==============================] - 2s 9ms/step - loss: 9866.0312
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 9544.0845
# Epoch 13/25
# 274/274 [==============================] - 3s 11ms/step - loss: 9108.9691
# Epoch 14/25
# 274/274 [==============================] - 3s 10ms/step - loss: 8567.7891
# Epoch 15/25
# 274/274 [==============================] - 3s 9ms/step - loss: 8328.4518
# Epoch 16/25
# 274/274 [==============================] - 3s 9ms/step - loss: 8038.9137
# Epoch 17/25
# 274/274 [==============================] - 3s 9ms/step - loss: 7626.8987
# Epoch 18/25
# 274/274 [==============================] - 3s 9ms/step - loss: 7323.8272
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6844.9242
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6717.8689
# Epoch 21/25
# 274/274 [==============================] - 3s 10ms/step - loss: 6359.4244
# Epoch 22/25
# 274/274 [==============================] - 3s 9ms/step - loss: 6070.2036
# Epoch 23/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5750.3315
# Epoch 24/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5461.2271
# Epoch 25/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5142.0014
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508735 72.19262572343541 0.5921874551050034 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_16 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_17 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 85770.8599
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 83838.2977
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 82022.6461
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 82572.9393
# Epoch 5/25
# 274/274 [==============================] - 3s 9ms/step - loss: 79898.8197
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 78664.5764
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 77299.4226
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 75452.1171
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 74987.8746
# Epoch 10/25
# 274/274 [==============================] - 3s 9ms/step - loss: 72745.8714
# Epoch 11/25
# 274/274 [==============================] - 3s 10ms/step - loss: 72423.3762
# Epoch 12/25
# 274/274 [==============================] - 3s 10ms/step - loss: 71718.8395
# Epoch 13/25
# 274/274 [==============================] - 3s 9ms/step - loss: 69021.4477
# Epoch 14/25
# 274/274 [==============================] - 3s 9ms/step - loss: 69014.5485
# Epoch 15/25
# 274/274 [==============================] - 3s 9ms/step - loss: 66456.2130
# Epoch 16/25
# 274/274 [==============================] - 3s 10ms/step - loss: 67194.8086
# Epoch 17/25
# 274/274 [==============================] - 3s 10ms/step - loss: 65527.6537
# Epoch 18/25
# 274/274 [==============================] - 3s 10ms/step - loss: 63906.5397
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 62700.8299
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 62099.1338
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 60323.7229
# Epoch 22/25
# 274/274 [==============================] - 3s 12ms/step - loss: 59032.2174
# Epoch 23/25
# 274/274 [==============================] - 2s 9ms/step - loss: 58551.6432
# Epoch 24/25
# 274/274 [==============================] - 3s 11ms/step - loss: 57511.0155
# Epoch 25/25
# 274/274 [==============================] - 2s 9ms/step - loss: 55924.4262
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.5552570597696993 335.9563635497514 337.4528498639382 1.0044544068115715 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_18 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_19 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 5s 11ms/step - loss: 5402587.3745
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5281422.3309
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5462527.9818
# Epoch 4/25
# 274/274 [==============================] - 3s 11ms/step - loss: 5313840.9891
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5259781.8836
# Epoch 6/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5321350.6455
# Epoch 7/25
# 274/274 [==============================] - 3s 11ms/step - loss: 5301552.4855
# Epoch 8/25
# 274/274 [==============================] - 3s 11ms/step - loss: 5357092.3273
# Epoch 9/25
# 274/274 [==============================] - 3s 12ms/step - loss: 5327450.0473
# Epoch 10/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5095389.1327
# Epoch 11/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5317679.9036
# Epoch 12/25
# 274/274 [==============================] - 3s 11ms/step - loss: 5224507.0145
# Epoch 13/25
# 274/274 [==============================] - 3s 11ms/step - loss: 5226234.7727
# Epoch 14/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5198049.1945
# Epoch 15/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5252729.4364
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5289973.6545
# Epoch 17/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5318094.9127
# Epoch 18/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5147201.8364
# Epoch 19/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5152849.5600
# Epoch 20/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5183733.8727
# Epoch 21/25
# 274/274 [==============================] - 3s 10ms/step - loss: 5204067.6673
# Epoch 22/25
# 274/274 [==============================] - 3s 13ms/step - loss: 5101009.7582
# Epoch 23/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5076926.7145
# Epoch 24/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5221086.2200
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5106997.0236
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358292 2188.6166774563144 1.0779457748659318 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_20 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_21 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 6s 13ms/step - loss: 4308526.5518
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4323844.2009
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4303510.7591
# Epoch 4/25
# 274/274 [==============================] - 3s 9ms/step - loss: 4406615.2936
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4329415.0818
# Epoch 6/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4295296.1591
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4272237.1055
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4343729.2673
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 4295439.2464
# Epoch 10/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4334798.5618
# Epoch 11/25
# 274/274 [==============================] - 3s 11ms/step - loss: 4282856.8609
# Epoch 12/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4293846.7018
# Epoch 13/25
# 274/274 [==============================] - 3s 11ms/step - loss: 4153507.1600
# Epoch 14/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4238896.2355
# Epoch 15/25
# 274/274 [==============================] - 3s 11ms/step - loss: 4283622.0091
# Epoch 16/25
# 274/274 [==============================] - 3s 13ms/step - loss: 4237230.5327
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 4313673.3000
# Epoch 18/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4179057.6045
# Epoch 19/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4200326.8109
# Epoch 20/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4270353.9227
# Epoch 21/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4172586.6236
# Epoch 22/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4133348.2727
# Epoch 23/25
# 274/274 [==============================] - 3s 9ms/step - loss: 4124771.3027
# Epoch 24/25
# 274/274 [==============================] - 3s 12ms/step - loss: 4176674.4782
# Epoch 25/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4091587.4964
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.8545240602973272 1634.2804902547193 1647.4122711347243 1.008035206293112 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_22 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_23 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 599389.9143
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 594828.9830
# Epoch 3/25
# 274/274 [==============================] - 3s 12ms/step - loss: 603382.6874
# Epoch 4/25
# 274/274 [==============================] - 3s 11ms/step - loss: 584991.5132
# Epoch 5/25
# 274/274 [==============================] - 3s 9ms/step - loss: 570877.2908
# Epoch 6/25
# 274/274 [==============================] - 3s 10ms/step - loss: 572521.1308
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 579018.5716
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 582729.4614
# Epoch 9/25
# 274/274 [==============================] - 3s 10ms/step - loss: 568641.6031
# Epoch 10/25
# 274/274 [==============================] - 3s 9ms/step - loss: 566958.7489
# Epoch 11/25
# 274/274 [==============================] - 3s 9ms/step - loss: 572154.4034
# Epoch 12/25
# 274/274 [==============================] - 3s 10ms/step - loss: 562356.2493
# Epoch 13/25
# 274/274 [==============================] - 5s 16ms/step - loss: 559097.8174
# Epoch 14/25
# 274/274 [==============================] - 3s 10ms/step - loss: 573113.4591
# Epoch 15/25
# 274/274 [==============================] - 3s 9ms/step - loss: 551659.5522
# Epoch 16/25
# 274/274 [==============================] - 3s 10ms/step - loss: 559668.5650
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 541944.4322
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 559536.4494
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 545744.7125
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 539723.9053
# Epoch 21/25
# 274/274 [==============================] - 3s 9ms/step - loss: 532068.7357
# Epoch 22/25
# 274/274 [==============================] - 2s 9ms/step - loss: 534669.9448
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 525691.9941
# Epoch 24/25
# 274/274 [==============================] - 2s 9ms/step - loss: 528416.4850
# Epoch 25/25
# 274/274 [==============================] - 3s 9ms/step - loss: 529260.4640
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245889 777.6676517564365 1.0932571303753666 Eagle_education_Norah
# Building Eagle_education_Will
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_24 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_25 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 5s 10ms/step - loss: 76022.0139
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 73653.8999
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 72631.9591
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 71798.5013
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 69560.9489
# Epoch 6/25
# 274/274 [==============================] - 3s 10ms/step - loss: 69546.5030
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 67638.0395
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 66458.8449
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 64890.9721
# Epoch 10/25
# 274/274 [==============================] - 2s 9ms/step - loss: 64804.0277
# Epoch 11/25
# 274/274 [==============================] - 3s 11ms/step - loss: 62983.0392
# Epoch 12/25
# 274/274 [==============================] - 4s 14ms/step - loss: 61536.9274
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 60516.8005
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 59818.2997
# Epoch 15/25
# 274/274 [==============================] - 2s 9ms/step - loss: 58609.1806
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 58077.8286
# Epoch 17/25
# 274/274 [==============================] - 3s 11ms/step - loss: 56153.9220
# Epoch 18/25
# 274/274 [==============================] - 3s 9ms/step - loss: 54686.8058
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 54242.3510
# Epoch 20/25
# 274/274 [==============================] - 3s 11ms/step - loss: 52638.5899
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 51907.0366
# Epoch 22/25
# 274/274 [==============================] - 2s 9ms/step - loss: 51975.0394
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 50478.3006
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 48903.9819
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 49295.7434
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769716 132.03865671561735 0.5840622599830627 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_26 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_27 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 5s 11ms/step - loss: 4122.1283
# Epoch 2/25
# 274/274 [==============================] - 3s 11ms/step - loss: 3597.0160
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3379.8411
# Epoch 4/25
# 274/274 [==============================] - 3s 11ms/step - loss: 3166.9912
# Epoch 5/25
# 274/274 [==============================] - 3s 11ms/step - loss: 2941.9951
# Epoch 6/25
# 274/274 [==============================] - 3s 9ms/step - loss: 2904.4574
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 2610.7911
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 2470.5102
# Epoch 9/25
# 274/274 [==============================] - 3s 9ms/step - loss: 2371.7661
# Epoch 10/25
# 274/274 [==============================] - 3s 10ms/step - loss: 2129.6348
# Epoch 11/25
# 274/274 [==============================] - 3s 10ms/step - loss: 2099.0140
# Epoch 12/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1923.9598
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1828.4151
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1761.4230
# Epoch 15/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1609.1984
# Epoch 16/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1648.6746
# Epoch 17/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1493.8876
# Epoch 18/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1486.5979
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1419.2364
# Epoch 20/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1362.8776
# Epoch 21/25
# 274/274 [==============================] - 3s 11ms/step - loss: 1354.1881
# Epoch 22/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1321.6974
# Epoch 23/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1293.8913
# Epoch 24/25
# 274/274 [==============================] - 3s 12ms/step - loss: 1227.6073
# Epoch 25/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1208.5221
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.96274977501869 29.514066990712344 0.5181292530167827 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_28 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_29 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 5s 11ms/step - loss: 11601.3938
# Epoch 2/25
# 274/274 [==============================] - 3s 11ms/step - loss: 10785.0991
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 10556.1592
# Epoch 4/25
# 274/274 [==============================] - 3s 9ms/step - loss: 9734.5933
# Epoch 5/25
# 274/274 [==============================] - 3s 9ms/step - loss: 10035.6597
# Epoch 6/25
# 274/274 [==============================] - 3s 9ms/step - loss: 9134.9853
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 8814.4166
# Epoch 8/25
# 274/274 [==============================] - 3s 9ms/step - loss: 8573.6884
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 8165.4911
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 8039.3988
# Epoch 11/25
# 274/274 [==============================] - 2s 9ms/step - loss: 7624.5496
# Epoch 12/25
# 274/274 [==============================] - 3s 9ms/step - loss: 7431.6805
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 7069.1428
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6995.9651
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6707.3308
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6591.4500
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6554.5038
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6125.2266
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5975.7218
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5975.8682
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5601.7254
# Epoch 22/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5404.4158
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5380.5425
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5085.6475
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4901.8215
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.6740953050024701 91.19691350551768 54.343506757997 0.5958919514826458 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_30 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_31 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8747, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 28719.9202
# Epoch 2/25
# 274/274 [==============================] - 3s 11ms/step - loss: 28244.7490
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 27373.3234
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 27252.8038
# Epoch 5/25
# 274/274 [==============================] - 3s 9ms/step - loss: 26126.8003
# Epoch 6/25
# 274/274 [==============================] - 3s 10ms/step - loss: 25463.7828
# Epoch 7/25
# 274/274 [==============================] - 3s 9ms/step - loss: 24800.0511
# Epoch 8/25
# 274/274 [==============================] - 3s 9ms/step - loss: 24120.6218
# Epoch 9/25
# 274/274 [==============================] - 3s 9ms/step - loss: 23629.3816
# Epoch 10/25
# 274/274 [==============================] - 3s 9ms/step - loss: 23017.9629
# Epoch 11/25
# 274/274 [==============================] - 3s 9ms/step - loss: 22143.1717
# Epoch 12/25
# 274/274 [==============================] - 3s 9ms/step - loss: 21658.2285
# Epoch 13/25
# 274/274 [==============================] - 3s 9ms/step - loss: 21412.5079
# Epoch 14/25
# 274/274 [==============================] - 3s 9ms/step - loss: 19863.5586
# Epoch 15/25
# 274/274 [==============================] - 3s 9ms/step - loss: 20061.3786
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 19106.4293
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 18519.4874
# Epoch 18/25
# 274/274 [==============================] - 2s 9ms/step - loss: 17805.9248
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 17597.1534
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 17145.2353
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 16657.9100
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 16155.7712
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 16040.1735
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 15296.4675
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 15048.1959
# Raw y_pred.shape: (8748, 1)
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033823 95.15629740372253 0.6407513359420297 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36    2188.62  1.08   Eagle_education_Sherrill
# -0.8545    1634.28    1647.41  1.01   Eagle_education_Brooke
# -0.8502    3147.43    3156.10  1.00   Eagle_education_Peter
# -0.8403     477.41     423.29  0.89   Eagle_health_Athena
# -0.8186    1197.02    1202.20  1.00   Eagle_education_Roman
# -0.7988      56.96      29.51  0.52   Eagle_education_Petra
# -0.7961     121.91      72.19  0.59   Eagle_health_Vincenza
# -0.7722     711.33     777.67  1.09   Eagle_education_Norah
# -0.7596     181.94     106.21  0.58   Eagle_public_Alvin
# -0.7222      81.87      48.46  0.59   Eagle_lodging_Edgardo
# -0.7130      92.73      54.71  0.59   Eagle_lodging_Dawn
# -0.6796     148.51      95.16  0.64   Eagle_education_Teresa
# -0.6741      91.20      54.34  0.60   Eagle_lodging_Trina
# -0.5553     335.96     337.45  1.00   Eagle_office_Francis
# -0.3579     226.07     132.04  0.58   Eagle_education_Will
#  0.7231       0.11       0.03  0.28   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Results on all buildings.
#
# * 0.00 mean RMSE
# * 0.00 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.00 mean RMSE
# * 0.00 stddev
