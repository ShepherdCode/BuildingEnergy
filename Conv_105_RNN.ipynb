# %% [markdown]
# # CNN + RNN
# Assume user downloaded archive.zip from Kaggle, renamed the file BuildingData.zip, and stored the file in the data subdirectory. Assume the zip file contains the weather.csv file.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import TimeDistributed

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %% [markdown]
# ## CNN setup

# %%
# Before analyzing the entire dataset, we look at this subset.
SITE = 'Eagle'
METER = 'steam'

# Arrange "picture" of weather with temperatures toward the middle
PREDICTED_VARIABLE = 'steam' 
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)

# Downsample True means collapse 365*24 measures to 365 daily averages
# Downsample False means replace 365*24 measures with 365*24 window averages
DOWNSAMPLE = False   

STEPS_HISTORY = 24   # length of the predictor sequence
STEPS_FUTURE =  24    # length of the predicted sequence

## CNN parameters
EPOCHS=25  # use 1 for testing, 25 for production
FILTERS = 8
WIDTH = 3
STRIDE = (1,1)
INPUT_SHAPE = (STEPS_HISTORY,len(PREDICTORS),1)
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors,1)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                # for x3 in range (0,X_shape[3]): # In 1 metric, loop over vector dimensions
                # In our data, each weather metric is a scalar.
                x3 = 0
                X[x0,x1,x2,x3] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Conv2D( input_shape=INPUT_SHAPE,
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(Conv2D(
            filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
            activation=None, padding="valid"))
    dnn.add(MaxPooling2D())
    dnn.add(TimeDistributed(Flatten()))
    dnn.add(SimpleRNN(8,return_sequences=True))
    dnn.add(SimpleRNN(8,return_sequences=False))
    dnn.add(Dense(STEPS_FUTURE))   
    dnn.compile(optimizer='adam',loss=MeanSquaredError())
    dnn.build(input_shape=INPUT_SHAPE)
    return dnn

# %% [markdown]
# ## Process all buildings

# %%
cors = []
ONE_PREDICTOR = 'dewTemperature'  ## illustrate difficulty by showing best correlate
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        #one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])

        model = make_DNN()
        print(model.summary())
        print("X_train.shape:",X_train.shape)
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)        
        print("Raw y_pred.shape:",y_pred.shape)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][ONE_PREDICTOR] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)
        
print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",ONE_PREDICTOR)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense (Dense)                (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 6ms/step - loss: 362736.8576
# Epoch 2/25
# 274/274 [==============================] - 2s 6ms/step - loss: 356945.9899
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 363839.2977
# Epoch 4/25
# 274/274 [==============================] - 2s 6ms/step - loss: 364265.5027
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 361001.7542
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 353601.1606
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 353609.2053
# Epoch 8/25
# 274/274 [==============================] - 2s 6ms/step - loss: 347409.6925
# Epoch 9/25
# 274/274 [==============================] - 2s 6ms/step - loss: 342880.3044
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 337920.7715
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 335958.3859
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 336257.9280
# Epoch 13/25
# 274/274 [==============================] - 2s 6ms/step - loss: 339611.8953
# Epoch 14/25
# 274/274 [==============================] - 2s 6ms/step - loss: 332644.5087
# Epoch 15/25
# 274/274 [==============================] - 2s 6ms/step - loss: 332183.2523
# Epoch 16/25
# 274/274 [==============================] - 2s 6ms/step - loss: 328079.7558
# Epoch 17/25
# 274/274 [==============================] - 2s 6ms/step - loss: 321949.9657
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 325012.4420
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 325266.6282
# Epoch 20/25
# 274/274 [==============================] - 2s 6ms/step - loss: 314368.5493
# Epoch 21/25
# 274/274 [==============================] - 2s 6ms/step - loss: 310462.4608
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 320528.6495
# Epoch 23/25
# 274/274 [==============================] - 2s 6ms/step - loss: 313769.4843
# Epoch 24/25
# 274/274 [==============================] - 2s 6ms/step - loss: 307277.5295
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 304085.5135
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.714675935601442 477.70168061445776 444.39213943092665 0.9302712497458964 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 6ms/step - loss: 61746.1183
# Epoch 2/25
# 274/274 [==============================] - 2s 6ms/step - loss: 60308.7449
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 59412.3839
# Epoch 4/25
# 274/274 [==============================] - 2s 6ms/step - loss: 58971.5104
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 57401.1029
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 55556.6382
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 55466.8027
# Epoch 8/25
# 274/274 [==============================] - 2s 6ms/step - loss: 55186.6661
# Epoch 9/25
# 274/274 [==============================] - 2s 6ms/step - loss: 53641.6356
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 53371.4740
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 51637.8545
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 50420.4489
# Epoch 13/25
# 274/274 [==============================] - 2s 6ms/step - loss: 49587.6656
# Epoch 14/25
# 274/274 [==============================] - 2s 6ms/step - loss: 49808.5466
# Epoch 15/25
# 274/274 [==============================] - 2s 6ms/step - loss: 48608.0592
# Epoch 16/25
# 274/274 [==============================] - 2s 6ms/step - loss: 47569.6438
# Epoch 17/25
# 274/274 [==============================] - 2s 6ms/step - loss: 48345.3009
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 45746.3019
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 45368.5938
# Epoch 20/25
# 274/274 [==============================] - 2s 6ms/step - loss: 45056.6574
# Epoch 21/25
# 274/274 [==============================] - 2s 6ms/step - loss: 44084.8860
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 43697.7382
# Epoch 23/25
# 274/274 [==============================] - 2s 6ms/step - loss: 43324.8667
# Epoch 24/25
# 274/274 [==============================] - 2s 6ms/step - loss: 42176.0766
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 41270.6586
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5644780905146625 182.08293646830808 117.35173142152375 0.6444960395393726 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_4 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 6ms/step - loss: 1724996.3173
# Epoch 2/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1739407.0005
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1743905.8782
# Epoch 4/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1728098.5568
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1726779.5336
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1691125.9436
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1695544.2491
# Epoch 8/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1697572.5664
# Epoch 9/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1679780.4245
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1694096.4750
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1676583.5782
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1699578.5714
# Epoch 13/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1643117.7100
# Epoch 14/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1658408.3927
# Epoch 15/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1680601.1800
# Epoch 16/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1671495.3200
# Epoch 17/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1647983.1332
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1675668.1209
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1617392.3568
# Epoch 20/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1655726.3109
# Epoch 21/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1611548.3636
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1623707.3132
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1621294.6468
# Epoch 24/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1611319.6423
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 1603491.8127
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6971970415159798 1197.8359713121304 1234.1260789122355 1.030296391550466 Eagle_education_Roman
# Building Eagle_office_Mandi
# Building Eagle_education_Jewell
# Building Eagle_office_Henriette
# Building Eagle_health_Reba
# Building Eagle_lodging_Edgardo
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_6 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_7 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 6ms/step - loss: 12723.6438
# Epoch 2/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12293.2341
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 11433.6823
# Epoch 4/25
# 274/274 [==============================] - 2s 6ms/step - loss: 10981.7909
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 11038.8367
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 10485.6653
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 10285.5278
# Epoch 8/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9840.0351
# Epoch 9/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9715.6939
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9512.8321
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 8943.9315
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 9044.9852
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8687.6387
# Epoch 14/25
# 274/274 [==============================] - 2s 6ms/step - loss: 8667.3834
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8323.8853
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8074.2311
# Epoch 17/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7877.9881
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7724.7218
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7390.4976
# Epoch 20/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7285.5687
# Epoch 21/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7120.5278
# Epoch 22/25
# 274/274 [==============================] - 2s 6ms/step - loss: 6897.5465
# Epoch 23/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7077.1243
# Epoch 24/25
# 274/274 [==============================] - 2s 6ms/step - loss: 6738.0767
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 6850.3549
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.420958250828966 81.9677919573641 79.3650614580765 0.9682469121451823 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_8 (SimpleRNN)     (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_9 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 13055856.7418
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12987816.1491
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12912914.6655
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13133140.0327
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13064165.5382
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12745252.5164
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 13109829.7091
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13086808.0473
# Epoch 9/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12842696.7455
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12950730.9455
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12803808.3636
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13078917.2436
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12949373.4909
# Epoch 14/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12522453.8727
# Epoch 15/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12778067.7927
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12912209.3527
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12760791.8255
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12769459.3273
# Epoch 19/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12618206.9382
# Epoch 20/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12683038.3018
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12705770.6873
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13007689.3636
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12341546.4691
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12771870.6836
# Epoch 25/25
# 274/274 [==============================] - 2s 6ms/step - loss: 12612096.6691
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8010592683514538 3149.6888831281212 3190.918532793872 1.0130900705420796 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_10 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 15300.2429
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 14841.1733
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13881.2438
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13650.7641
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13246.5537
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12817.1155
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12441.4310
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11978.5718
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11594.4929
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11513.9688
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10881.3913
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10677.8514
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10036.3310
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9821.5565
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9530.6610
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9482.9830
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8793.3413
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8577.2664
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8590.2958
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8142.5441
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8135.7197
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 7650.1549
# Epoch 23/25
# 274/274 [==============================] - 2s 6ms/step - loss: 7587.8084
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 7261.1341
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 6979.4342
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5293626578197084 92.82705527815749 72.23892889281792 0.7782098513881867 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_12 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_13 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 0.0352
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0020
# Epoch 3/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0016
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0016
# Epoch 5/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 6/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 7/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 8/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 9/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 10/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 11/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 12/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 13/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 15/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 16/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 18/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 23/25
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0013
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 0.0013
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: 0.43722987743290215 0.10518451322389408 0.04248893445859949 0.403946675763553 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_14 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_15 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 18280.8518
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 17653.5975
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 16975.1374
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 16503.5269
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 15969.9156
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 15509.6846
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 14927.6658
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 14461.3217
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13997.3388
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13778.3844
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13173.3096
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12571.6539
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12436.3003
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11797.3808
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11482.7916
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11076.8256
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10804.3995
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 10456.6170
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 10255.0435
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9722.8586
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9294.0189
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9174.4412
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8661.1728
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8513.9764
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8251.5118
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.46361408982228286 121.94931946534436 91.64774792199566 0.7515232419811918 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_16 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_17 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 8ms/step - loss: 90646.2848
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 88957.7500
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 86800.6268
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 86130.4651
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 84211.8140
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 84822.5637
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 82759.0876
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 82034.6216
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 80432.7522
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 78562.3027
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 78916.8135
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 76028.4680
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 74820.0641
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 73943.9611
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 72441.1713
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 71295.4689
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 70209.1034
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 69855.4796
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 67549.5910
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 66146.9228
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 65182.0382
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 64327.1655
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 64120.7327
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 62271.4867
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 60948.3357
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.4515947035800076 336.35952546169125 347.85820958412984 1.0341856949246653 Eagle_office_Francis
# Building Eagle_office_Sheree
# Building Eagle_education_Sherrill
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_18 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_19 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_9 (Dense)              (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 5625526.7364
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5409789.2945
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5516505.8200
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5527714.0836
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5425553.8236
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5556220.1691
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5528014.1527
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5461668.0855
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5504495.5182
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5541688.5036
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5513121.9618
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5357520.9800
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5408246.6073
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5425895.2545
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5421093.7582
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5456547.9764
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5374045.2627
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5398548.0818
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5382625.6018
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5357746.7309
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5214914.9127
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5414641.0836
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5332768.0255
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5254443.7673
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5369886.0491
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.8130507458567988 2032.6741548164603 2230.129087294897 1.0971404747832127 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_20 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_21 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_10 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 8ms/step - loss: 5395037.0800
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5313562.9800
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5297219.7800
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5239106.2127
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5251221.7255
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5282965.9909
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5330055.8618
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5243032.7545
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5292187.1727
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5153170.0727
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5250498.7200
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5158888.6491
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5087334.8345
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5134120.0655
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5181798.0600
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5212469.8145
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5081256.2636
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5035519.3273
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5201350.8000
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5184834.8927
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5172639.9500
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5098691.3236
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5061277.5255
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5062089.1818
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 5094675.6418
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5974542280786012 1635.325760391017 1926.7001330662533 1.1781751255514785 Eagle_education_Brooke
# Building Eagle_education_Alberto
# Building Eagle_food_Kay
# Building Eagle_health_Jodi
# Building Eagle_education_Norah
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_22 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_23 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_11 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 629218.6639
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 628483.6565
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 622443.4755
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 613096.9670
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 617246.8916
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 620942.9957
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 611504.3193
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 605611.7614
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 605908.6752
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 596736.5836
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 588754.4450
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 597520.5286
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 608971.3159
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 602298.2491
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 584726.7043
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 578590.3919
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 576779.3200
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 579334.2520
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 568375.8588
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 570338.9324
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 575960.6798
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 567483.6291
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 558948.7136
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 565638.5486
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 544383.3631
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6928377753347054 712.0697702804412 804.5866934687651 1.1299267670805448 Eagle_education_Norah
# Building Eagle_education_Will
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_24 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_25 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_12 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 79885.1853
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 78179.8744
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 75691.6512
# Epoch 4/25
# 274/274 [==============================] - 2s 8ms/step - loss: 74452.8723
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 74380.5617
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 71480.1383
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 70384.5003
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 70481.1401
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 69214.8102
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 66626.6655
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 67245.9316
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 65930.0115
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 64290.0972
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 61808.5306
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 61685.9285
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 59866.6396
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 59680.6059
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 59464.5335
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 58118.4320
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 56811.5887
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 56304.5275
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 54830.4882
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 52751.4427
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 52547.7024
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 51223.5329
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.3225867063544024 226.25485356247063 137.18718124336613 0.6063391749759204 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_26 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_27 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_13 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 4s 8ms/step - loss: 4661.4576
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 4328.6424
# Epoch 3/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4094.3689
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 3890.6287
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 3704.8327
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 3502.6630
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 3234.4599
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 3054.1093
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2927.4660
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 2731.8575
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 2578.2624
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 2484.7628
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 2387.8220
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2259.6438
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2180.3044
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 2027.4754
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1983.9590
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1928.8393
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1811.3214
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1757.2070
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1777.3665
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1658.3693
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1721.8523
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 1613.7820
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1569.7202
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.6191464903644708 57.05018764819895 43.01310384260475 0.7539520134069647 Eagle_education_Petra
# Building Eagle_lodging_Trina
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_28 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_29 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 8ms/step - loss: 15288.0733
# Epoch 2/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14717.0576
# Epoch 3/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14563.6642
# Epoch 4/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14322.6874
# Epoch 5/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14082.9072
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13049.3042
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13076.7544
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 13169.6574
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12567.4978
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 12431.4764
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 11845.8214
# Epoch 12/25
# 274/274 [==============================] - 2s 8ms/step - loss: 11787.8216
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11547.1366
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 11274.9944
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 10949.7294
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 10564.8444
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 10015.4489
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9883.7764
# Epoch 19/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9769.3123
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9679.2761
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9693.7732
# Epoch 22/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9769.1684
# Epoch 23/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9135.3288
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 8980.3444
# Epoch 25/25
# 274/274 [==============================] - 2s 7ms/step - loss: 9176.7130
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.4243310096275085 91.28035335157311 88.33609803358065 0.9677449176094615 Eagle_lodging_Trina
# Building Eagle_health_Reuben
# Building Eagle_education_Teresa
# make_DNN
# input shape: (24, 8, 1)
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 22, 6, 8)          80
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 20, 4, 8)          584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 2, 8)          0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 10, 16)            0
# _________________________________________________________________
# simple_rnn_30 (SimpleRNN)    (None, 10, 8)             200
# _________________________________________________________________
# simple_rnn_31 (SimpleRNN)    (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 24)                216
# =================================================================
# Total params: 1,216
# Trainable params: 1,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train.shape: (8748, 24, 8, 1)
# Epoch 1/25
# 274/274 [==============================] - 3s 7ms/step - loss: 31211.6775
# Epoch 2/25
# 274/274 [==============================] - 2s 7ms/step - loss: 30627.4851
# Epoch 3/25
# 274/274 [==============================] - 2s 7ms/step - loss: 30315.8913
# Epoch 4/25
# 274/274 [==============================] - 2s 7ms/step - loss: 29361.2141
# Epoch 5/25
# 274/274 [==============================] - 2s 7ms/step - loss: 28363.8710
# Epoch 6/25
# 274/274 [==============================] - 2s 7ms/step - loss: 28291.0566
# Epoch 7/25
# 274/274 [==============================] - 2s 7ms/step - loss: 28103.7275
# Epoch 8/25
# 274/274 [==============================] - 2s 7ms/step - loss: 26637.0347
# Epoch 9/25
# 274/274 [==============================] - 2s 7ms/step - loss: 26167.3013
# Epoch 10/25
# 274/274 [==============================] - 2s 7ms/step - loss: 25571.8102
# Epoch 11/25
# 274/274 [==============================] - 2s 7ms/step - loss: 24974.4456
# Epoch 12/25
# 274/274 [==============================] - 2s 7ms/step - loss: 24566.3897
# Epoch 13/25
# 274/274 [==============================] - 2s 7ms/step - loss: 23411.9211
# Epoch 14/25
# 274/274 [==============================] - 2s 7ms/step - loss: 23112.0633
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 22557.4175
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 22207.1446
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 22335.7714
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 21394.8562
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 20059.7239
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 20139.0662
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 19808.6861
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 19229.4087
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 19287.6609
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 17754.6599
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 17727.0196
# Raw y_pred.shape: (8748, 24)
# cor,mean,rmse,rmse/mean,bldg: -0.5300855283289124 148.50781927724552 109.30818018207745 0.7360432650217074 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
#
# History 24 Future 24
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8131    2032.67    2230.13  1.10   Eagle_education_Sherrill
# -0.8011    3149.69    3190.92  1.01   Eagle_education_Peter
# -0.7147     477.70     444.39  0.93   Eagle_health_Athena
# -0.6972    1197.84    1234.13  1.03   Eagle_education_Roman
# -0.6928     712.07     804.59  1.13   Eagle_education_Norah
# -0.6191      57.05      43.01  0.75   Eagle_education_Petra
# -0.5975    1635.33    1926.70  1.18   Eagle_education_Brooke
# -0.5645     182.08     117.35  0.64   Eagle_public_Alvin
# -0.5301     148.51     109.31  0.74   Eagle_education_Teresa
# -0.5294      92.83      72.24  0.78   Eagle_lodging_Dawn
# -0.4636     121.95      91.65  0.75   Eagle_health_Vincenza
# -0.4516     336.36     347.86  1.03   Eagle_office_Francis
# -0.4243      91.28      88.34  0.97   Eagle_lodging_Trina
# -0.4210      81.97      79.37  0.97   Eagle_lodging_Edgardo
# -0.3226     226.25     137.19  0.61   Eagle_education_Will
#  0.4372       0.11       0.04  0.40   Eagle_education_Wesley

# %% [markdown]
# ### Report 2
# Results on all buildings.
#
# * 0.88 mean RMSE
# * 0.22 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.91 mean RMSE
# * 0.18 stddev
