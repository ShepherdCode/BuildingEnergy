# %% [markdown]
# # RNN
# This notebook was formerly named LSTM_107.
#
# Assume user downloaded archive.zip from Kaggle, renamed the file BuildingData.zip, and stored the file in the data subdirectory. Assume the zip file contains the weather.csv file.
#
# Use RNN with SimpleRNN layers to predict steam usage based on weather.
# This notebook should be compared to LSTM_108,
# which uses LSTM layers instead.
#
# The model was trained for 25 epochs.
# The model was trained on Year 1 and tested on Year 2.
# Only selected buildings of site Eagle wered used.
#
# The predictor variables are the 8 features of weather
# over the previous 24 time periods.
# The predicted variable is the 1 steam usage feature
# over the future 1 time period.

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
STEAM_FILE='steam.csv'
WEATHER_FILE='weather.csv'
MODEL_FILE='Model'  # will be used later to save models

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed
def get_site_timeseries(panda,site):
    # Assume the panda dataframe has a datetime column.
    # (If not, call fix_date_type() before this.)
    # Extract the timeseries for one site.
    # Convert the datetime column to a DatetimeIndex.
    site_df = panda[panda['site_id']==site]
    temp_col = site_df['date']
    temp_val = temp_col.values
    temp_ndx = pd.DatetimeIndex(temp_val)
    dropped = site_df.drop('date',axis=1)
    panda = dropped.set_index(temp_ndx)
    return panda

# %%
SITE = 'Eagle'
METER = 'steam'
BLDG = 'Eagle_education_Peter'   # one example
PREDICTOR_VARIABLE = 'dewTemperature'  # for starters
PREDICTORS = ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
print("PREDICTORS=",len(PREDICTORS),PREDICTORS)
PREDICTED_VARIABLE = 'steam'  # for starters
# Out:
# PREDICTORS= 8 ['cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']

# %%
wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
wet_df = fix_date_type(wet_df)
stm_df = read_zip_to_panda(ZIP_PATH,STEAM_FILE)
stm_df = fix_date_type(stm_df)
site_specific_weather = wet_df.loc[wet_df['site_id'] == SITE]
all_buildings = [x for x in stm_df.columns if x.startswith(SITE)]

# %%
DOWNSAMPLE = False   # if true, use 1 time per day, else 24 times per day
STEPS_HISTORY = 24 
STEPS_FUTURE =  1    
def smooth(df):
    # For smoothing the 24 hour cycle, we do not want exponential smoothing.
    smoothed = None
    if DOWNSAMPLE:
        # This alternate method samples down to 1/24 time steps.
        smoothed = df.resample("24H").mean() 
    else:
        # This method does not reduce the number of time steps.
        # Note the first 23 measurements get set to Nan.
        smoothed=df.rolling(window=24).mean()
        smoothed=smoothed[24:]
    return smoothed

# Correlation is low when buildings have many NaN and 0 meter readings.
# We will ignore buildings that have >max bad meter readings.
def is_usable_column(df,column_name):
    MAX_BAD = 500 
    bad = df[column_name].isin([0]).sum()
    return bad<=MAX_BAD

def prepare_for_learning(df):
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    num_predictors = len(PREDICTORS)
    X_shape = (num_samples,STEPS_HISTORY,num_predictors)
    X=np.zeros(X_shape)
    Y_shape = (num_samples,STEPS_FUTURE)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # e.g. all weather values
    predicted_series = df[PREDICTED_VARIABLE].values  # e.g. all meter readings
    
    for x0 in range (0,num_samples): # Loop over all 1000 samples
        # This is one array of weather for previous 24 time periods
        one_sample = predictor_series[x0:x0+STEPS_HISTORY]
        one_label =  predicted_series[x0+STEPS_HISTORY:x0+STEPS_FUTURE]
        # Loop over all 24 time periods
        for x1 in range (0,STEPS_HISTORY): # In 1 sample, loop over 24 time periods
            one_period = one_sample[x1]
            for x2 in range (0,num_predictors): # In 1 time period, loop over 8 weather metrics
                one_predictor = one_period[x2]
                X[x0,x1,x2] = one_predictor
        y[x0]=predicted_series[x0:x0+STEPS_FUTURE]
    return X,y

# %%
num_predictors = len(PREDICTORS)  # e.g. 8 weather features
def make_RNN():
    rnn = Sequential([
        SimpleRNN(20,return_sequences=True, 
                  input_shape=(STEPS_HISTORY,num_predictors)), 
        SimpleRNN(10,return_sequences=False),
        Dense(STEPS_FUTURE)   
    ])
    rnn.compile(optimizer='adam',loss=MeanSquaredError())
    return rnn

# %%
cors = []
EPOCHS=25
for BLDG in all_buildings:
    print("Building",BLDG)
    # Get steam usage for one building.
    bldg_specific_steam = stm_df[[BLDG]]
    # Concatenate steam usage with weather.
    one_bldg_df = pd.concat([bldg_specific_steam,site_specific_weather],axis=1)
    # Drop the site, which is constant (we selected for one site).
    one_bldg_df = one_bldg_df.drop(['site_id'],axis=1)
    # The original steam table used column name = building name.
    # We are processing one building, so rename to the column 'steam'.
    one_bldg_df = one_bldg_df.rename(columns={BLDG : METER})
    # In order to filter bad buildings, count sum of NaN + zero.
    one_bldg_df = one_bldg_df.fillna(0)
    
    if is_usable_column(one_bldg_df,METER):
        one_bldg_df = smooth(one_bldg_df) 
        X,y = prepare_for_learning(one_bldg_df)
        # Ideally, split Year1 = train, Year2 = test.
        # Some data is incomplete, so split 1st half and 2nd half.
        split = len(X)//2 
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        print("Train on",len(X_train),"samples such as",X_train[100][0])
        print("Predict",len(y_train),"labels such as",y_train[100])

        model = make_RNN()
        print(model.summary())
        model.fit(X_train,y_train,epochs=EPOCHS)
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        # Keep a table for reporting later.
        mean = one_bldg_df[METER].mean()
        cor = one_bldg_df.corr().loc[PREDICTED_VARIABLE][PREDICTOR_VARIABLE] 
        cors.append([cor,mean,rmse,rmse/mean,BLDG])
        print("cor,mean,rmse,rmse/mean,bldg:",cor,mean,rmse,rmse/mean,BLDG)

print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Correlation of",PREDICTED_VARIABLE,"and",PREDICTOR_VARIABLE)
print("          Using one weather feature as leading correlate.")
print("Column 2: Mean usage.")
print("          Using mean to help understand the RMSE.")
print("Column 3: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 4: RMSE/mean normalized to help understand RMSE.")
print("Column 5: Building.")
for cor in sorted(cors):
    print("%7.4f %10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3],cor[4]))
# Out:
# Building Eagle_office_Lamont
# Building Eagle_health_Athena
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [856.91]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 5s 11ms/step - loss: 343108.7625
# Epoch 2/25
# 274/274 [==============================] - 3s 11ms/step - loss: 342032.0261
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 335312.2940
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 324116.9731
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 318690.4561
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 323373.7386
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 320012.5808
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 314408.6568
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 311789.4760
# Epoch 10/25
# 274/274 [==============================] - 3s 10ms/step - loss: 313093.7775
# Epoch 11/25
# 274/274 [==============================] - 3s 10ms/step - loss: 307549.4691
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 303689.8799
# Epoch 13/25
# 274/274 [==============================] - 3s 11ms/step - loss: 304450.8867
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 297282.7988
# Epoch 15/25
# 274/274 [==============================] - 2s 7ms/step - loss: 292354.8931
# Epoch 16/25
# 274/274 [==============================] - 2s 7ms/step - loss: 291666.2236
# Epoch 17/25
# 274/274 [==============================] - 2s 7ms/step - loss: 286743.8259
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 282774.0967
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 289057.0858
# Epoch 20/25
# 274/274 [==============================] - 2s 7ms/step - loss: 283372.0524
# Epoch 21/25
# 274/274 [==============================] - 2s 7ms/step - loss: 278465.7682
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 272314.4752
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 275332.3239
# Epoch 24/25
# 274/274 [==============================] - 2s 7ms/step - loss: 268076.7686
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 266527.5177
# cor,mean,rmse,rmse/mean,bldg: -0.8403439150973826 477.4110643545475 411.287280777319 0.8614950751788151 Eagle_health_Athena
# Building Eagle_assembly_Herbert
# Building Eagle_public_Alvin
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [424.34]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 52053.4643
# Epoch 2/25
# 274/274 [==============================] - 2s 9ms/step - loss: 49977.0677
# Epoch 3/25
# 274/274 [==============================] - 3s 9ms/step - loss: 48733.8279
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 47731.7854
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 47251.2986
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 45889.1937
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 44203.5462
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 43892.3567
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 42155.3604
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 41449.7300
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 39450.8741
# Epoch 12/25
# 274/274 [==============================] - 2s 8ms/step - loss: 38969.4739
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 38403.2800
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 37259.8160
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 36837.5107
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 35645.4992
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 34766.7304
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 34222.7802
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 32493.0875
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 32210.4867
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 31230.7119
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 29796.4691
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 29091.9563
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 28887.9708
# Epoch 25/25
# 274/274 [==============================] - 3s 10ms/step - loss: 27955.7265
# cor,mean,rmse,rmse/mean,bldg: -0.759617507777322 181.93965687500085 95.05416074499611 0.522448829340718 Eagle_public_Alvin
# Building Eagle_education_Raul
# Building Eagle_education_Roman
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [2374.16]
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 5s 11ms/step - loss: 1644702.2123
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1633408.9555
# Epoch 3/25
# 274/274 [==============================] - 3s 11ms/step - loss: 1638853.4218
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1619005.2932
# Epoch 5/25
# 274/274 [==============================] - 4s 13ms/step - loss: 1618290.0227
# Epoch 6/25
# 274/274 [==============================] - 3s 11ms/step - loss: 1606778.2045
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1625682.9555
# Epoch 8/25
# 274/274 [==============================] - 3s 11ms/step - loss: 1616610.6764
# Epoch 9/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1574531.3305
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1571883.0414
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1584350.9982
# Epoch 12/25
# 274/274 [==============================] - 3s 10ms/step - loss: 1593942.9659
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1589028.6841
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1572414.0364
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 1518322.6005
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1544413.8032
# Epoch 17/25
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3065.8821
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2976.1710
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2917.9541
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2736.5753
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2688.2480
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2622.9461
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 2434.8088
# cor,mean,rmse,rmse/mean,bldg: -0.7222281821273872 81.87169456264256 44.6694397236307 0.545602970138266 Eagle_lodging_Edgardo
# Building Eagle_education_Cassie
# Building Eagle_education_Peter
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [6895.45]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_8 (SimpleRNN)     (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_9 (SimpleRNN)     (None, 10)                310
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 9ms/step - loss: 12875570.6364
# Epoch 2/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12551018.1564
# Epoch 3/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12761146.5236
# Epoch 4/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12750644.6382
# Epoch 5/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12717156.7745
# Epoch 6/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12539881.1927
# Epoch 7/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12659991.9527
# Epoch 8/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12583485.1309
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12563269.9200
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12767831.4982
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12793103.7200
# Epoch 12/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12591695.9309
# Epoch 13/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12392664.2764
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12573561.8618
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12414668.1673
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12451201.1382
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12525106.5055
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12290585.6982
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12241044.6145
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12693694.3782
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12278000.0364
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12368041.6291
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12270951.6545
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12412852.2291
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12511881.8691
# cor,mean,rmse,rmse/mean,bldg: -0.850213186834573 3147.430703431568 3143.6629532615852 0.9988029124308043 Eagle_education_Peter
# Building Eagle_health_Gregoria
# Building Eagle_lodging_Dawn
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [256.52]
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_10 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 12551.6485
# Epoch 2/25
# 274/274 [==============================] - 2s 9ms/step - loss: 11785.4830
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 11117.0237
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 10565.4755
# Epoch 5/25
# 274/274 [==============================] - 3s 9ms/step - loss: 10261.6489
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 9690.6772
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 9220.1343
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 8766.6326
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 8239.3272
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 7953.0789
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 7768.1200
# Epoch 12/25
# 274/274 [==============================] - 2s 8ms/step - loss: 7204.5428
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6901.3221
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 6402.0037
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6387.2195
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6099.9875
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5711.1536
# Epoch 18/25
# 274/274 [==============================] - 3s 12ms/step - loss: 5536.8907
# Epoch 19/25
# 274/274 [==============================] - 3s 11ms/step - loss: 5149.9196
# Epoch 20/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4961.4625
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4772.5636
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4548.8720
# Epoch 23/25
# 274/274 [==============================] - 3s 10ms/step - loss: 4384.8697
# Epoch 24/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3994.1317
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3769.0239
# cor,mean,rmse,rmse/mean,bldg: -0.7129673388128998 92.73484781606874 50.91857727030335 0.5490770564620517 Eagle_lodging_Dawn
# Building Eagle_office_Nereida
# Building Eagle_lodging_Tressa
# Building Eagle_education_Eileen
# Building Eagle_education_Wesley
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [0.08]
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_12 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_13 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 5s 12ms/step - loss: 0.0807
# Epoch 2/25
# 274/274 [==============================] - 4s 13ms/step - loss: 3.6078e-04
# Epoch 3/25
# 274/274 [==============================] - 3s 9ms/step - loss: 3.5715e-04
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.5705e-04
# Epoch 5/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.5822e-04
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3.4211e-04
# Epoch 7/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.5697e-04
# Epoch 8/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3.4764e-04
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6928e-04
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6488e-04
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6552e-04
# Epoch 12/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.7684e-04
# Epoch 13/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.5830e-04
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.5414e-04
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6837e-04
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.8739e-04
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6709e-04
# Epoch 18/25
# 274/274 [==============================] - 2s 7ms/step - loss: 3.7771e-04
# Epoch 19/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.9622e-04
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4.3833e-04
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.7409e-04
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6928e-04
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6420e-04
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 3.6083e-04
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4.1250e-04
# cor,mean,rmse,rmse/mean,bldg: 0.7230993469793111 0.10523124548135475 0.028967793842814206 0.2752774968148298 Eagle_education_Wesley
# Building Eagle_health_Vincenza
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [201.49]
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_14 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_15 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 9ms/step - loss: 15307.6921
# Epoch 2/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14332.6064
# Epoch 3/25
# 274/274 [==============================] - 2s 8ms/step - loss: 13562.6416
# Epoch 4/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12986.3890
# Epoch 5/25
# 274/274 [==============================] - 2s 8ms/step - loss: 12403.2812
# Epoch 6/25
# 274/274 [==============================] - 2s 8ms/step - loss: 11938.7271
# Epoch 7/25
# 274/274 [==============================] - 2s 8ms/step - loss: 11098.9775
# Epoch 8/25
# 274/274 [==============================] - 2s 8ms/step - loss: 10636.2224
# Epoch 9/25
# 274/274 [==============================] - 2s 8ms/step - loss: 10138.2411
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 9611.8302
# Epoch 11/25
# 274/274 [==============================] - 2s 8ms/step - loss: 9293.8446
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 8769.0218
# Epoch 13/25
# 274/274 [==============================] - 2s 8ms/step - loss: 8229.6123
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 7889.9667
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 7403.9950
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 7075.5446
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6612.7695
# Epoch 18/25
# 274/274 [==============================] - 2s 8ms/step - loss: 6367.8361
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5981.3628
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5520.4154
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5214.7158
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4930.4601
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4629.9944
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4409.3568
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 4161.7564
# cor,mean,rmse,rmse/mean,bldg: -0.7961450049576672 121.90840096508735 63.49464412292376 0.5208389546599633 Eagle_health_Vincenza
# Building Eagle_office_Dallas
# Building Eagle_education_Shante
# Building Eagle_office_Chauncey
# Building Eagle_office_Phyllis
# Building Eagle_office_Freida
# Building Eagle_office_Francis
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [412.35]
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_18 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_19 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 5308014.8218
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5326652.4436
# Epoch 3/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5257578.3545
# Epoch 4/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5390694.5600
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5287182.2945
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5236880.7927
# Epoch 7/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5275181.4673
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5373639.6964
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5343735.6236
# Epoch 10/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5370348.8727
# Epoch 11/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5346519.4182
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5267744.8691
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5165046.4855
# Epoch 14/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5188675.5309
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5177841.9891
# Epoch 16/25
# 274/274 [==============================] - 2s 8ms/step - loss: 5302839.8982
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5300042.4436
# Epoch 18/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5192726.7427
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5169302.8073
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5091405.1909
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5132919.9764
# Epoch 22/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5071315.3564
# Epoch 23/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5039137.5800
# Epoch 24/25
# 274/274 [==============================] - 3s 9ms/step - loss: 5063959.6309
# Epoch 25/25
# 274/274 [==============================] - 2s 9ms/step - loss: 5056365.7491
# cor,mean,rmse,rmse/mean,bldg: -0.8876757978269461 2030.3587884358292 2175.2783247884317 1.071376318893986 Eagle_education_Sherrill
# Building Eagle_education_Brooke
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [3581.43]
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_22 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_23 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 607741.6859
# Epoch 2/25
# 274/274 [==============================] - 2s 9ms/step - loss: 599062.3536
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 583243.5082
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 590208.2130
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 577150.6739
# Epoch 6/25
# 274/274 [==============================] - 3s 11ms/step - loss: 588233.8716
# Epoch 7/25
# 274/274 [==============================] - 3s 11ms/step - loss: 570102.6631
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 564728.4603
# Epoch 9/25
# 274/274 [==============================] - 3s 11ms/step - loss: 562817.2844
# Epoch 10/25
# 274/274 [==============================] - 3s 11ms/step - loss: 553941.0791
# Epoch 11/25
# 274/274 [==============================] - 3s 9ms/step - loss: 554766.1901
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 556156.4634
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 548243.2058
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 538553.7785
# Epoch 15/25
# 274/274 [==============================] - 2s 8ms/step - loss: 540651.9818
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 534746.6267
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 548701.1025
# Epoch 18/25
# 274/274 [==============================] - 3s 9ms/step - loss: 533959.9857
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 523477.4453
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 520875.3231
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 520375.1547
# Epoch 22/25
# 274/274 [==============================] - 2s 9ms/step - loss: 516876.4576
# Epoch 23/25
# 274/274 [==============================] - 2s 9ms/step - loss: 515318.4974
# Epoch 24/25
# 274/274 [==============================] - 2s 9ms/step - loss: 502910.7577
# Epoch 25/25
# 274/274 [==============================] - 2s 9ms/step - loss: 506648.1157
# cor,mean,rmse,rmse/mean,bldg: -0.7722467071075976 711.3309670245889 765.8381929435996 1.0766270954672588 Eagle_education_Norah
# Building Eagle_education_Will
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [297.45]
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_24 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_25 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 76087.3440
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 74612.6240
# Epoch 3/25
# 274/274 [==============================] - 3s 10ms/step - loss: 71360.1324
# Epoch 4/25
# 274/274 [==============================] - 3s 10ms/step - loss: 71001.0382
# Epoch 5/25
# 274/274 [==============================] - 3s 9ms/step - loss: 70394.7283
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 67767.1370
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 65037.1563
# Epoch 8/25
# 274/274 [==============================] - 3s 9ms/step - loss: 64786.5777
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 63256.0251
# Epoch 10/25
# 274/274 [==============================] - 2s 9ms/step - loss: 61109.0404
# Epoch 11/25
# 274/274 [==============================] - 2s 9ms/step - loss: 60258.4974
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 59811.6472
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 58368.6908
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 57069.2950
# Epoch 15/25
# 274/274 [==============================] - 2s 9ms/step - loss: 55251.0273
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 55405.0122
# Epoch 17/25
# 274/274 [==============================] - 2s 9ms/step - loss: 52596.1561
# Epoch 18/25
# 274/274 [==============================] - 2s 9ms/step - loss: 50805.0361
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 50904.8746
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 48837.1406
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 48166.2124
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 47215.9631
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 46365.7027
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 44158.2233
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 43593.6882
# cor,mean,rmse,rmse/mean,bldg: -0.3578536854358871 226.06948909769716 120.11833982762568 0.531333707644714 Eagle_education_Will
# Building Eagle_lodging_Blake
# Building Eagle_education_Petra
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [135.07]
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_26 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_27 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 4183.3262
# Epoch 2/25
# 274/274 [==============================] - 3s 10ms/step - loss: 3653.0435
# Epoch 3/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3353.4639
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 3171.1104
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 2923.8189
# Epoch 6/25
# 274/274 [==============================] - 2s 9ms/step - loss: 2708.5759
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 2533.0654
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 2344.9738
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 2134.6894
# Epoch 10/25
# 274/274 [==============================] - 2s 9ms/step - loss: 2030.5927
# Epoch 11/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1892.7235
# Epoch 12/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1792.2078
# Epoch 13/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1719.2164
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1645.4145
# Epoch 15/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1511.3418
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1363.2113
# Epoch 17/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1415.9550
# Epoch 18/25
# 274/274 [==============================] - 3s 9ms/step - loss: 1411.2153
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1303.6415
# Epoch 20/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1227.3947
# Epoch 21/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1255.7804
# Epoch 22/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1209.9841
# Epoch 23/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1154.4400
# Epoch 24/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1204.7786
# Epoch 25/25
# 274/274 [==============================] - 2s 9ms/step - loss: 1237.5562
# cor,mean,rmse,rmse/mean,bldg: -0.7988023057131248 56.96274977501869 28.985163609299583 0.5088441784109793 Eagle_education_Petra
# Building Eagle_lodging_Trina
# Train on 8747 samples such as [   0.     -7.17  -17.68    0.      0.   1035.42  195.      2.19]
# Predict 8747 labels such as [304.34]
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_28 (SimpleRNN)    (None, 24, 20)            580
# _________________________________________________________________
# simple_rnn_29 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 901
# Trainable params: 901
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 274/274 [==============================] - 4s 10ms/step - loss: 10673.8066
# Epoch 2/25
# 274/274 [==============================] - 3s 9ms/step - loss: 10526.8145
# Epoch 3/25
# 274/274 [==============================] - 3s 9ms/step - loss: 10043.6246
# Epoch 4/25
# 274/274 [==============================] - 2s 9ms/step - loss: 9887.2219
# Epoch 5/25
# 274/274 [==============================] - 2s 9ms/step - loss: 8924.6809
# Epoch 6/25
# 274/274 [==============================] - 3s 9ms/step - loss: 8683.1678
# Epoch 7/25
# 274/274 [==============================] - 2s 9ms/step - loss: 8599.7606
# Epoch 8/25
# 274/274 [==============================] - 2s 9ms/step - loss: 8239.7620
# Epoch 9/25
# 274/274 [==============================] - 2s 9ms/step - loss: 7427.9019
# Epoch 10/25
# 274/274 [==============================] - 2s 8ms/step - loss: 19061.5650
# Epoch 14/25
# 274/274 [==============================] - 2s 9ms/step - loss: 19008.0978
# Epoch 15/25
# 274/274 [==============================] - 3s 10ms/step - loss: 17437.6145
# Epoch 16/25
# 274/274 [==============================] - 2s 9ms/step - loss: 17479.0252
# Epoch 17/25
# 274/274 [==============================] - 2s 8ms/step - loss: 17306.8725
# Epoch 18/25
# 274/274 [==============================] - 2s 9ms/step - loss: 16329.4416
# Epoch 19/25
# 274/274 [==============================] - 2s 9ms/step - loss: 16018.7438
# Epoch 20/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14671.2635
# Epoch 21/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14855.4819
# Epoch 22/25
# 274/274 [==============================] - 2s 8ms/step - loss: 14144.3552
# Epoch 23/25
# 274/274 [==============================] - 2s 8ms/step - loss: 13650.0562
# Epoch 24/25
# 274/274 [==============================] - 2s 8ms/step - loss: 13411.7707
# Epoch 25/25
# 274/274 [==============================] - 2s 8ms/step - loss: 13123.5994
# cor,mean,rmse,rmse/mean,bldg: -0.6796379179294123 148.50737262033823 84.24727190190819 0.5672935317311677 Eagle_education_Teresa
# Building Eagle_office_Norbert
# Building Eagle_lodging_Casey
# Building Eagle_office_Tia
# Building Eagle_office_Remedios
# Building Eagle_office_Patrice
# Building Eagle_education_Shana
# History 24 Future 1
# Column 1: Correlation of steam and dewTemperature
#           Using one weather feature as leading correlate.
# Column 2: Mean usage.
#           Using mean to help understand the RMSE.
# Column 3: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 4: RMSE/mean normalized to help understand RMSE.
# Column 5: Building.
# -0.8877    2030.36    2175.28  1.07   Eagle_education_Sherrill
# -0.8545    1634.28    1635.79  1.00   Eagle_education_Brooke
# -0.8502    3147.43    3143.66  1.00   Eagle_education_Peter
# -0.8403     477.41     411.29  0.86   Eagle_health_Athena
# -0.8186    1197.02    1187.55  0.99   Eagle_education_Roman
# -0.7988      56.96      28.99  0.51   Eagle_education_Petra
# -0.7961     121.91      63.49  0.52   Eagle_health_Vincenza
# -0.7722     711.33     765.84  1.08   Eagle_education_Norah
# -0.7596     181.94      95.05  0.52   Eagle_public_Alvin
# -0.7222      81.87      44.67  0.55   Eagle_lodging_Edgardo
# -0.7130      92.73      50.92  0.55   Eagle_lodging_Dawn
# -0.6796     148.51      84.25  0.57   Eagle_education_Teresa
# -0.6741      91.20      48.48  0.53   Eagle_lodging_Trina
# -0.5553     335.96     325.05  0.97   Eagle_office_Francis
# -0.3579     226.07     120.12  0.53   Eagle_education_Will
#  0.7231       0.11       0.03  0.28   Eagle_education_Wesley

# %% [markdown]
# ### Report 1
# Report 1, Table I, includes the following summary. This is the mean over 16 builings of the normalized RMSE per building.
#
# Simple RNN model using predictions based on 24 times, 8 features
#
# * 0.72 mean RMSE
# * 0.27 stddev
#
# Here are the results omitting outlier building Wesley.
#
# * 0.75 mean RMSE
# * 0.24 stddev
