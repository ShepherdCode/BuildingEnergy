# %% [markdown]
# # RNN
# Restructured code. Compare to RNN 217.
#
# No smoothing.
# Train on hours 1-12, predict hours 25-36
# (e.g. yesterday AM predicts today AM).
# Predictors: month, day-of-year, hour-of-day
# Predicted variable: steam
# Train for 50 epochs.

# %%
from os import listdir
import csv
from zipfile import ZipFile
import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.losses import MeanSquaredError

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
# Constants
EPOCHS=50  # use 5 for software testing, 50 for model testing
SITE = 'Eagle'
PREDICTORS = ['hour','month','doy','meter','cloudCoverage', 'airTemperature', 'dewTemperature', 'precipDepth1HR', 'precipDepth6HR', 'seaLvlPressure', 'windDirection', 'windSpeed']
PREDICTORS = ['hour','doy','meter'] # short list for testing
NUM_PREDICTORS=len(PREDICTORS)
print("PREDICTORS=",NUM_PREDICTORS,PREDICTORS)
PREDICTED_VARIABLE = 'meter'  
STEPS_HISTORY = 24
STEPS_FORWARD = 12 
STEPS_FUTURE =  12 
METER_FILE='steam.csv'
WEATHER_FILE='weather.csv'
EXAMPLE='Eagle_lodging_Edgardo'
SITE_BUILDINGS = None
# Out:
# PREDICTORS= 3 ['hour', 'doy', 'meter']

# %%
DATAPATH=''
try:
    # On Google Drive, set path to my drive / data directory.
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    # On home computer, set path to local data directory.
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"

ZIP_FILE='BuildingData.zip'
ZIP_PATH = DATAPATH+ZIP_FILE
MODEL_FILE='Model'  # will be used later to save models
# Out:
# Mounted at /content/drive/

# %%
def read_zip_to_panda(zip_filename,csv_filename):
    zip_handle = ZipFile(zip_filename)
    csv_handle = zip_handle.open(csv_filename)
    panda = pd.read_csv(csv_handle)
    return panda
def fix_date_type(panda):
    # Convert the given timestamp column to the pandas datetime data type.
    panda['timestamp'] = pd.to_datetime(panda['timestamp'], infer_datetime_format = True)
    indexed = panda.set_index(['timestamp'])
    return indexed

# %%
def load_weather_for_site(site):
    wet_df = read_zip_to_panda(ZIP_PATH,WEATHER_FILE)
    wet_df = fix_date_type(wet_df)
    site_df = wet_df.loc[wet_df['site_id'] == site]
    # Drop the site, which is constant (we selected for one site).
    site_df = site_df.drop(['site_id'],axis=1)
    site_df.insert(0,'hour',0)
    site_df.insert(1,'month',0)
    site_df.insert(2,'doy',0)
    L=len(site_df)
    for i in range(0,L):
        dt=site_df.index[i]
        hour=dt.hour
        month=dt.month
        doy=dt.dayofyear
        site_df.iat[i,0] = hour
        site_df.iat[i,1] = month
        site_df.iat[i,2] = doy
    return site_df

one_site_weather = load_weather_for_site(SITE)
one_site_weather.tail()
# Out:
#                      hour  month  doy  ...  seaLvlPressure  windDirection  windSpeed
# timestamp                              ...
# 2017-12-31 18:00:00    18     12  365  ...          1026.2          330.0        2.6
# 2017-12-31 20:00:00    20     12  365  ...          1027.0          320.0        1.5
# 2017-12-31 21:00:00    21     12  365  ...          1027.2          310.0        2.6
# 2017-12-31 22:00:00    22     12  365  ...          1027.4          330.0        3.1
# 2017-12-31 23:00:00    23     12  365  ...          1027.4          320.0        4.6
#
# [5 rows x 11 columns]

# %%
def load_meter_for_building(bldg):
    all_df = read_zip_to_panda(ZIP_PATH,METER_FILE)
    all_df = fix_date_type(all_df)
    global SITE_BUILDINGS
    SITE_BUILDINGS = [x for x in all_df.columns if x.startswith(SITE)]
    site_series = all_df[bldg]
    site_df = site_series.to_frame()
    #site_df = all_df.loc[all_df['site_id'] == site]
    # Change column name from building name to meter.
    site_df = site_df.rename(columns={bldg : PREDICTED_VARIABLE})
    return site_df

one_bldg_meter = load_meter_for_building(EXAMPLE)
print(type(one_bldg_meter))
one_bldg_meter.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                         meter
# timestamp
# 2017-12-31 19:00:00   92.2957
# 2017-12-31 20:00:00  277.5584
# 2017-12-31 21:00:00  280.5331
# 2017-12-31 22:00:00  289.3302
# 2017-12-31 23:00:00  164.3474

# %%
# TO DO: add smoothing to X
def prepare_for_learning(wdf,mdf):
    # Concatenate weather and meter.
    df = pd.concat([wdf,mdf],axis=1)
    num_samples = len(df) - STEPS_FUTURE - STEPS_HISTORY
    X_shape = (num_samples,STEPS_FUTURE,NUM_PREDICTORS)
    Y_shape = (num_samples,STEPS_FUTURE)
    X=np.zeros(X_shape)
    y=np.zeros(Y_shape)
    predictor_series = df[PREDICTORS].values  # selected features
    predicted_series = df[PREDICTED_VARIABLE].values  # meter
    # TO DO: can we take predicted from mdf instead?
    for sam in range (0,num_samples): 
        prev_val = 0
        one_sample = predictor_series[sam:sam+STEPS_FORWARD]
        for time in range (0,STEPS_FORWARD): 
            one_period = one_sample[time]
            for feat in range (0,NUM_PREDICTORS):
                val = one_period[feat]
                if np.isnan(val):
                    val = prev_val
                else:
                    prev_val = val
                X[sam,time,feat] = val
        for time in range (0,STEPS_FUTURE):  
            y[sam,time]=predicted_series[sam+STEPS_HISTORY+time]
    return X,y 
X,y = prepare_for_learning(one_site_weather,one_bldg_meter)
print("X shape:",X.shape)
print("y shape:",y.shape)
# Out:
# X shape: (17508, 12, 3)
# y shape: (17508, 12)

# %%
print("X columns:",PREDICTORS)
print("X example:\n",X[100].astype(int))
print("y example:\n",y[100].astype(int))
# Out:
# X columns: ['hour', 'doy', 'meter']
# X example:
#  [[  4   5 232]
#  [  5   5 253]
#  [  6   5 251]
#  [  7   5 135]
#  [  8   5 259]
#  [  9   5 326]
#  [ 10   5 320]
#  [ 11   5 364]
#  [ 12   5 342]
#  [ 13   5 296]
#  [ 14   5  45]
#  [ 15   5  56]]
# y example:
#  [ 43 119 327 322 273  92 328 363 346 168 266  27]

# %%
def make_RNN():
    # The GRU in Keras is optimized for speed on CoLab GPU.
    rnn = Sequential([
        GRU(16,return_sequences=True, 
                  input_shape=(STEPS_FORWARD,NUM_PREDICTORS)), 
        GRU(16,return_sequences=True),
        GRU(16,return_sequences=False),
        Dense(STEPS_FUTURE)
    ])
    rnn.compile(optimizer='adam',loss=MeanSquaredError())
    return rnn

# %%
cors = []
one_site_weather = load_weather_for_site(SITE)
for BLDG in SITE_BUILDINGS:
    print("Building",BLDG)
    one_bldg_meter = load_meter_for_building(BLDG)
    count_bad = one_bldg_meter[PREDICTED_VARIABLE].isna().sum()
    MAX_BAD = 500
    if count_bad<=MAX_BAD:
        # Must get rid of Nan labels, else loss hits NaN during training.
        print(" Count bad values before:",count_bad)
        pseudovalue = one_bldg_meter[PREDICTED_VARIABLE].mean()
        one_bldg_meter = one_bldg_meter.fillna(pseudovalue)
        count_bad = one_bldg_meter[PREDICTED_VARIABLE].isna().sum()
        print(" Count bad values after:",count_bad)
        # 
        X,y = prepare_for_learning(one_site_weather,one_bldg_meter)
        split = len(X)//2   # year 1 vs year 2
        X_train = np.asarray(X[0:split])
        y_train = np.asarray(y[0:split])
        X_test = np.asarray(X[split:])
        y_test = np.asarray(y[split:])
        model = make_RNN()
        print(model.summary())
        #print("Example X train:\n",X_train[example].astype(int))
        example=411
        print("Example y train:\n",y_train[example].astype(int))
        model.fit(X_train,y_train,epochs=EPOCHS)
        # Keep a table for reporting later.
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test,y_pred,squared=False)
        mean = one_bldg_meter[PREDICTED_VARIABLE].mean()
        cors.append([mean,rmse,rmse/mean,BLDG])
        print("mean,rmse,rmse/mean,bldg:",mean,rmse,rmse/mean,BLDG)
        for hr in range(0,24,2):
            print("Example prediction:\n",hr,y_pred[example+hr].astype(int))

print()
print("History",STEPS_HISTORY,"Future",STEPS_FUTURE)
print("Column 1: Mean usage.")
print("Column 2: RMSE of LinearRegression(X=Weather, y=Usage).")
print("Column 3: RMSE/mean normalized to help understand RMSE.")
print("Column 4: Building.")
for cor in sorted(cors):
    print("%10.2f %10.2f %5.2f   %s"%(cor[0],cor[1],cor[2],cor[3]))
# Out:
# Building Eagle_office_Lamont
#  Count bad values before: 8
#  Count bad values after: 0
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_135 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_136 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_137 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_45 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [60 74 71 71 74 71 77 70 65 72 74 69]
# Epoch 1/50
# 274/274 [==============================] - 5s 6ms/step - loss: 1236.3738
# Epoch 2/50
# 274/274 [==============================] - 2s 6ms/step - loss: 937.4079
# Epoch 3/50
# 274/274 [==============================] - 2s 6ms/step - loss: 716.1115
# Epoch 4/50
# Epoch 42/50
# 274/274 [==============================] - 2s 6ms/step - loss: 52.3059
# Epoch 43/50
# 274/274 [==============================] - 2s 6ms/step - loss: 55.9532
# Epoch 44/50
# 274/274 [==============================] - 2s 6ms/step - loss: 52.3968
# Epoch 45/50
# 274/274 [==============================] - 2s 6ms/step - loss: 54.6489
# Epoch 46/50
# 274/274 [==============================] - 2s 6ms/step - loss: 54.3010
# Epoch 47/50
# 274/274 [==============================] - 2s 6ms/step - loss: 54.7026
# Epoch 48/50
# 274/274 [==============================] - 2s 6ms/step - loss: 54.5008
# Epoch 49/50
# 274/274 [==============================] - 2s 6ms/step - loss: 51.9471
# Epoch 50/50
# 274/274 [==============================] - 2s 6ms/step - loss: 50.0978
# mean,rmse,rmse/mean,bldg: 36.926709665830415 10.638746321016995 0.28810436719904675 Eagle_office_Lamont
# Example prediction:
#  0 [54 55 55 56 56 56 57 57 57 57 56 55]
# Example prediction:
#  2 [54 55 55 56 56 57 57 57 57 57 56 55]
# Example prediction:
#  4 [53 54 55 55 55 56 56 56 56 56 55 54]
# Example prediction:
#  6 [53 54 55 55 55 56 56 56 56 56 55 54]
# Example prediction:
#  8 [53 54 54 55 55 55 56 56 56 55 55 54]
# Example prediction:
#  10 [49 49 49 49 49 49 49 49 49 49 49 49]
# Example prediction:
#  12 [48 48 48 48 49 49 48 48 48 48 48 48]
# Example prediction:
#  14 [46 46 46 46 46 46 46 46 46 46 46 46]
# Example prediction:
#  16 [44 43 43 43 43 43 43 43 43 43 43 43]
# Example prediction:
#  18 [44 44 44 44 44 44 44 44 44 44 44 44]
# Example prediction:
#  20 [47 48 48 48 48 48 49 49 49 49 49 48]
# Example prediction:
#  22 [49 50 50 50 51 51 52 52 52 51 51 50]
# Building Eagle_health_Athena
#  Count bad values before: 0
#  Count bad values after: 0
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_138 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_139 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_140 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_46 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [1383 1299 1280  984  892 1005  606  847  948 1203 1312 1234]
# Epoch 1/50
# 274/274 [==============================] - 5s 6ms/step - loss: 360841.1791
# Epoch 2/50
# 274/274 [==============================] - 2s 6ms/step - loss: 362775.1426
# Epoch 3/50
# 274/274 [==============================] - 2s 6ms/step - loss: 357306.1519
# Epoch 4/50
# 274/274 [==============================] - 2s 6ms/step - loss: 350499.0799
# Epoch 5/50
# 274/274 [==============================] - 2s 7ms/step - loss: 338052.0229
# Epoch 6/50
# 274/274 [==============================] - 2s 6ms/step - loss: 343072.0926
# Epoch 7/50
# 274/274 [==============================] - 2s 6ms/step - loss: 339752.1497
# Epoch 8/50
# 274/274 [==============================] - 2s 6ms/step - loss: 331857.8240
# Epoch 9/50
# 274/274 [==============================] - 2s 6ms/step - loss: 328648.6957
# 274/274 [==============================] - 2s 7ms/step - loss: 192321.7131
# Epoch 47/50
# 274/274 [==============================] - 2s 6ms/step - loss: 186325.8405
# Epoch 48/50
# 274/274 [==============================] - 2s 6ms/step - loss: 186206.2165
# Epoch 49/50
# 274/274 [==============================] - 2s 6ms/step - loss: 185163.3028
# Epoch 50/50
# 274/274 [==============================] - 2s 6ms/step - loss: 178926.1080
# mean,rmse,rmse/mean,bldg: 477.70168061445776 325.7617585260037 0.6819355504610809 Eagle_health_Athena
# Example prediction:
#  0 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  2 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  4 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  6 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  8 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  10 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  12 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  14 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  16 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  18 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  20 [225 225 225 224 224 225 225 223 224 226 224 225]
# Example prediction:
#  22 [225 225 225 224 224 225 225 223 224 226 224 225]
# Building Eagle_assembly_Herbert
#  Count bad values before: 393
#  Count bad values after: 0
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_141 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_142 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_143 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_47 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [135 149  44  80  12  32  30  30  26  29  33 172]
# Epoch 1/50
# 274/274 [==============================] - 6s 6ms/step - loss: 85877.7812
# Epoch 2/50
# 274/274 [==============================] - 2s 6ms/step - loss: 83993.4478
# Epoch 3/50
# 274/274 [==============================] - 2s 6ms/step - loss: 80851.4651
# Epoch 4/50
# 274/274 [==============================] - 2s 6ms/step - loss: 81229.9076
# Epoch 5/50
# 274/274 [==============================] - 2s 6ms/step - loss: 78706.5681
# Epoch 6/50
# 274/274 [==============================] - 2s 6ms/step - loss: 77337.7490
# Epoch 7/50
# 274/274 [==============================] - 2s 6ms/step - loss: 76782.0680
# Epoch 8/50
# 274/274 [==============================] - 2s 7ms/step - loss: 75072.5461
# Epoch 9/50
# 274/274 [==============================] - 2s 6ms/step - loss: 71767.9273
# Epoch 10/50
# 274/274 [==============================] - 2s 6ms/step - loss: 70464.5657
# Epoch 11/50
# 274/274 [==============================] - 2s 6ms/step - loss: 69214.8516
# Epoch 12/50
# 274/274 [==============================] - 2s 6ms/step - loss: 68587.5355
# Epoch 13/50
# 274/274 [==============================] - 2s 6ms/step - loss: 67659.1592
# Epoch 14/50
# mean,rmse,rmse/mean,bldg: 216.03328870036609 244.83290304792206 1.1333110027663398 Eagle_assembly_Herbert
# Example prediction:
#  0 [156 156 156 156 154 155 157 157 154 155 155 155]
# Example prediction:
#  2 [179 180 180 180 178 179 181 181 178 179 179 179]
# Example prediction:
#  4 [205 205 206 205 204 205 206 207 204 206 206 206]
# Example prediction:
#  6 [205 206 207 206 204 206 207 207 204 206 206 206]
# Example prediction:
#  8 [205 206 207 206 204 206 207 207 204 206 206 206]
# Example prediction:
#  10 [205 206 207 206 204 206 207 207 204 206 206 206]
# Example prediction:
#  12 [205 206 207 206 204 206 207 207 204 206 206 206]
# Example prediction:
#  14 [205 206 207 206 204 206 207 207 204 206 206 206]
# Example prediction:
#  16 [205 206 206 205 204 206 207 207 204 206 206 206]
# Example prediction:
#  18 [205 206 206 205 204 206 207 207 204 206 206 206]
# Example prediction:
#  20 [205 206 206 205 204 206 207 207 204 206 206 206]
# Example prediction:
#  22 [205 206 206 205 204 206 207 207 204 206 206 206]
# Building Eagle_public_Alvin
#  Count bad values before: 0
#  Count bad values after: 0
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_144 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_145 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_146 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_48 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [687 432 286 547 109 237 541 523 486 535 389 426]
# Epoch 1/50
# 274/274 [==============================] - 5s 6ms/step - loss: 61601.4735
# Epoch 2/50
# 274/274 [==============================] - 2s 6ms/step - loss: 60181.2177
# Epoch 3/50
# 274/274 [==============================] - 2s 6ms/step - loss: 57292.0475
# Epoch 4/50
# 274/274 [==============================] - 2s 6ms/step - loss: 55955.7127
# Epoch 5/50
# 274/274 [==============================] - 2s 6ms/step - loss: 54225.8262
# Epoch 6/50
# 274/274 [==============================] - 2s 7ms/step - loss: 52256.0089
# Epoch 7/50
# 274/274 [==============================] - 2s 6ms/step - loss: 50740.8562
# Epoch 8/50
# 274/274 [==============================] - 2s 6ms/step - loss: 48495.6613
# Epoch 9/50
# 274/274 [==============================] - 2s 6ms/step - loss: 47866.3178
# Epoch 10/50
# 274/274 [==============================] - 2s 6ms/step - loss: 46640.0593
# Epoch 11/50
# 274/274 [==============================] - 2s 6ms/step - loss: 44401.6231
# Epoch 12/50
# 274/274 [==============================] - 2s 7ms/step - loss: 42403.8689
# Epoch 13/50
# 274/274 [==============================] - 2s 6ms/step - loss: 41634.0957
# Epoch 14/50
# 274/274 [==============================] - 2s 6ms/step - loss: 40421.2645
# Epoch 15/50
# 274/274 [==============================] - 2s 6ms/step - loss: 39699.9238
# Epoch 16/50
# 274/274 [==============================] - 2s 6ms/step - loss: 38963.5907
# Epoch 17/50
# 274/274 [==============================] - 2s 6ms/step - loss: 37082.3013
# Epoch 18/50
# 274/274 [==============================] - 2s 7ms/step - loss: 35957.2543
#  6 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  8 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  10 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  12 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  14 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  16 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  18 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  20 [191 191 191 192 191 191 191 192 191 192 191 192]
# Example prediction:
#  22 [191 191 191 192 191 191 191 192 191 192 191 192]
# Building Eagle_education_Raul
# Building Eagle_education_Roman
#  Count bad values before: 23
#  Count bad values after: 0
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_147 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_148 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_149 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_49 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [2875 2422 2129 2760 3130 3071 3131 1877 3442 3736 3785 3729]
# Epoch 1/50
# 274/274 [==============================] - 6s 7ms/step - loss: 1739105.7677
# Epoch 2/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1745822.4273
# Epoch 3/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1726731.3295
# Epoch 4/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1703196.0491
# Epoch 5/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1708459.3373
# Epoch 6/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1689916.3345
# Epoch 7/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1676351.4977
# Epoch 8/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1645486.9195
# Epoch 9/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1677463.3814
# Epoch 10/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1655801.6009
# Epoch 11/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1632198.6882
# Epoch 12/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1606077.3373
# Epoch 13/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1593109.8636
# Epoch 14/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1618591.1468
# Epoch 15/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1617955.3900
# Epoch 16/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1588528.7373
# Epoch 17/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1579794.8618
# Epoch 18/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1553785.7064
# Epoch 19/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1539139.8791
# Epoch 20/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1533887.8455
# Epoch 21/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1537060.1468
# Epoch 22/50
#  12 [231 231 231 229 230 232 231 231 229 230 230 230]
# Example prediction:
#  14 [231 231 231 229 230 232 231 231 229 230 230 230]
# Example prediction:
#  16 [231 231 231 229 230 232 231 231 229 230 230 230]
# Example prediction:
#  18 [231 231 231 229 230 232 231 231 229 230 230 230]
# Example prediction:
#  20 [231 231 231 229 230 232 231 231 229 230 230 230]
# Example prediction:
#  22 [231 231 231 229 230 232 231 231 229 230 230 230]
# Building Eagle_office_Mandi
#  Count bad values before: 0
#  Count bad values after: 0
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_150 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_151 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_152 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_50 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [63 63 63 63 63 63 63 63 64 63 62 63]
# Epoch 1/50
# 274/274 [==============================] - 6s 7ms/step - loss: 1560.5985
# Epoch 2/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1197.3415
# Epoch 3/50
# 274/274 [==============================] - 2s 7ms/step - loss: 949.6745
# Epoch 4/50
# 274/274 [==============================] - 2s 7ms/step - loss: 764.5058
# Epoch 5/50
# 274/274 [==============================] - 2s 7ms/step - loss: 622.5566
# Epoch 6/50
# 274/274 [==============================] - 2s 7ms/step - loss: 504.9131
# Epoch 7/50
# 274/274 [==============================] - 2s 7ms/step - loss: 425.3084
# Epoch 8/50
# 274/274 [==============================] - 2s 7ms/step - loss: 370.1228
# Epoch 9/50
# 274/274 [==============================] - 2s 7ms/step - loss: 328.8295
# Epoch 10/50
# 274/274 [==============================] - 2s 7ms/step - loss: 307.0518
# Epoch 11/50
# 274/274 [==============================] - 2s 7ms/step - loss: 283.4725
# Epoch 12/50
# 274/274 [==============================] - 2s 7ms/step - loss: 286.5486
# Epoch 13/50
# 274/274 [==============================] - 2s 7ms/step - loss: 279.2136
# Epoch 14/50
# 274/274 [==============================] - 2s 7ms/step - loss: 280.3563
# Epoch 15/50
# 274/274 [==============================] - 2s 7ms/step - loss: 273.1696
# Epoch 16/50
# 274/274 [==============================] - 2s 7ms/step - loss: 275.6796
# Epoch 17/50
# 274/274 [==============================] - 2s 7ms/step - loss: 275.5470
# Epoch 18/50
# 274/274 [==============================] - 2s 7ms/step - loss: 269.7344
# Epoch 19/50
# 274/274 [==============================] - 2s 7ms/step - loss: 279.2986
# Epoch 20/50
# 274/274 [==============================] - 2s 7ms/step - loss: 269.9372
# Epoch 21/50
# 274/274 [==============================] - 2s 7ms/step - loss: 273.2310
# Epoch 22/50
# 274/274 [==============================] - 2s 7ms/step - loss: 279.7125
# Epoch 23/50
# 274/274 [==============================] - 2s 7ms/step - loss: 266.7597
# Epoch 24/50
# 274/274 [==============================] - 2s 7ms/step - loss: 280.6600
# Epoch 25/50
# 274/274 [==============================] - 2s 7ms/step - loss: 275.0311
# Epoch 26/50
# 274/274 [==============================] - 2s 7ms/step - loss: 288.6731
# Epoch 27/50
# 274/274 [==============================] - 2s 7ms/step - loss: 234.0348
# Epoch 28/50
# 274/274 [==============================] - 2s 7ms/step - loss: 140.1072
# Epoch 29/50
# 274/274 [==============================] - 2s 7ms/step - loss: 102.6954
# Epoch 30/50
# 274/274 [==============================] - 2s 7ms/step - loss: 87.2628
# Epoch 31/50
# 274/274 [==============================] - 2s 7ms/step - loss: 76.8083
# Epoch 32/50
# 274/274 [==============================] - 2s 7ms/step - loss: 71.1390
# Epoch 33/50
# 274/274 [==============================] - 2s 7ms/step - loss: 67.7289
# Epoch 34/50
# 274/274 [==============================] - 2s 7ms/step - loss: 65.7436
# Epoch 35/50
# 274/274 [==============================] - 2s 7ms/step - loss: 64.2078
# Epoch 36/50
# 274/274 [==============================] - 2s 7ms/step - loss: 65.5009
# Epoch 37/50
# 274/274 [==============================] - 2s 7ms/step - loss: 65.2846
# Epoch 38/50
# 274/274 [==============================] - 2s 7ms/step - loss: 63.3053
# Epoch 39/50
# 274/274 [==============================] - 2s 7ms/step - loss: 61.8029
# Epoch 40/50
# 274/274 [==============================] - 2s 7ms/step - loss: 66.1816
# Epoch 41/50
# 274/274 [==============================] - 2s 7ms/step - loss: 63.2712
# Epoch 42/50
# 274/274 [==============================] - 2s 7ms/step - loss: 61.9722
# Epoch 43/50
# 274/274 [==============================] - 2s 7ms/step - loss: 65.5463
# Epoch 44/50
# 274/274 [==============================] - 2s 7ms/step - loss: 62.1047
# Epoch 45/50
# 274/274 [==============================] - 2s 7ms/step - loss: 60.3186
# Epoch 46/50
# 274/274 [==============================] - 2s 7ms/step - loss: 59.2470
# Epoch 47/50
# 274/274 [==============================] - 2s 7ms/step - loss: 60.2662
# Epoch 48/50
# 274/274 [==============================] - 2s 7ms/step - loss: 59.4704
# Epoch 49/50
# 274/274 [==============================] - 2s 7ms/step - loss: 63.0826
# Epoch 50/50
# 274/274 [==============================] - 2s 7ms/step - loss: 62.8044
# mean,rmse,rmse/mean,bldg: 35.89375163018761 9.049186992867973 0.25211036968499456 Eagle_office_Mandi
# Example prediction:
#  0 [53 53 53 53 53 53 53 53 52 53 53 53]
# Example prediction:
#  2 [56 56 56 56 56 56 56 56 56 56 56 56]
# Example prediction:
#  4 [61 60 61 61 61 61 61 61 61 61 61 60]
# Example prediction:
#  6 [60 60 60 60 60 60 61 60 60 60 60 60]
# Example prediction:
#  8 [58 58 58 59 59 58 59 58 58 59 58 58]
# Example prediction:
#  10 [59 59 59 59 59 59 59 59 59 59 59 58]
# Example prediction:
#  12 [58 58 58 58 59 58 59 58 58 58 58 58]
# Example prediction:
#  14 [60 60 60 60 60 60 60 60 60 60 60 60]
# Example prediction:
#  16 [57 57 57 57 57 57 57 57 57 57 57 57]
# Example prediction:
#  18 [50 50 50 50 50 50 50 50 50 50 50 50]
# Example prediction:
#  20 [49 49 49 49 49 49 48 49 49 48 49 49]
# Example prediction:
#  22 [49 49 49 49 49 49 49 49 49 49 49 49]
# Building Eagle_education_Jewell
#  Count bad values before: 0
#  Count bad values after: 0
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Epoch 32/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1661.4075
# Epoch 33/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1589.6622
# Epoch 34/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1642.3559
# Epoch 35/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1576.7631
# Epoch 36/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1489.1065
# Epoch 37/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1504.0061
# Epoch 38/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1444.5798
# Epoch 39/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1442.2287
# Epoch 40/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1444.7734
# Epoch 41/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1476.1213
# Epoch 42/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1448.5109
# Epoch 43/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1362.1051
# Epoch 44/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1373.7621
# Epoch 45/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1284.5976
# Epoch 46/50
# 274/274 [==============================] - 2s 7ms/step - loss: 1414.3762
# Epoch 47/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1316.8071
# Epoch 48/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1265.6903
# Epoch 49/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1260.5601
# Epoch 50/50
# 274/274 [==============================] - 2s 6ms/step - loss: 1257.2411
# mean,rmse,rmse/mean,bldg: 15.763073324212357 29.932069133121853 1.8988726701629732 Eagle_education_Jewell
# Example prediction:
#  0 [82 83 82 83 84 83 84 82 81 81 81 80]
# Example prediction:
#  2 [78 78 78 78 79 78 79 78 76 77 76 76]
# Example prediction:
#  4 [107 107 107 107 108 107 108 107 105 105 104 104]
# Example prediction:
#  6 [123 124 124 124 124 124 124 123 122 121 121 120]
# Example prediction:
#  8 [135 135 135 135 135 135 135 134 133 133 132 131]
# Example prediction:
#  10 [72 71 72 72 72 73 70 71 71 70 70 70]
# Example prediction:
#  12 [125 124 125 125 125 125 125 124 123 123 122 121]
# Example prediction:
#  14 [135 135 135 135 136 135 135 134 133 133 132 131]
# Example prediction:
#  16 [9 7 9 8 8 8 8 8 9 8 8 9]
# Example prediction:
#  18 [30 29 29 29 29 29 28 29 29 28 29 29]
# Example prediction:
#  20 [123 122 123 123 123 123 123 122 121 121 120 119]
# Example prediction:
#  22 [101 101 101 102 102 101 102 101 100  99  99  99]
# Building Eagle_office_Henriette
#  Count bad values before: 117
#  Count bad values after: 0
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Epoch 35/50
# 274/274 [==============================] - 2s 7ms/step - loss: 4.0866e-07
# Epoch 36/50
# 274/274 [==============================] - 2s 7ms/step - loss: 7.2395e-07
# Epoch 37/50
# 274/274 [==============================] - 2s 7ms/step - loss: 4.4804e-07
# Epoch 38/50
# ...
# Epoch 49/50
# 274/274 [==============================] - 2s 8ms/step - loss: 670.0824
# Epoch 50/50
# 274/274 [==============================] - 2s 8ms/step - loss: 647.0140
# mean,rmse,rmse/mean,bldg: 121.45534449703446 28.455637574576564 0.2342888877588368 Eagle_office_Remedios
# Example prediction:
#  0 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  2 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  4 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  6 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  8 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  10 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  12 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  14 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  16 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  18 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  20 [157 157 157 157 157 157 158 157 157 157 156 156]
# Example prediction:
#  22 [157 157 157 157 157 157 158 157 157 157 156 156]
# Building Eagle_office_Patrice
#  Count bad values before: 0
#  Count bad values after: 0
# Model: "sequential_84"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_252 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_253 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_254 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_84 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [453 435 295 371 293 213 213 210 213 240 432 704]
# Epoch 1/50
# 274/274 [==============================] - 6s 8ms/step - loss: 33837.1480
# Epoch 2/50
# 274/274 [==============================] - 2s 9ms/step - loss: 32297.1802
# Epoch 3/50
# 274/274 [==============================] - 2s 8ms/step - loss: 31784.9300
# Epoch 4/50
# 274/274 [==============================] - 2s 8ms/step - loss: 29787.0157
# Epoch 5/50
# 274/274 [==============================] - 2s 8ms/step - loss: 30046.8418
# Epoch 6/50
# 274/274 [==============================] - 2s 8ms/step - loss: 29353.1985
# Epoch 7/50
# 274/274 [==============================] - 2s 8ms/step - loss: 27778.3632
# Epoch 8/50
# 274/274 [==============================] - 2s 9ms/step - loss: 27444.6377
# Epoch 9/50
# 274/274 [==============================] - 2s 8ms/step - loss: 26034.7483
# Epoch 10/50
# 274/274 [==============================] - 2s 8ms/step - loss: 24968.3630
# Epoch 11/50
# 274/274 [==============================] - 2s 8ms/step - loss: 24302.2559
# Epoch 12/50
# 274/274 [==============================] - 2s 8ms/step - loss: 23287.8207
# Epoch 13/50
# Epoch 50/50
# 274/274 [==============================] - 2s 8ms/step - loss: 8399.2463
# mean,rmse,rmse/mean,bldg: 165.8827588691298 105.84932042055453 0.6380971786468927 Eagle_office_Patrice
# Example prediction:
#  0 [6 6 4 8 7 7 6 6 7 7 7 6]
# Example prediction:
#  2 [4 4 3 6 5 5 5 4 6 5 5 5]
# Example prediction:
#  4 [3 3 2 5 4 4 4 3 4 4 4 3]
# Example prediction:
#  6 [193 192 191 192 191 191 193 191 193 191 192 194]
# Example prediction:
#  8 [193 193 192 192 191 192 193 192 193 192 192 194]
# Example prediction:
#  10 [193 193 192 192 191 192 193 192 193 192 192 194]
# Example prediction:
#  12 [193 193 192 192 191 192 194 192 193 192 192 194]
# Example prediction:
#  14 [193 193 192 192 191 192 194 192 193 192 192 194]
# Example prediction:
#  16 [193 193 192 192 191 192 194 192 193 192 192 194]
# Example prediction:
#  18 [193 193 192 192 191 192 194 192 193 192 192 194]
# Example prediction:
#  20 [193 193 192 192 191 192 194 192 193 192 192 194]
# Example prediction:
#  22 [193 193 192 192 191 192 194 192 193 192 192 194]
# Building Eagle_education_Shana
#  Count bad values before: 0
#  Count bad values after: 0
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_255 (GRU)                (None, 12, 16)            1008
# _________________________________________________________________
# gru_256 (GRU)                (None, 12, 16)            1632
# _________________________________________________________________
# gru_257 (GRU)                (None, 16)                1632
# _________________________________________________________________
# dense_85 (Dense)             (None, 12)                204
# =================================================================
# Total params: 4,476
# Trainable params: 4,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# Example y train:
#  [182 182 183 183 182 182 183 183 184 183 180 182]
# Epoch 1/50
# 274/274 [==============================] - 7s 8ms/step - loss: 13296.4043
# Epoch 2/50
# 274/274 [==============================] - 2s 8ms/step - loss: 12248.4443
# Epoch 3/50
# 274/274 [==============================] - 2s 8ms/step - loss: 11215.2442
# Epoch 4/50
# 274/274 [==============================] - 2s 8ms/step - loss: 10465.5359
# Epoch 5/50
# 274/274 [==============================] - 2s 8ms/step - loss: 9483.2462
# Epoch 6/50
# 274/274 [==============================] - 2s 8ms/step - loss: 9048.9760
# Epoch 7/50
# 274/274 [==============================] - 2s 8ms/step - loss: 8282.4960
# Epoch 8/50
# 274/274 [==============================] - 2s 8ms/step - loss: 7665.0737
# Epoch 9/50
# 274/274 [==============================] - 2s 8ms/step - loss: 7106.6286
# Epoch 10/50
# 274/274 [==============================] - 2s 8ms/step - loss: 6597.5348
# Epoch 11/50
# 274/274 [==============================] - 2s 8ms/step - loss: 6125.5029
# Epoch 12/50
# 274/274 [==============================] - 2s 8ms/step - loss: 5666.8019
# Epoch 13/50
# 274/274 [==============================] - 2s 8ms/step - loss: 5150.8360
# Epoch 14/50
# 274/274 [==============================] - 2s 8ms/step - loss: 4855.7460
# Epoch 15/50
# 274/274 [==============================] - 2s 8ms/step - loss: 4383.3668
# Epoch 16/50
# 274/274 [==============================] - 2s 9ms/step - loss: 4219.8262
# Epoch 17/50
# 274/274 [==============================] - 2s 8ms/step - loss: 3848.9762
#  4 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  6 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  8 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  10 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  12 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  14 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  16 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  18 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  20 [149 149 149 149 150 149 149 150 149 149 149 149]
# Example prediction:
#  22 [149 149 149 149 150 149 149 150 149 149 149 149]
#
# History 24 Future 12
# Column 1: Mean usage.
# Column 2: RMSE of LinearRegression(X=Weather, y=Usage).
# Column 3: RMSE/mean normalized to help understand RMSE.
# Column 4: Building.
#       0.00       0.00   inf   Eagle_office_Henriette
#       0.11       0.04  0.38   Eagle_education_Wesley
#      15.76      29.93  1.90   Eagle_education_Jewell
#      22.57      44.45  1.97   Eagle_lodging_Casey
#      35.89       9.05  0.25   Eagle_office_Mandi
#      36.93      10.64  0.29   Eagle_office_Lamont
#      43.44      47.04  1.08   Eagle_lodging_Blake
#      46.46      22.45  0.48   Eagle_education_Eileen
#      56.51      76.04  1.35   Eagle_office_Dallas
#      57.05      36.24  0.64   Eagle_education_Petra
#      62.02      58.83  0.95   Eagle_office_Sheree
#      81.97      68.99  0.84   Eagle_lodging_Edgardo
#      87.21      23.26  0.27   Eagle_office_Phyllis
#      91.28      76.74  0.84   Eagle_lodging_Trina
#      92.83      58.54  0.63   Eagle_lodging_Dawn
#     101.60      63.62  0.63   Eagle_office_Freida
#     103.18      23.43  0.23   Eagle_education_Shana
#     121.46      28.46  0.23   Eagle_office_Remedios
#     122.35      56.26  0.46   Eagle_health_Vincenza
#     148.74      61.23  0.41   Eagle_education_Teresa
#     165.88     105.85  0.64   Eagle_office_Patrice
#     174.62      94.71  0.54   Eagle_office_Tia
#     182.08      81.12  0.45   Eagle_public_Alvin
#     192.41      77.20  0.40   Eagle_health_Jodi
#     216.03     244.83  1.13   Eagle_assembly_Herbert
#     226.32      55.24  0.24   Eagle_education_Will
#     272.96     124.67  0.46   Eagle_office_Nereida
#     276.26     209.65  0.76   Eagle_food_Kay
#     336.47     213.28  0.63   Eagle_office_Francis
#     390.78     230.62  0.59   Eagle_office_Norbert
#     477.70     325.76  0.68   Eagle_health_Athena
#     659.66     777.20  1.18   Eagle_health_Gregoria
#     694.98     528.06  0.76   Eagle_education_Alberto
#     712.07     671.74  0.94   Eagle_education_Norah
#    1004.16    1873.14  1.87   Eagle_education_Shante
#    1037.69     936.30  0.90   Eagle_office_Chauncey
#    1084.29     927.79  0.86   Eagle_health_Reba
#    1199.41    1085.07  0.90   Eagle_education_Roman
#    1638.69    1814.41  1.11   Eagle_education_Brooke
#    2032.67    2084.72  1.03   Eagle_education_Sherrill
#    3153.28    3043.10  0.97   Eagle_education_Peter
